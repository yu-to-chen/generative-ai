# %% [markdown]
# # L3: Agentic Sales Pipeline

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Load API tokens for our 3rd party APIs

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'lead_agents': 'config/lead_qualification_agents.yaml',
    'lead_tasks': 'config/lead_qualification_tasks.yaml',
    'email_agents': 'config/email_engagement_agents.yaml',
    'email_tasks': 'config/email_engagement_tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
lead_agents_config = configs['lead_agents']
lead_tasks_config = configs['lead_tasks']
email_agents_config = configs['email_agents']
email_tasks_config = configs['email_tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from pydantic import BaseModel, Field
from typing import Dict, Optional, List, Set, Tuple

class LeadPersonalInfo(BaseModel):
    name: str = Field(..., description="The full name of the lead.")
    job_title: str = Field(..., description="The job title of the lead.")
    role_relevance: int = Field(..., ge=0, le=10, description="A score representing how relevant the lead's role is to the decision-making process (0-10).")
    professional_background: Optional[str] = Field(..., description="A brief description of the lead's professional background.")

class CompanyInfo(BaseModel):
    company_name: str = Field(..., description="The name of the company the lead works for.")
    industry: str = Field(..., description="The industry in which the company operates.")
    company_size: int = Field(..., description="The size of the company in terms of employee count.")
    revenue: Optional[float] = Field(None, description="The annual revenue of the company, if available.")
    market_presence: int = Field(..., ge=0, le=10, description="A score representing the company's market presence (0-10).")

class LeadScore(BaseModel):
    score: int = Field(..., ge=0, le=100, description="The final score assigned to the lead (0-100).")
    scoring_criteria: List[str] = Field(..., description="The criteria used to determine the lead's score.")
    validation_notes: Optional[str] = Field(None, description="Any notes regarding the validation of the lead score.")

class LeadScoringResult(BaseModel):
    personal_info: LeadPersonalInfo = Field(..., description="Personal information about the lead.")
    company_info: CompanyInfo = Field(..., description="Information about the lead's company.")
    lead_score: LeadScore = Field(..., description="The calculated score and related information for the lead.")

# %% [markdown]
# ## Importing Tools

# %%
from crewai_tools import SerperDevTool, ScrapeWebsiteTool

# %% [markdown]
# ## Lead Qualification Crew, Agents and Tasks

# %%
# Creating Agents
lead_data_agent = Agent(
  config=lead_agents_config['lead_data_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()]
)

cultural_fit_agent = Agent(
  config=lead_agents_config['cultural_fit_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()]
)

scoring_validation_agent = Agent(
  config=lead_agents_config['scoring_validation_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()]
)

# Creating Tasks
lead_data_task = Task(
  config=lead_tasks_config['lead_data_collection'],
  agent=lead_data_agent
)

cultural_fit_task = Task(
  config=lead_tasks_config['cultural_fit_analysis'],
  agent=cultural_fit_agent
)

scoring_validation_task = Task(
  config=lead_tasks_config['lead_scoring_and_validation'],
  agent=scoring_validation_agent,
  context=[lead_data_task, cultural_fit_task],
  output_pydantic=LeadScoringResult
)

# Creating Crew
lead_scoring_crew = Crew(
  agents=[
    lead_data_agent,
    cultural_fit_agent,
    scoring_validation_agent
  ],
  tasks=[
    lead_data_task,
    cultural_fit_task,
    scoring_validation_task
  ],
  verbose=True
)
# Out:
# 2025-01-02 17:26:24,493 - 13007122432 - __init__.py-__init__:362 - ERROR: Exception while exporting Span batch.
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 1428, in getresponse
#     response.begin()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py", line 1251, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py", line 1103, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/util/util.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connectionpool.py", line 538, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/urllib3/connectionpool.py", line 369, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/opentelemetry/sdk/trace/export/__init__.py", line 360, in _export_batch
#     self.span_exporter.export(self.spans_list[:idx])  # type: ignore
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/opentelemetry/exporter/otlp/proto/http/trace_exporter/__init__.py", line 189, in export
#     return self._export_serialized_spans(serialized_data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/opentelemetry/exporter/otlp/proto/http/trace_exporter/__init__.py", line 159, in _export_serialized_spans
#     resp = self._export(serialized_data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/opentelemetry/exporter/otlp/proto/http/trace_exporter/__init__.py", line 133, in _export
#     return self._session.post(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/requests/sessions.py", line 637, in post
#     return self.request("POST", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/requests/adapters.py", line 713, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Read timed out. (read timeout=30)

# %% [markdown]
# ## Email Engagement Crew

# %%
# Creating Agents
email_content_specialist = Agent(
  config=email_agents_config['email_content_specialist']
)

engagement_strategist = Agent(
  config=email_agents_config['engagement_strategist']
)

# Creating Tasks
email_drafting = Task(
  config=email_tasks_config['email_drafting'],
  agent=email_content_specialist
)

engagement_optimization = Task(
  config=email_tasks_config['engagement_optimization'],
  agent=engagement_strategist
)

# Creating Crew
email_writing_crew = Crew(
  agents=[
    email_content_specialist,
    engagement_strategist
  ],
  tasks=[
    email_drafting,
    engagement_optimization
  ],
  verbose=True
)
# Out:
# 2025-01-02 17:16:21,634 - 8559460928 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Creating Complete Sales Flow

# %%
from crewai import Flow
from crewai.flow.flow import listen, start

class SalesPipeline(Flow):
    @start()
    def fetch_leads(self):
        # Pull our leads from the database
        leads = [
            {
                "lead_data": {
                    "name": "João Moura",
                    "job_title": "Director of Engineering",
                    "company": "Clearbit",
                    "email": "joao@clearbit.com",
                    "use_case": "Using AI Agent to do better data enrichment."
                },
            },
        ]
        return leads

    @listen(fetch_leads)
    def score_leads(self, leads):
        scores = lead_scoring_crew.kickoff_for_each(leads)
        self.state["score_crews_results"] = scores
        return scores

    @listen(score_leads)
    def store_leads_score(self, scores):
        # Here we would store the scores in the database
        return scores

    @listen(score_leads)
    def filter_leads(self, scores):
        return [score for score in scores if score['lead_score'].score > 70]

    @listen(filter_leads)
    def write_email(self, leads):
        scored_leads = [lead.to_dict() for lead in leads]
        emails = email_writing_crew.kickoff_for_each(scored_leads)
        return emails

    @listen(write_email)
    def send_email(self, emails):
        # Here we would send the emails to the leads
        return emails

flow = SalesPipeline()

# %% [markdown]
# ## Plotting the Flow

# %%
flow.plot()
# Out:
# Plot saved as crewai_flow.html

# %%
from IPython.display import IFrame

IFrame(src='./crewai_flow.html', width='150%', height=600)
# Out:
#         <iframe
#             width="150%"
#             height="600"
#             src="./crewai_flow.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Flow Kickoff

# %%
#%autoawait

# %%
import sys
# !{sys.executable} -m pip install nest-asyncio
# Out:
# Requirement already satisfied: nest-asyncio in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (1.6.0)

# %%
#emails = flow.kickoff()

# %%
"""
import nest_asyncio

nest_asyncio.apply()

# Now your async code should work:
emails = await flow.kickoff()
"""

# %%
"""
import asyncio

async def run_flow():
    return await flow.kickoff()

emails = await run_flow()
"""

# %%
async def run_flow():
    return await flow.kickoff_async()

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio

emails = await run_flow()
# Out:
# 2025-01-02 17:41:39,117 - 8559460928 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Lead Data Specialist
# ## Task: Collect and analyze the following information about the lead:
# - Personal Information:
#   - Name: Obtain the full name of the lead.
#   - Job Title: Determine the lead's current job title.
#   - Role Relevance: Assess how relevant the lead's role is to the decision-making process on a scale from 0 to 10.
#   - Professional Background: Optionally, gather a brief description of the lead's professional background.
#
# - Company Information:
#   - Company Name: Identify the name of the company the lead works for.
#   - Industry: Determine the industry in which the company operates.
#   - Company Size: Estimate the size of the company in terms of employee count.
#   - Revenue: If available, collect information on the annual revenue of the company.
#   - Market Presence: Evaluate the company's market presence on a scale from 0 to 10.
#
# - Our Company and Product:
#   - Company Name: CrewAI
#   - Product: Multi-Agent Orchestration Platform
#   - ICP: Enterprise companies looking into Agentic automation.
#   - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# -Lead Data:
#   {'name': 'João Moura', 'job_title': 'Director of Engineering', 'company': 'Clearbit', 'email': 'joao@clearbit.com', 'use_case': 'Using AI Agent to do better data enrichment.'}
#
#
#
# # Agent: Lead Data Specialist
# ## Thought: I need to gather information about the lead, João Moura, and his company, Clearbit. I'll start by searching for personal information and company details.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Jo\\u00e3o Moura Director of Engineering Clearbit profile\"}"
# ## Tool Output:
#
# Search results: Title: Meet João Moura: Clearbit's Senior Engineering Manager
# Link: https://clearbit.com/blog/joao-moura
# Snippet: João Moura has always been a leader. And for the past 4 years, he has been building and scaling the Clearbit engineering team as Senior Engineering Manager.
# ---
# Title: About me - Joao Moura
# Link: http://joaomdmoura.com/about/
# Snippet: Currently I'm an Engineering Manager at Clearbit, a fast growing company in the San Francisco, where I help manage and build some of the most incredible ...
# ---
# Title: João (Joe) Moura on LinkedIn: #clearbit #hubspot #ai #leadership ...
# Link: https://www.linkedin.com/posts/joaomdmoura_clearbit-hubspot-ai-activity-7125492053857189888-G5DN?trk=public_profile_like_view
# Snippet: Founder at crewAI - Remote Team Leader | Product Strategy | Leadership | Expert in Ruby, Python, JavaScript, Elixir and Data Science
# ---
# Title: João (Joe) Moura's Post - LinkedIn
# Link: https://www.linkedin.com/posts/joaomdmoura_fully-autonomous-departments-backed-by-ai-activity-7130285095780777985--4DP
# Snippet: João (Joe) Moura's Post. View profile for João (Joe) Moura, graphic. João (Joe) Moura. Founder at crewAI - Remote Team Leader | Product ...
# ---
# Title: Joao Moura - Crunchbase Person Profile
# Link: https://www.crunchbase.com/person/joao-moura
# Snippet: Joao Moura is the Engineering Manager at Clearbit . Additionally, Joao Moura has had 1 past job as the Senior Software Engineer at Ride . Clearbit Logo.
# ---
# Title: João Moura - Warmly
# Link: https://rapport.warmly.ai/user/jo%C3%A3omoura
# Snippet: User Profile. João Moura. Director of Engineering. Clearbit. Cotia - State of ... Director of Engineering at Clearbit. Cotia - State of São Paulo, Brazil.
# ---
# Title: João Moura AI professional profile, contact information, work ...
# Link: https://www.edgein.io/people/joao-moura/
# Snippet: View João Moura's profile on EdgeIn, the world's leading AI & Web3 data intelligence platform. João Moura has 1 jobs listed on their profile.
# ---
# Title: Clearbit - From teaching a typing class at 13 to managing... | Facebook
# Link: https://m.facebook.com/story.php/?story_fbid=5683901614976708&id=984849984881918
# Snippet: From teaching a typing class at 13 to managing multiple engineering teams, João Moura has always been a leader. And for the past 4 years, he has been building ...
# ---
# Title: The Future of AI Agents - Joao Moura (CEO, CrewAI)
# Link: https://shomik.substack.com/p/the-future-of-ai-agents-joao-moura
# Snippet: Joao Moura is Founder & CEO of CrewAI, the leading multi-agent platform. He previously was Director of AI Engineering at Clearbit which was ...
# ---
# Title: João Moura (@joaomdmoura) • Threads, Say more
# Link: https://www.threads.net/@joaomdmoura
# Snippet: 270 Followers • 172 Threads • Director of Engineering at @clearbit | Open Source enthusiast | Creator of Machinery | Public Speaker | Blog:...
# ---
#
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: I have gathered some identifiers related to João Moura, particularly his job title and current company. Next, I will search for information related to Clearbit to gather more detailed company information, including industry, size, revenue, and market presence.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Clearbit company profile industry size revenue\"}"
# ## Tool Output:
#
# Search results: Title: Clearbit Company Profile 2024: Valuation, Investors, Acquisition
# Link: https://pitchbook.com/profiles/company/101066-86
# Snippet: What is the size of Clearbit? Clearbit has 116 total employees. What industry is Clearbit in? Clearbit's primary industry is Business/Productivity Software.
# ---
# Title: Leverage 100+ business data attributes - Clearbit
# Link: https://clearbit.com/attributes
# Snippet: Enrich your CRM and database, manage leads efficiently, and enable marketing personalization with over 100 business data points.
# ---
# Title: Fit: firmographic and employment data - Clearbit
# Link: https://clearbit.com/resources/books/b2b-data/firmographic-demographic
# Snippet: Firmographic data: company information, like size, type, industry, revenue, etc., indicating whether the company is a good fit for your product or service.
# ---
# Title: Clearbit company information, funding & investors | Dealroom.co
# Link: https://app.dealroom.co/companies/clearbit
# Snippet: Clearbit, clearbit is the marketing data engine for all of your customer interactions. Here you'll find information about their funding, investors and team.
# ---
# Title: Clearbit Reviews, Ratings & Features 2024 | Gartner Peer Insights
# Link: https://www.gartner.com/reviews/market/revenue-data-solutions/vendor/clearbit/product/clearbit
# Snippet: World-class tool for data and information. Reviewed on Mar 15, 2020. Reviewer Function: IT; Company Size: 500M - 1B USD; Industry: Finance (non-banking) ...
# ---
# Title: Clearbit - Company Profile - Tracxn
# Link: https://tracxn.com/d/companies/clearbit/__Ce8LwLChfXW6bZzY3dPGa0_FQQTE-gGHyGdZnzdvqT4
# Snippet: Clearbit - Business Intelligence APIs for Lead generation and enrichment. Acquired by HubSpot. Raised a total funding of $2M over 1 round ...
# ---
# Title: Clearbit - Products, Competitors, Financials, Employees ...
# Link: https://www.cbinsights.com/company/clearbit
# Snippet: Clearbit provides business-to-business (B2B) marketing intelligence solutions. Use the CB Insights Platform to explore Clearbit's full profile.
# ---
# Title: Searching for healthier revenue — the process behind ... - Clearbit
# Link: https://clearbit.com/blog/ideal-customer-profile-process
# Snippet: We found that the Pareto principle holds true for us: around 86% of Clearbit's long-term revenue comes from around 18% of the leads that enter our funnel.
# ---
# Title: Clearbit: Revenue, Competitors, Alternatives - Growjo
# Link: https://growjo.com/company/Clearbit
# Snippet: Estimated Revenue & Valuation · Clearbit's estimated annual revenue is currently $17.8M per year.(i) · Clearbit received $15.0M in venture funding in March 2019.
# ---
#
#
#
# # Agent: Lead Data Specialist
# ## Final Answer:
# - Personal Information:
#   - Name: João Moura
#   - Job Title: Director of Engineering
#   - Role Relevance: 8 (as he plays a key role in technical decisions and AI implementation)
#   - Professional Background: João Moura has extensive experience in leading engineering teams, previously worked as a Senior Engineering Manager at Clearbit, and has founding experience with CrewAI, focusing on AI and data enrichment.
#
# - Company Information:
#   - Company Name: Clearbit
#   - Industry: Business/Productivity Software
#   - Company Size: Approximately 116 employees
#   - Revenue: Estimated annual revenue of $17.8 million
#   - Market Presence: 8 (Clearbit has a significant presence in the data enrichment and marketing intelligence sector, recognized for its innovative solutions and a strong customer base).
#
#
# # Agent: Cultural Fit Analyst
# ## Task: Assess the cultural alignment between the lead's company and our organization by considering the following:
#   - Cultural Values: Analyze the company's publicly stated values and internal culture (e.g., innovation, sustainability, employee engagement).
#   - Strategic Alignment: Evaluate how well the company's goals and mission align with our organization's strategic objectives.
#   - Qualitative Scoring: Assign a qualitative score (0-10) representing the overall cultural fit.
#   - Comments: Provide additional comments or observations that support the cultural fit score.
#
# - Our Company and Product:
#   - Company Name: CrewAI
#   - Product: Multi-Agent Orchestration Platform
#   - ICP: Enterprise companies looking into Agentic automation.
#   - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# - Lead Data:
#   {'name': 'João Moura', 'job_title': 'Director of Engineering', 'company': 'Clearbit', 'email': 'joao@clearbit.com', 'use_case': 'Using AI Agent to do better data enrichment.'}
#
#
#
# # Agent: Cultural Fit Analyst
# ## Thought: I need to gather information regarding the cultural values and mission of Clearbit in order to assess the cultural alignment with CrewAI. Since this information may be available on their website, I'll start by reading their website content.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://clearbit.com\"}"
# ## Tool Output:
# Clearbit is Now Breeze Intelligence for HubSpot Clearbit customer login Clearbit has joined HubSpot! The best B2B data provider is now part of the best B2B customer platform! Breeze Intelligence for HubSpot To reach the right audiences and get the most out of AI, you need the right data. With Breeze Intelligence, you ‌get a full picture of your prospects and customers — making your marketing, sales, and service efforts even more effective. Check out Breeze! A data foundation you can build on We gather public data from the web, our proprietary data, and the power of LLMs to convert unstructured information into precise and standardized data sets. Get access to clean, precise, and reliable data that your B2B team needs to go-to-market. Data for leads, contacts, and accounts Enrich every single record Global coverage across every country, in any language. Starting with the most precise data sources, we then incorporate all other available sources to offer you the optimal combination of accuracy and coverage. Focus on what matters Score & route instantly The data you need to score and route every lead, in real-time. Identify your high fit leads in real time and focus your team's efforts where they matter most. Best in class industry info. The most granular possible industry categorization, including 6 digit NAICS, GICS, and SIC. Corporate Hierarchies. Understand parent companies and subsidiaries to route the right lead to the right rep. Normalized Role & Seniority. Turn titles into a standardized set of roles and seniorities to easily map your systems to your Ideal Customer Profile. Identify hidden intent Reveal buying intent Turn your anonymous website traffic into real buying intent signals with our best-in-class IP intelligence data. The visitor dashboard highlights companies that match your ideal customer profile, enabling you to concentrate outbound efforts on qualified companies that are showing interest. Form shortening Shorter forms convert better Reduce friction be removing fields that Clearbit can enrich simply by collecting an email address. Dynamic Form Shortening only shows necessary fields if an enrichment value isn't available ensuring 100% data coverage for your leads. Trust Center Privacy Policy Status Support Legal Do Not Sell My Info Manage Cookies © 2024 Clearbit
#
#
# # Agent: Cultural Fit Analyst
# ## Thought: The website content largely focuses on Clearbit's product offerings and capabilities, with less emphasis on their internal cultural values or mission. Therefore, I need to search for additional information about Clearbit's corporate culture and values to make a more thorough assessment.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Clearbit company culture values\"}"
# ## Tool Output:
#
# Search results: Title: Clearbit Mission, Values, Culture & Jobs - Teal
# Link: https://www.tealhq.com/company/clearbit
# Snippet: Continuous Improvement: Clearbit fosters a culture of continuous improvement, encouraging employees to learn, grow, and innovate to drive the company forward.
# ---
# Title: Clearbit Digital Marketing Team Culture | ClickThrough
# Link: https://clickthrough.marketing/clearbit-team-values/
# Snippet: We're a team of highly analytical and data-driven individuals. We have a deep understanding of core marketing metrics and how they directly impact our business.
# ---
# Title: My first year at Clearbit: learning how to be remote and resourceful
# Link: https://clearbit.com/blog/remote-work-growth
# Snippet: Good work is only possible when there's an environment of (1) autonomy, (2) trust, and (3) healthy communication habits. These are foundational ...
# ---
# Title: Mission, Vision & Core Values of Clearbit - CBM
# Link: https://canvasbusinessmodel.com/blogs/mission/clearbit-mission
# Snippet: Clearbit is dedicated to continuous innovation and excellence in everything we do. We strive to push boundaries and challenge the status quo in ...
# ---
# Title: Clearbit Employee Benefits | Built In
# Link: https://builtin.com/company/clearbit/benefits
# Snippet: We believe in relentless pursuit of learning and development. That's why craft is one of our values and why you get an annual "Master Your Craft" stipend of ...
# ---
# Title: Values interviews - The Manager's Handbook
# Link: https://themanagershandbook.com/hiring-and-onboarding/interviewing/values-interviews
# Snippet: At Clearbit, we place a particular emphasis on building a close-knit team. We want to work with people whom we also enjoy spending time with.
# ---
# Title: Searching for healthier revenue — the process behind ... - Clearbit
# Link: https://clearbit.com/blog/ideal-customer-profile-process
# Snippet: See the step-by-step analysis behind how we redefined our ideal customer profile and what shifted our thinking about growth and revenue.
# ---
# Title: How Zapier builds remote success from the ground up - Clearbit
# Link: https://clearbit.com/blog/how-zapier-builds-remote-success
# Snippet: For example, one of their core values is bias to action. This focus on being proactive is especially important to remote companies, because if ...
# ---
# Title: Welcoming Clearbit to the HubSpot Team
# Link: https://www.hubspot.com/company-news/welcoming-clearbit-to-hubspot
# Snippet: Clearbit's CEO and CTO, Matt and Harlow, have a bold mission to leverage AI to power customer insights and are passionate about data. In all our ...
# ---
#
#
#
# # Agent: Cultural Fit Analyst
# ## Final Answer:
# Cultural Fit Score: **8/10**
#
# Supporting Analysis and Comments:
# - Both Clearbit and CrewAI share a strong commitment to innovation, which is crucial given the technological nature of CrewAI’s product.
# - Clearbit's cultural emphasis on autonomy and trust aligns with good engineering practices and the collaborative nature of tech teams within CrewAI.
# - The strong focus on data-driven decision-making at Clearbit supports CrewAI’s own product ethos, making this partnership promising for long-term success.
# - While sustainability was not directly mentioned, the culture of continuous improvement can indirectly lead to sustainable practices, creating an opportunity for aligning in this area in future.
#
# This assessment outlines a detailed analysis of the cultural fit between CrewAI and Clearbit, emphasizing their shared values and strategic objectives.
#
#
# # Agent: Lead Scorer and Validator
# ## Task: Aggregate the collected data and perform the following steps: - Score Calculation: Based on predefined criteria, calculate a final lead score (0-100). Consider factors such as:
#   - Role Relevance
#   - Company Size
#   - Market Presence
#   - Cultural Fit
# - Scoring Criteria Documentation: List the criteria used to determine the score. - Validation: Review the collected data and the calculated score for consistency and accuracy. Make adjustments if necessary. - Final Report: Compile a summary report that includes the final validated lead score, the criteria used, and any validation notes.
# - Our Company and Product:
#   - Company Name: CrewAI
#   - Product: Multi-Agent Orchestration Platform
#   - ICP: Enterprise companies looking into Agentic automation.
#   - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# - Lead Data:
#   {'name': 'João Moura', 'job_title': 'Director of Engineering', 'company': 'Clearbit', 'email': 'joao@clearbit.com', 'use_case': 'Using AI Agent to do better data enrichment.'}
#
#
#
# # Agent: Lead Scorer and Validator
# ## Thought: I need to gather information about Clearbit to verify the details provided concerning the company's industry, size, revenue, and market presence. Additionally, I will aggregate the information available on João Moura, focusing particularly on his role relevance.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Clearbit company overview, industry, size, revenue\"}"
# ## Tool Output:
#
# Search results: Title: Clearbit Company Profile 2024: Valuation, Investors, Acquisition
# Link: https://pitchbook.com/profiles/company/101066-86
# Snippet: Information on acquisition, funding, cap tables, investors, and executives for Clearbit. Use the PitchBook Platform to explore the full profile.
# ---
# Title: Clearbit company information, funding & investors | Dealroom.co
# Link: https://app.dealroom.co/companies/clearbit
# Snippet: Clearbit, clearbit is the marketing data engine for all of your customer interactions. Here you'll find information about their funding, investors and team.
# ---
# Title: Clearbit - Overview, News & Similar companies | ZoomInfo.com
# Link: https://www.zoominfo.com/c/clearbit/464190707
# Snippet: Clearbit's official website is www.clearbit.com What is Clearbit's Revenue? Clearbit's revenue is $20 Million What is Clearbit's SIC code?
# ---
# Title: Clearbit Reviews, Ratings & Features 2024 | Gartner Peer Insights
# Link: https://www.gartner.com/reviews/market/revenue-data-solutions/vendor/clearbit/product/clearbit
# Snippet: Company Size: 250M - 500M USD; Industry: IT Services Industry. Clearbit is a good platform to get quality B2B data for new business development. Being a part ...
# ---
# Title: Leverage 100+ business data attributes - Clearbit
# Link: https://clearbit.com/attributes
# Snippet: Enrich your CRM and database, manage leads efficiently, and enable marketing personalization with over 100 business data points.
# ---
# Title: Clearbit - Products, Competitors, Financials, Employees ...
# Link: https://www.cbinsights.com/company/clearbit
# Snippet: Clearbit provides business-to-business (B2B) marketing intelligence solutions. Use the CB Insights Platform to explore Clearbit's full profile.
# ---
# Title: Clearbit: Revenue, Competitors, Alternatives - Growjo
# Link: https://growjo.com/company/Clearbit
# Snippet: Estimated Revenue & Valuation · Clearbit's estimated annual revenue is currently $17.8M per year.(i) · Clearbit received $15.0M in venture funding in March 2019.
# ---
# Title: Clearbit - Market Share, Competitor Insights in Market Research
# Link: https://www.6sense.com/tech/market-research/clearbit-market-share
# Snippet: Clearbit has market share of 1.94% in market-research market. Clearbit competes with 111 competitor tools in market-research category. The top alternatives for ...
# ---
# Title: Clearbit Company Overview, Contact Details & Competitors | LeadIQ
# Link: https://leadiq.com/c/clearbit/5a1d842e24000024005ea95d
# Snippet: As of October 2024, Clearbit's annual revenue reached $15M. What is Clearbit's SIC code NAICS code?
# ---
#
#
#
# # Agent: Lead Scorer and Validator
# ## Thought: Thought: I need to extract useful information from one of the results to confirm the size, industry, and revenue of Clearbit. I will check the most relevant link from the results regarding company information.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://growjo.com/company/Clearbit\"}"
# ## Tool Output:
#
# Clearbit: Revenue, Competitors, Alternatives
#  $17M Total Funding 127 Number of Employees $17.8M Revenue (est) -16% Employee Growth % N/A Valuation N/A Accelerator Clearbit News 2022-04-19 - SaaS Sales Software Market Growth Prospects, Business ... Clearbit, HootSuite, Ringcentral, Slack, PandaDoc, GoToMeeting, Buffer, Hotjar, Intercom, Hoopla, BuzzSumo, Plecto, Optimizely, Google,... 2022-04-19 - Lead Capture Software Market Size, Scope And Outlook ... Landingi, NetFactor, CallRail, Form Assembly, Lusha Systems, Clearbit, UpLead, NetLine, LeadIQ, Datanyze. Market factors could use prospect information to... 2022-04-17 - Data Management Platform DMP Software Market Size ... Google, Salesforce, Oracle, Clearbit, SAS Institute, OnAudience, OpenPrise, Pegasystems, Dobility, Nielsen Company, Lotame Solutions,... 2021-03-22 - Clearbit Announces Ross Moser as New Chief Executive Officer ing and sales teams. It is important to compare features and pricing of Clearbit competitors  such as ZoomInfo and Lead411 before selecting the appropriate solution. keywords: Analytics,Customer Support,Data Storage,Email,Enterprise Software,Marketing,Marketing Analytics,Software Development,Storage, sales, data, saasil/Phone 7 Brian Hemeryck Head Growth Engineering Reveal Email/Phone 8 Nick Wentz VP Marketing Reveal Email/Phone 9 Rebecca Yang VP Engineering Reveal Email/Phone 10 Julie Beynon Head Analytics Reveal Email/Phone Clearbit Competitors & Alternatives Add Company Competitor Name Revenue Number of Employees Employee Growth Total Funding Valuation # 1 ZoomInfo $664.6M 4193 6% $7M $20.7B # 2 People Data Lab... $16M 114 -8% N/A N/A # 3 6sense $309.1M 1544 13% $426M $5.2B # 4 Datanyze $0M 2 -67% $1.8M N/A # 5 Leadfeeder $15.4M 110 -13% €4.4M N/A # 6 UpLead $0.4M 6 N/A N/A N/A # 7 HubSpot $1180M 10407 6% $100.5M $21.8B # 8 Seamless.AI $70.9M 385 -22% $300K N/A # 9 Apollo $300.7M 1502 88% $183.2M $1.6B # 10 Lead411 $2.1M 21 -12% N/A N/A # 11 HG Insights $114.9M 646 50% $18.3M N/A # 12 Lusha $61.3M 345 3% $245M $1.5B # 13 Cognism $103.3M 581 32% $130M
# SAN FRANCISCO, March 22, 2021 /PRNewswire/ -- Clearbit, an industry leader in Market Intelligence software serving B2B organizations, today announced that Ross Moser has been appointed the company's new Chief Executive Officer and member of its Board of Directors. Moser brings a passion for ta ... 2019-09-07 - Exclusive Research On Mobility Aid Devices Market 2019 ... The latest research Mobility Aid Devices Market 2019-2024. A detailed study accumulated to offer Latest insights about acute features of the ... Other Companies in San Francisco Company Name Revenue Number of Employees Employee Growth Total Funding # 1 Urban Services ... $12.7M 127 -3% N/A # 2 Token $16.5M 127 9% $50M # 3 Datameer $17.8M 127 -5% $139.8M # 4 Gumroad $31.9M 127 21% $16.1M # 5 San Francisco F... $22.9M 127 3% N/A Clearbit Funding Date Amount Round Lead Investors Reference 2015-03-09 $ 2.0M Undisclosed SV Angel Article 2019-03-21 $ 15.0M Undisclosed Zetta Ventures Article © 2025 Growjo All right reserved Cities Atlanta Austin Baltimore Bangalore Berlin Boston Boulder Charlotte Chicago Cleveland Dallas Denver Detroit Dublin East Bay Houston Jacksonville Kansas City Las Vegas London Los Angeles Miami Minneapolis Nashville New York City Orange County Orlando Paris Philadelphia Phoenix Pittsburgh Portland Raleigh Durham Salt Lake City San Antonio San Diego San Francisco Santa Barbara Seattle Silicon Valley Singapore St Louis Stockholm Sydney Tampa Tel Aviv Toronto Vancouver Washington DC States AZ CA CO FL GA ID IL MA MI MN NY OH OR PA TN TX UT WA Industries AdTech Analytics BioTech Cannabis DevOps Digital Health EdTech Fintech Martech Real Estate Tech Services Growjo Directory What is ZoomInfo? Best Sales Lead Database Terms & conditions Privacy Policy Do Not Sell Contact Us About our Data
# 2025-01-02 17:42:29,491 - 8559460928 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Lead Scorer and Validator
# ## Final Answer:
# {
#   "personal_info": {
#     "name": "João Moura",
#     "job_title": "Director of Engineering",
#     "role_relevance": 8,
#     "professional_background": "João Moura has extensive experience in leading engineering teams, previously worked as a Senior Engineering Manager at Clearbit, and has founding experience with CrewAI, focusing on AI and data enrichment."
#   },
#   "company_info": {
#     "company_name": "Clearbit",
#     "industry": "Business/Productivity Software",
#     "company_size": 127,
#     "revenue": 17.8,
#     "market_presence": 8
#   },
#   "lead_score": {
#     "score": 88,
#     "scoring_criteria": [
#       "Role Relevance: 8 (Director of Engineering responsible for AI implementation)",
#       "Company Size: 7 (Medium-sized company with around 127 employees)",
#       "Market Presence: 8 (Significant presence in data enrichment sector)",
#       "Cultural Fit: 8 (Alignment in innovation and data-driven decision-making)"
#     ],
#     "validation_notes": "All information aggregated and verified from multiple sources; lead score calculated with established criteria."
#   }
# }
#
#
# # Agent: Email Content Writer
# ## Task: Craft a highly personalized email using the lead's name, job title, company information, and any relevant personal or company achievements. The email should speak directly to the lead's interests and the needs of their company. This is not as cold outreach as it is a follow up to a lead form, so keep it short and to the point. Don't use any salutations or closing remarks, nor too complex sentences.
# Our Company and Product: - Company Name: CrewAI - Product: Multi-Agent Orchestration Platform - ICP: Enterprise companies looking into Agentic automation. - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
# Use the following information: Personal Info: {'name': 'João Moura', 'job_title': 'Director of Engineering', 'role_relevance': 8, 'professional_background': 'João Moura has extensive experience in leading engineering teams, previously worked as a Senior Engineering Manager at Clearbit, and has founding experience with CrewAI, focusing on AI and data enrichment.'} Company Info: {'company_name': 'Clearbit', 'industry': 'Business/Productivity Software', 'company_size': 127, 'revenue': 17.8, 'market_presence': 8} Lead Score: {'score': 88, 'scoring_criteria': ['Role Relevance: 8 (Director of Engineering responsible for AI implementation)', 'Company Size: 7 (Medium-sized company with around 127 employees)', 'Market Presence: 8 (Significant presence in data enrichment sector)', 'Cultural Fit: 8 (Alignment in innovation and data-driven decision-making)'], 'validation_notes': 'All information aggregated and verified from multiple sources; lead score calculated with established criteria.'}
#
#
#
# # Agent: Email Content Writer
# ## Final Answer:
# João, with your extensive background in leading engineering teams at Clearbit, I see a strong alignment between your focus on AI implementation and CrewAI's multi-agent orchestration platform. As you navigate the complexities of agentic automation in the business productivity sector, our platform can streamline your operations and enhance your team's efficiency. With Clearbit’s notable presence in data enrichment, imagine how orchestrating AI agents could transform your processes and boost engagement across your projects, driving innovative outcomes. Let's explore how CrewAI can empower your engineering initiatives to meet Clearbit’s evolving needs.
#
#
# # Agent: Engagement Optimization Specialist
# ## Task: Review the personalized email draft and optimize it with strong CTAs and engagement hooks. Keep in mind they reached out and filled a lead form. Keep it short and to the point. Don't use any salutations or closing remarks, nor too complex sentences. Ensure the email encourages the lead to schedule a meeting or take another desired action immediately.
# Our Company and Product: - Company Name: CrewAI - Product: Multi-Agent Orchestration Platform - ICP: Enterprise companies looking into Agentic automation. - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
#
#
# # Agent: Engagement Optimization Specialist
# ## Final Answer:
# João,
#
# Leverage CrewAI to unlock the full potential of agentic automation in your operations. Our multi-agent orchestration platform is designed to enhance efficiencies and drive innovation. Picture your team achieving unprecedented productivity levels by integrating AI agents seamlessly into your workflows.
#
# Ready to see how this works? Schedule a demo today and witness the difference firsthand.
#
# [Book a Demo Now]
#
# Curious about specific use cases tailored to Clearbit’s unique challenges? Let’s discuss how CrewAI can streamline your projects.
#
# [Let’s Chat]
#
# Don’t miss out on transforming your engineering initiatives—take action now!

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([flow.state["score_crews_results"][0].token_usage.dict()])

# Calculate total costs
costs = 0.150 * df_usage_metrics['total_tokens'].sum() / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Display the DataFrame
df_usage_metrics
# Out:
# Total costs: $0.0029
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0         19163          17004                  7296               2159
#
#    successful_requests
# 0                   10

# %%
import pandas as pd

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([emails[0].token_usage.dict()])

# Calculate total costs
costs = 0.150 * df_usage_metrics['total_tokens'].sum() / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Display the DataFrame
df_usage_metrics
# Out:
# Total costs: $0.0002
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          1280           1023                     0                257
#
#    successful_requests
# 0                    2

# %% [markdown]
# ## Inspecting Results

# %%
scores = flow.state["score_crews_results"]

# %%
import pandas as pd
from IPython.display import display, HTML

lead_scoring_result = scores[0].pydantic

# Create a dictionary with the nested structure flattened
data = {
    'Name': lead_scoring_result.personal_info.name,
    'Job Title': lead_scoring_result.personal_info.job_title,
    'Role Relevance': lead_scoring_result.personal_info.role_relevance,
    'Professional Background': lead_scoring_result.personal_info.professional_background,
    'Company Name': lead_scoring_result.company_info.company_name,
    'Industry': lead_scoring_result.company_info.industry,
    'Company Size': lead_scoring_result.company_info.company_size,
    'Revenue': lead_scoring_result.company_info.revenue,
    'Market Presence': lead_scoring_result.company_info.market_presence,
    'Lead Score': lead_scoring_result.lead_score.score,
    'Scoring Criteria': ', '.join(lead_scoring_result.lead_score.scoring_criteria),
    'Validation Notes': lead_scoring_result.lead_score.validation_notes
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data, orient='index', columns=['Value'])

# Reset the index to turn the original column names into a regular column
df = df.reset_index()

# Rename the index column to 'Attribute'
df = df.rename(columns={'index': 'Attribute'})

# Create HTML table with bold attributes and left-aligned values
html_table = df.style.set_properties(**{'text-align': 'left'}) \
                     .format({'Attribute': lambda x: f'<b>{x}</b>'}) \
                     .hide(axis='index') \
                     .to_html()

# Display the styled HTML table
display(HTML(html_table))
# Out:
# <style type="text/css">
# #T_61c0c_row0_col0, #T_61c0c_row0_col1, #T_61c0c_row1_col0, #T_61c0c_row1_col1, #T_61c0c_row2_col0, #T_61c0c_row2_col1, #T_61c0c_row3_col0, #T_61c0c_row3_col1, #T_61c0c_row4_col0, #T_61c0c_row4_col1, #T_61c0c_row5_col0, #T_61c0c_row5_col1, #T_61c0c_row6_col0, #T_61c0c_row6_col1, #T_61c0c_row7_col0, #T_61c0c_row7_col1, #T_61c0c_row8_col0, #T_61c0c_row8_col1, #T_61c0c_row9_col0, #T_61c0c_row9_col1, #T_61c0c_row10_col0, #T_61c0c_row10_col1, #T_61c0c_row11_col0, #T_61c0c_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_61c0c">
#   <thead>
#     <tr>
#       <th id="T_61c0c_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_61c0c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_61c0c_row0_col0" class="data row0 col0" ><b>Name</b></td>
#       <td id="T_61c0c_row0_col1" class="data row0 col1" >João Moura</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row1_col0" class="data row1 col0" ><b>Job Title</b></td>
#       <td id="T_61c0c_row1_col1" class="data row1 col1" >Director of Engineering</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row2_col0" class="data row2 col0" ><b>Role Relevance</b></td>
#       <td id="T_61c0c_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row3_col0" class="data row3 col0" ><b>Professional Background</b></td>
#       <td id="T_61c0c_row3_col1" class="data row3 col1" >João Moura has extensive experience in leading engineering teams, previously worked as a Senior Engineering Manager at Clearbit, and has founding experience with CrewAI, focusing on AI and data enrichment.</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row4_col0" class="data row4 col0" ><b>Company Name</b></td>
#       <td id="T_61c0c_row4_col1" class="data row4 col1" >Clearbit</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row5_col0" class="data row5 col0" ><b>Industry</b></td>
#       <td id="T_61c0c_row5_col1" class="data row5 col1" >Business/Productivity Software</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row6_col0" class="data row6 col0" ><b>Company Size</b></td>
#       <td id="T_61c0c_row6_col1" class="data row6 col1" >127</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row7_col0" class="data row7 col0" ><b>Revenue</b></td>
#       <td id="T_61c0c_row7_col1" class="data row7 col1" >17.800000</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row8_col0" class="data row8 col0" ><b>Market Presence</b></td>
#       <td id="T_61c0c_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row9_col0" class="data row9 col0" ><b>Lead Score</b></td>
#       <td id="T_61c0c_row9_col1" class="data row9 col1" >88</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row10_col0" class="data row10 col0" ><b>Scoring Criteria</b></td>
#       <td id="T_61c0c_row10_col1" class="data row10 col1" >Role Relevance: 8 (Director of Engineering responsible for AI implementation), Company Size: 7 (Medium-sized company with around 127 employees), Market Presence: 8 (Significant presence in data enrichment sector), Cultural Fit: 8 (Alignment in innovation and data-driven decision-making)</td>
#     </tr>
#     <tr>
#       <td id="T_61c0c_row11_col0" class="data row11 col0" ><b>Validation Notes</b></td>
#       <td id="T_61c0c_row11_col1" class="data row11 col1" >All information aggregated and verified from multiple sources; lead score calculated with established criteria.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results

# %%
import textwrap

result_text = emails[0].raw
wrapped_text = textwrap.fill(result_text, width=80)
print(wrapped_text)
# Out:
# João,   Leverage CrewAI to unlock the full potential of agentic automation in
# your operations. Our multi-agent orchestration platform is designed to enhance
# efficiencies and drive innovation. Picture your team achieving unprecedented
# productivity levels by integrating AI agents seamlessly into your workflows.
# Ready to see how this works? Schedule a demo today and witness the difference
# firsthand.    [Book a Demo Now]    Curious about specific use cases tailored to
# Clearbit’s unique challenges? Let’s discuss how CrewAI can streamline your
# projects.    [Let’s Chat]    Don’t miss out on transforming your engineering
# initiatives—take action now!

# %% [markdown]
# ## How Complex Can it Get?

# %%
# !{sys.executable} -m pip install --upgrade crewai
# Out:
# Requirement already satisfied: crewai in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (0.86.0)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (4.7.2)
# Requirement already satisfied: chromadb>=0.5.18 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (8.1.7)
# Requirement already satisfied: crewai-tools>=0.17.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.17.0)
# Requirement already satisfied: instructor>=1.3.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.34.0)
# Requirement already satisfied: jsonref>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.56.3)
# Requirement already satisfied: openai>=1.13.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.58.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.11.4)
# Requirement already satisfied: pydantic>=2.4.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (2.9.2)
# Requirement already satisfied: python-dotenv>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.0.1)
# Requirement already satisfied: pyvis>=0.3.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: tomli-w>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai) (0.5.13)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (3.11.11)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.2.2)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.115.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (0.31.1)
# Requirement already satisfied: numpy>=1.22.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from chromadb>=0.5.18->crewai) (13.9.2)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (0.1.125)
# Requirement already satisfied: lancedb>=0.5.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (0.17.0)
# Requirement already satisfied: pyright>=1.1.350 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (1.1.391)
# Requirement already satisfied: pytest>=8.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (8.3.4)
# Requirement already satisfied: pytube>=15.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (15.0.0)
# Requirement already satisfied: selenium>=4.18.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from crewai-tools>=0.17.0->crewai) (4.27.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (3.1.4)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.8.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (2.23.4)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.50b0)
# Requirement already satisfied: pdfminer.six==20231228 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (8.26.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (3.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.8)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->crewai-tools>=0.17.0->crewai) (2.6)
# Requirement already satisfied: packaging>=19.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.18->crewai) (24.1)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.18->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.14.0)
# Requirement already satisfied: cohere<6.0,>=5.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (5.13.4)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.75.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.13)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.13)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.2.14)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.1.147)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.29 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.1.36)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.0.36)
# Requirement already satisfied: starlette<0.41.0,>=0.37.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.5.18->crewai) (0.39.2)
# Requirement already satisfied: certifi in /opt/homebrew/opt/certifi/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.5.18->crewai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.5.18->crewai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.18->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai) (3.21.0)
# Requirement already satisfied: decorator in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: stack-data in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.20.0)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (0.9)
# Requirement already satisfied: deprecation in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools>=0.17.0->crewai) (2.1.0)
# Requirement already satisfied: pylance==0.20.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools>=0.17.0->crewai) (0.20.0)
# Requirement already satisfied: pyarrow>=14 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pylance==0.20.0->lancedb>=0.5.4->crewai-tools>=0.17.0->crewai) (18.1.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (24.12.23)
# Requirement already satisfied: sympy in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (1.13.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (0.50b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.18->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.18->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.18->crewai) (2.2.1)
# Requirement already satisfied: nodeenv>=1.6.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pyright>=1.1.350->crewai-tools>=0.17.0->crewai) (1.9.1)
# Requirement already satisfied: iniconfig in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools>=0.17.0->crewai) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pytest>=8.0.0->crewai-tools>=0.17.0->crewai) (1.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.18->crewai) (3.0.0)
# Requirement already satisfied: trio~=0.17 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (0.28.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (0.11.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (0.25.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.5.18->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai) (12.0)
# Requirement already satisfied: Mako in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.3.8)
# Requirement already satisfied: pycparser in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.32.0.20241016)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (4.9)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.24.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.0.6)
# Requirement already satisfied: filelock in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.18->crewai) (2024.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.4)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.7.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.18->crewai) (0.1.2)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.12.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: sortedcontainers in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (2.4.0)
# Requirement already satisfied: outcome in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools>=0.17.0->crewai) (1.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.9.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.68.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.33)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2024.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.18->crewai) (0.6.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.68.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (2.10.1)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (74.0.0)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (4.1.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai) (4.0.0)

# %%
from crewai import Flow
from crewai.flow.flow import listen, start, and_, or_, router

class SalesPipeline(Flow):
    
  @start()
  def fetch_leads(self):
    # Pull our leads from the database
    # This is a mock, in a real-world scenario, this is where you would
    # fetch leads from a database
    leads = [
      {
        "lead_data": {
          "name": "João Moura",
          "job_title": "Director of Engineering",
          "company": "Clearbit",
          "email": "joao@clearbit.com",
          "use_case": "Using AI Agent to do better data enrichment."
        },
      },
    ]
    return leads

  @listen(fetch_leads)
  def score_leads(self, leads):
    scores = lead_scoring_crew.kickoff_for_each(leads)
    self.state["score_crews_results"] = scores
    return scores

  @listen(score_leads)
  def store_leads_score(self, scores):
    # Here we would store the scores in the database
    return scores

  @listen(score_leads)
  def filter_leads(self, scores):
    return [score for score in scores if score['lead_score'].score > 70]

  @listen(and_(filter_leads, store_leads_score))
  def log_leads(self, leads):
    print(f"Leads: {leads}")

  """
  @router(filter_leads, paths=["high", "medium", "low"])
  def count_leads(self, scores):
    if len(scores) > 10:
      return 'high'
    elif len(scores) > 5:
      return 'medium'
    else:
      return 'low'
  """

  @router(filter_leads)
  def count_leads(self, scores):
      if len(scores) > 10:
          return "high"
      elif len(scores) > 5:
          return "medium"
      else:
          return "low"

  @listen('high')
  def store_in_salesforce(self, leads):
    return leads

  @listen('medium')
  def send_to_sales_team(self, leads):
    return leads

  @listen('low')
  def write_email(self, leads):
    scored_leads = [lead.to_dict() for lead in leads]
    emails = email_writing_crew.kickoff_for_each(scored_leads)
    return emails

  @listen(write_email)
  def send_email(self, emails):
    # Here we would send the emails to the leads
    return emails

# %% [markdown]
# ## Plotting the Flow

# %%
flow = SalesPipeline()
flow.plot()
# Out:
# Plot saved as crewai_flow.html

# %%
from IPython.display import IFrame

IFrame(src='./crewai_flow_complex.html', width='150%', height=600)
# Out:
#         <iframe
#             width="150%"
#             height="600"
#             src="./crewai_flow_complex.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
