# %% [markdown]
# # LangChain: Q&A over Documents
# An example might be a tool that would allow you to query a product catalog for items of interest.

# %%
import sys
# !{sys.executable} -m pip install --upgrade "langchain[docarray]"
# Out:
# Collecting langchain[docarray]
#   Downloading langchain-0.0.254-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 2.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: async-timeout<5.0.0,>=4.0.0; python_version < "3.11" in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (4.0.2)
# Requirement already satisfied, skipping upgrade: tenacity<9.0.0,>=8.1.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (8.2.2)
# Requirement already satisfied, skipping upgrade: numpy<2,>=1 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (1.24.3)
# Requirement already satisfied, skipping upgrade: aiohttp<4.0.0,>=3.8.3 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (3.8.5)
# Requirement already satisfied, skipping upgrade: langsmith<0.1.0,>=0.0.11 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (0.0.16)
# Requirement already satisfied, skipping upgrade: numexpr<3.0.0,>=2.8.4 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (2.8.4)
# Requirement already satisfied, skipping upgrade: pydantic<2,>=1 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (1.10.12)
# Requirement already satisfied, skipping upgrade: dataclasses-json<0.6.0,>=0.5.7 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (0.5.14)
# Requirement already satisfied, skipping upgrade: PyYAML>=5.3 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (6.0.1)
# Requirement already satisfied, skipping upgrade: SQLAlchemy<3,>=1.4 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (2.0.19)
# Requirement already satisfied, skipping upgrade: openapi-schema-pydantic<2.0,>=1.2 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (1.2.4)
# Requirement already satisfied, skipping upgrade: requests<3,>=2 in /home/yuto/research/env3/lib/python3.8/site-packages (from langchain[docarray]) (2.31.0)
# Collecting docarray[hnswlib]<0.33.0,>=0.32.0; extra == "docarray" or extra == "all"
#   Downloading docarray-0.32.1-py3-none-any.whl (215 kB)
#      |████████████████████████████████| 215 kB 43.0 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: charset-normalizer<4.0,>=2.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (3.2.0)
# Requirement already satisfied, skipping upgrade: frozenlist>=1.1.1 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.4.0)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (6.0.4)
# Requirement already satisfied, skipping upgrade: aiosignal>=1.1.2 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.3.1)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.9.2)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (23.1.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.2.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from pydantic<2,>=1->langchain[docarray]) (4.5.0)
# Requirement already satisfied, skipping upgrade: typing-inspect<1,>=0.4.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (0.9.0)
# Requirement already satisfied, skipping upgrade: marshmallow<4.0.0,>=3.18.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (3.20.1)
# Requirement already satisfied, skipping upgrade: greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))) in /home/yuto/research/env3/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain[docarray]) (2.0.2)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /home/yuto/research/env3/lib/python3.8/site-packages (from requests<3,>=2->langchain[docarray]) (1.26.16)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/yuto/research/env3/lib/python3.8/site-packages (from requests<3,>=2->langchain[docarray]) (2023.5.7)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /home/yuto/research/env3/lib/python3.8/site-packages (from requests<3,>=2->langchain[docarray]) (3.4)
# Collecting types-requests>=2.28.11.6
#   Downloading types_requests-2.31.0.2-py3-none-any.whl (14 kB)
# Collecting orjson>=3.8.2
#   Downloading orjson-3.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#      |████████████████████████████████| 140 kB 43.2 MB/s eta 0:00:01
# Collecting rich>=13.1.0
#   Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 43.5 MB/s eta 0:00:01
# Collecting hnswlib>=0.6.2; extra == "hnswlib"
#   Downloading hnswlib-0.7.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied, skipping upgrade: protobuf>=3.19.0; extra == "proto" or extra == "hnswlib" or extra == "full" in /home/yuto/research/env3/lib/python3.8/site-packages (from docarray[hnswlib]<0.33.0,>=0.32.0; extra == "docarray" or extra == "all"->langchain[docarray]) (4.23.4)
# Requirement already satisfied, skipping upgrade: mypy-extensions>=0.3.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (1.0.0)
# Requirement already satisfied, skipping upgrade: packaging>=17.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (23.1)
# Collecting types-urllib3
#   Downloading types_urllib3-1.26.25.14-py3-none-any.whl (15 kB)
# Requirement already satisfied, skipping upgrade: pygments<3.0.0,>=2.13.0 in /home/yuto/research/env3/lib/python3.8/site-packages (from rich>=13.1.0->docarray[hnswlib]<0.33.0,>=0.32.0; extra == "docarray" or extra == "all"->langchain[docarray]) (2.15.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 16.7 MB/s eta 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (PEP 517) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.7.0-cp38-cp38-linux_x86_64.whl size=2164075 sha256=f811ebf0414b80e11a38949c132623e87f1a2c553ce3fcf43b7cd2ec082547d4
#   Stored in directory: /home/yuto/.cache/pip/wheels/93/0d/13/bbdc55499ef621f8f722fad91050fbb1380709f0c62fa7719a
# Successfully built hnswlib
# Installing collected packages: types-urllib3, types-requests, orjson, mdurl, markdown-it-py, rich, hnswlib, docarray, langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.249
#     Uninstalling langchain-0.0.249:
#       Successfully uninstalled langchain-0.0.249
# Successfully installed docarray-0.32.1 hnswlib-0.7.0 langchain-0.0.254 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.9.3 rich-13.5.2 types-requests-2.31.0.2 types-urllib3-1.26.25.14

# %%
#pip install --upgrade langchain

# %%
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import CSVLoader
from langchain.vectorstores import DocArrayInMemorySearch
from IPython.display import display, Markdown

# %%
file = 'OutdoorClothingCatalog_1000.csv'
loader = CSVLoader(file_path=file)

# %%
from langchain.indexes import VectorstoreIndexCreator

# %%
#pip install docarray

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch
).from_loaders([loader])
# Out:
# 2023-08-07 04:18:36.245863: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 04:18:36.913441: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
query ="Please list all your shirts with sun protection \
in a table in markdown and summarize each one."

# %%
response = index.query(query)

# %%
display(Markdown(response))
# Out:
# | Name | Description |
# | --- | --- |
# | Men's Tropical Plaid Short-Sleeve Shirt | UPF 50+ rated, 100% polyester, wrinkle-resistant, front and back cape venting, two front bellows pockets |
# | Men's Plaid Tropic Shirt, Short-Sleeve | UPF 50+ rated, 52% polyester and 48% nylon, machine washable and dryable, front and back cape venting, two front bellows pockets |
# | Men's TropicVibe Shirt, Short-Sleeve | UPF 50+ rated, 71% Nylon, 29% Polyester, 100% Polyester knit mesh, wrinkle resistant, front and back cape venting, two front bellows pockets |
# | Sun Shield Shirt by | UPF 50+ rated, 78% nylon, 22% Lycra Xtra Life fiber, wicks moisture, fits comfortably over swimsuit, abrasion resistant |
#
# All four shirts provide UPF 50+ sun protection, blocking 98% of the sun's harmful rays. The Men's Tropical Plaid Short-Sleeve Shirt is made of 100% polyester and is wrinkle-resistant. The Men's Plaid Trop

# %%
loader = CSVLoader(file_path=file)

# %%
docs = loader.load()

# %%
docs[0]
# Out:
# Document(page_content=": 0\nname: Women's Campside Oxfords\ndescription: This ultracomfortable lace-to-toe Oxford boasts a super-soft canvas, thick cushioning, and quality construction for a broken-in feel from the first time you put them on. \n\nSize & Fit: Order regular shoe size. For half sizes not offered, order up to next whole size. \n\nSpecs: Approx. weight: 1 lb.1 oz. per pair. \n\nConstruction: Soft canvas material for a broken-in feel and look. Comfortable EVA innersole with Cleansport NXT® antimicrobial odor control. Vintage hunt, fish and camping motif on innersole. Moderate arch contour of innersole. EVA foam midsole for cushioning and support. Chain-tread-inspired molded rubber outsole with modified chain-tread pattern. Imported. \n\nQuestions? Please contact us for any inquiries.", metadata={'source': 'OutdoorClothingCatalog_1000.csv', 'row': 0})

# %%
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# %%
embed = embeddings.embed_query("Hi my name is Harrison")

# %%
print(len(embed))
# Out:
# 1536

# %%
print(embed[:5])
# Out:
# [-0.021913960576057434, 0.006774206645786762, -0.018190348520874977, -0.039148248732089996, -0.014089343138039112]

# %%
db = DocArrayInMemorySearch.from_documents(
    docs, 
    embeddings
)

# %%
query = "Please suggest a shirt with sunblocking"

# %%
docs = db.similarity_search(query)

# %%
len(docs)
# Out:
# 4

# %%
docs[0]
# Out:
# Document(page_content=': 255\nname: Sun Shield Shirt by\ndescription: "Block the sun, not the fun – our high-performance sun shirt is guaranteed to protect from harmful UV rays. \n\nSize & Fit: Slightly Fitted: Softly shapes the body. Falls at hip.\n\nFabric & Care: 78% nylon, 22% Lycra Xtra Life fiber. UPF 50+ rated – the highest rated sun protection possible. Handwash, line dry.\n\nAdditional Features: Wicks moisture for quick-drying comfort. Fits comfortably over your favorite swimsuit. Abrasion resistant for season after season of wear. Imported.\n\nSun Protection That Won\'t Wear Off\nOur high-performance fabric provides SPF 50+ sun protection, blocking 98% of the sun\'s harmful rays. This fabric is recommended by The Skin Cancer Foundation as an effective UV protectant.', metadata={'source': 'OutdoorClothingCatalog_1000.csv', 'row': 255})

# %%
retriever = db.as_retriever()

# %%
llm = ChatOpenAI(temperature = 0.0)

# %%
qdocs = "".join([docs[i].page_content for i in range(len(docs))])

# %%
response = llm.call_as_llm(f"{qdocs} Question: Please list all your \
shirts with sun protection in a table in markdown and summarize each one.")

# %% [markdown]
# # Something wrong!
# - No results returned.
# - Why keep restoring connections to the notebook???

# %%
display(Markdown(response))
# Out:
# | Shirt Name                        | Description

# %%
qa_stuff = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", 
    retriever=retriever, 
    verbose=True
)

# %%
query =  "Please list all your shirts with sun protection in a table \
in markdown and summarize each one."

# %%
response = qa_stuff.run(query)
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.

# %%
display(Markdown(response))
# Out:
# | Shirt ID | Name                                 | Description

# %%
response = index.query(query, llm=llm)

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch,
    embedding=embeddings,
).from_loaders([loader])
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIError: OpenAI API returned an empty embedding.
