# %% [markdown]
# <table align="left">
#   <tr>
#  <td><img src="icecreamtruck.jpeg" alt="Ice Cream Truck" width="150"/></td>
#  <td align="left"><h1>Lesson 2: Introduction to Code Agents</h1></td>

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code>  file:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %%
# Warning control
import warnings

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=RuntimeWarning)

import os
import io
import IPython.display
from PIL import Image
import base64

from dotenv import load_dotenv, find_dotenv

_ = load_dotenv() # read local .env file

from huggingface_hub import login

login(os.environ['HF_API_KEY'])

# %%
import pandas as pd

suppliers_data = {
    "name": [
        "Montreal Ice Cream Co",
        "Brain Freeze Brothers",
        "Toronto Gelato Ltd",
        "Buffalo Scoops",
        "Vermont Creamery",
    ],
    "location": [
        "Montreal, QC",
        "Burlington, VT",
        "Toronto, ON",
        "Buffalo, NY",
        "Portland, ME",
    ],
    "distance_km": [120, 85, 400, 220, 280],
    "canadian": [True, False, True, False, False],
    "price_per_liter": [1.95, 1.91, 1.82, 2.43, 2.33],
    "tasting_fee": [0, 12.50, 30.14, 42.00, 0.20],
}

data_description = """Suppliers have an additional tasting fee: that is a fixed fee applied to each order to taste the ice cream."""
suppliers_df = pd.DataFrame(suppliers_data)
suppliers_df
# Out:
#                     name        location  distance_km  canadian  \
# 0  Montreal Ice Cream Co    Montreal, QC          120      True
# 1  Brain Freeze Brothers  Burlington, VT           85     False
# 2     Toronto Gelato Ltd     Toronto, ON          400      True
# 3         Buffalo Scoops     Buffalo, NY          220     False
# 4       Vermont Creamery    Portland, ME          280     False
#
#    price_per_liter  tasting_fee
# 0             1.95         0.00
# 1             1.91        12.50
# 2             1.82        30.14
# 3             2.43        42.00
# 4             2.33         0.20

# %% [markdown]
# ## Setup tools

# %%
import numpy as np

def calculate_daily_supplier_price(row):
    order_volume = 30

    # Calculate raw product cost
    product_cost = row["price_per_liter"] * order_volume

    # Calculate transport cost
    trucks_needed = np.ceil(order_volume / 300)
    cost_per_km = 1.20
    transport_cost = row["distance_km"] * cost_per_km * trucks_needed

    # Calculate tariffs for ice cream imported from Canada
    tariff = product_cost * np.pi / 50 * row["canadian"]

    # Get total cost
    total_cost = product_cost + transport_cost + tariff + row["tasting_fee"]
    return total_cost

suppliers_df["daily_price"] = suppliers_df.apply(calculate_daily_supplier_price, axis=1)
display(suppliers_df)

# Let's remove this column now.
suppliers_df = suppliers_df.drop("daily_price", axis=1)
# Out:
#                     name        location  distance_km  canadian  \
# 0  Montreal Ice Cream Co    Montreal, QC          120      True
# 1  Brain Freeze Brothers  Burlington, VT           85     False
# 2     Toronto Gelato Ltd     Toronto, ON          400      True
# 3         Buffalo Scoops     Buffalo, NY          220     False
# 4       Vermont Creamery    Portland, ME          280     False
#
#    price_per_liter  tasting_fee  daily_price
# 0             1.95         0.00   206.175663
# 1             1.91        12.50   171.800000
# 2             1.82        30.14   568.170619
# 3             2.43        42.00   378.900000
# 4             2.33         0.20   406.100000

# %%
# First we make a few tools
from smolagents import tool

@tool
def calculate_transport_cost(distance_km: float, order_volume: float) -> float:
    """
    Calculate transportation cost based on distance and order size.
    Refrigerated transport costs $1.2 per kilometer and has a capacity of 300 liters.

    Args:
        distance_km: the distance in kilometers
        order_volume: the order volume in liters
    """
    trucks_needed = np.ceil(order_volume / 300)
    cost_per_km = 1.20
    return distance_km * cost_per_km * trucks_needed


@tool
def calculate_tariff(base_cost: float, is_canadian: bool) -> float:
    """
    Calculates tariff for Canadian imports. Returns the tariff only, not the total cost.
    Assumes tariff on dairy products from Canada is worth 2 * pi / 100, approx 6.2%

    Args:
        base_cost: the base cost of goods, not including transportation cost.
        is_canadian: wether the import is from Canada.
    """
    if is_canadian:
        return base_cost * np.pi / 50
    return 0

# %%
calculate_transport_cost.description
# Out:
# 'Calculate transportation cost based on distance and order size.\nRefrigerated transport costs $1.2 per kilometer and has a capacity of 300 liters.'

# %% [markdown]
# ## Setup the Model

# %%
import helper
openai_api_key = helper.get_openai_api_key()

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel, VisitWebpageTool, ToolCallingAgent, ToolCollection

model = LiteLLMModel(
    #model_id="openai/gpt-4",  
    model_id="openai/gpt-4o-mini",  
    max_tokens=2048
)

#agent = CodeAgent(tools=[DuckDuckGoSearchTool(), VisitWebpageTool()], model=model)

# %% [markdown]
# ### !!! FAIL WITH QWEN MODEL, USE OPENAI INSTEAD !!!

# %%
"""
from smolagents import HfApiModel, CodeAgent
from helper import get_huggingface_token

model = HfApiModel(
    "Qwen/Qwen2.5-72B-Instruct",
    provider="together", # Choose a specific inference provider
    max_tokens=4096,
    temperature=0.1
)
"""
# Out:
# '\nfrom smolagents import HfApiModel, CodeAgent\nfrom helper import get_huggingface_token\n\nmodel = HfApiModel(\n    "Qwen/Qwen2.5-72B-Instruct",\n    provider="together", # Choose a specific inference provider\n    max_tokens=4096,\n    temperature=0.1\n)\n'

# %% [markdown]
# ## Setup the Code Agent

# %%
agent = CodeAgent(
    model=model,
    tools=[calculate_transport_cost, calculate_tariff],
    max_steps=10,
    additional_authorized_imports=["pandas", "numpy"],
    verbosity_level=2
)
agent.logger.console.width=66

# %%
agent.run(
    """Can you get me the transportation cost for 50 liters
    of ice cream over 10 kilometers?"""
)
# Out:
# ╭─────────────────────────── New run ────────────────────────────╮
# │                                                                │
# │ Can you get me the transportation cost for 50 liters           │
# │     of ice cream over 10 kilometers?                           │
# │                                                                │
# ╰─ LiteLLMModel - openai/gpt-4o-mini ────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ───────────────────────────────────────
# Thought: To calculate the transportation cost, I will use the
# `calculate_transport_cost` function. The distance is 10
# kilometers, and the order volume is 50 liters of ice cream. I will
# directly call the function with these parameters.
# <code>
# transportation_cost = calculate_transport_cost(distance_km=10,
# order_volume=50)
# print(transportation_cost)
# </code>
#  ─ Executing parsed code: ───────────────────────────────────────
#   transportation_cost = calculate_transport_cost(distance_km=10,
#   order_volume=50)
#   print(transportation_cost)
#  ────────────────────────────────────────────────────────────────
# Execution logs:
# 12.0
#
# Out: None
# [Step 1: Duration 3.09 seconds| Input tokens: 2,080 | Output
# tokens: 81]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ───────────────────────────────────────
# Thought: The transportation cost for 50 liters of ice cream over
# 10 kilometers is $12. I will now provide this as the final answer.
# <code>
# final_answer(12.0)
# </code>
#  ─ Executing parsed code: ───────────────────────────────────────
#   final_answer(12.0)
#  ────────────────────────────────────────────────────────────────
# Out - Final answer: 12.0
# [Step 2: Duration 2.20 seconds| Input tokens: 4,322 | Output
# tokens: 124]
# 12.0

# %% [markdown]
# ## Give the agent detailed instructions

# %%
task = """Here is a dataframe of different ice cream suppliers.
Could you give me a comparative table (as a dataframe) of the total
daily price for getting daily ice cream delivery from each of them,
given that we need exactly 30 liters of ice cream per day? Take
into account transportation cost and tariffs.
"""
agent.logger.level = 1 # Lower verbosity level
agent.run(
    task,
    additional_args={"suppliers_data": suppliers_df, "data_description": data_description},
)
# Out:
# ╭─────────────────────────── New run ────────────────────────────╮
# │                                                                │
# │ Here is a dataframe of different ice cream suppliers.          │
# │ Could you give me a comparative table (as a dataframe) of the  │
# │ total                                                          │
# │ daily price for getting daily ice cream delivery from each of  │
# │ them,                                                          │
# │ given that we need exactly 30 liters of ice cream per day?     │
# │ Take                                                           │
# │ into account transportation cost and tariffs.                  │
# │                                                                │
# │ You have been provided with these additional arguments, that   │
# │ you can access using the keys as variables in your python      │
# │ code:                                                          │
# │ {'suppliers_data':                     name        location    │
# │ distance_km  canadian  \                                       │
# │ 0  Montreal Ice Cream Co    Montreal, QC          120          │
# │ True                                                           │
# │ 1  Brain Freeze Brothers  Burlington, VT           85          │
# │ False                                                          │
# │ 2     Toronto Gelato Ltd     Toronto, ON          400          │
# │ True                                                           │
# │ 3         Buffalo Scoops     Buffalo, NY          220          │
# │ False                                                          │
# │ 4       Vermont Creamery    Portland, ME          280          │
# │ False                                                          │
# │                                                                │
# │    price_per_liter  tasting_fee                                │
# │ 0             1.95         0.00                                │
# │ 1             1.91        12.50                                │
# │ 2             1.82        30.14                                │
# │ 3             2.43        42.00                                │
# │ 4             2.33         0.20  , 'data_description':         │
# │ 'Suppliers have an additional tasting fee: that is a fixed fee │
# │ applied to each order to taste the ice cream.'}.               │
# │                                                                │
# ╰─ LiteLLMModel - openai/gpt-4o-mini ────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ───────────────────────────────────────
#   import pandas as pd
#
#   # Given supplier data
#   suppliers_data = pd.DataFrame({
#       'name': ['Montreal Ice Cream Co', 'Brain Freeze Brothers',
#   'Toronto Gelato Ltd',
#                'Buffalo Scoops', 'Vermont Creamery'],
#       'location': ['Montreal, QC', 'Burlington, VT', 'Toronto,
#   ON',
#                    'Buffalo, NY', 'Portland, ME'],
#       'distance_km': [120, 85, 400, 220, 280],
#       'canadian': [True, False, True, False, False],
#       'price_per_liter': [1.95, 1.91, 1.82, 2.43, 2.33],
#       'tasting_fee': [0.00, 12.50, 30.14, 42.00, 0.20]
#   })
#
#   order_volume = 30
#
#   # Calculating the total costs for each supplier
#   def compute_total_costs(suppliers_data, order_volume):
#       total_costs = []
#
#       for index, row in suppliers_data.iterrows():
#           distance_km = row['distance_km']
#           price_per_liter = row['price_per_liter']
#           tasting_fee = row['tasting_fee']
#           is_canadian = row['canadian']
#
#           # Calculate transportation cost
#           transport_cost = calculate_transport_cost(distance_km,
#   order_volume)
#
#           # Calculate base ice cream cost
#           ice_cream_cost = price_per_liter * order_volume
#
#           # Calculate tariff
#           tariff = calculate_tariff(ice_cream_cost, is_canadian)
#
#           # Total cost
#           total_cost = ice_cream_cost + transport_cost + tariff
#   + tasting_fee
#           total_costs.append({
#               'name': row['name'],
#               'total_daily_cost': total_cost
#           })
#
#       return pd.DataFrame(total_costs)
#
#   total_costs_df = compute_total_costs(suppliers_data,
#   order_volume)
#   print(total_costs_df)
#  ────────────────────────────────────────────────────────────────
# Execution logs:
#                     name  total_daily_cost
# 0  Montreal Ice Cream Co        206.175663
# 1  Brain Freeze Brothers        171.800000
# 2     Toronto Gelato Ltd        568.170619
# 3         Buffalo Scoops        378.900000
# 4       Vermont Creamery        406.100000
#
# Out: None
# [Step 1: Duration 13.51 seconds| Input tokens: 2,337 | Output
# tokens: 559]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ───────────────────────────────────────
#   final_answer(total_costs_df)
#  ────────────────────────────────────────────────────────────────
# Out - Final answer:                     name  total_daily_cost
# 0  Montreal Ice Cream Co        206.175663
# 1  Brain Freeze Brothers        171.800000
# 2     Toronto Gelato Ltd        568.170619
# 3         Buffalo Scoops        378.900000
# 4       Vermont Creamery        406.100000
# [Step 2: Duration 2.72 seconds| Input tokens: 5,837 | Output
# tokens: 635]
#                     name  total_daily_cost
# 0  Montreal Ice Cream Co        206.175663
# 1  Brain Freeze Brothers        171.800000
# 2     Toronto Gelato Ltd        568.170619
# 3         Buffalo Scoops        378.900000
# 4       Vermont Creamery        406.100000

# %% [markdown]
# ## Compare to traditional tool calling.

# %% [raw]
# Thought: I need to use the `calculate_transport_cost` tool
# to get the transportation cost for 50 liters of ice cream over
# 10 kilometers.
#
# Code:
# ```py
# transport_cost = calculate_transport_cost(
#     distance_km=10,
#     order_volume=50
# )
# print(transport_cost)
# ```

# %% [raw]
# Thought: I need to use the `calculate_transport_cost` tool
# to get the transportation cost for 50 liters of ice cream over
# 10 kilometers.
#
# Action:
# {
#     "tool_name": "calculate_transport_cost",
#     "tool_arguments": {
#         "distance_km": 10,
#         "order_volume": 50
#     }
# }

# %%
from smolagents import ToolCallingAgent

"""
model = HfApiModel(
    "Qwen/Qwen2.5-72B-Instruct",
    temperature=0.6
)
"""
agent = ToolCallingAgent(
    model=model,
    tools=[calculate_transport_cost, calculate_tariff],
    max_steps=20,
)
agent.logger.console.width=66

# %% [markdown]
# <div style="font-size: 14px; background-color: #fff9b0; padding: 12px; border-left: 4px solid #facc15;">
#   <strong>Note:</strong> During this run, the agent may generate code that creates an error. This is OK. The agent will try to fix the error.
# </div>

# %%
output = agent.run(
    task,
    additional_args={"suppliers_data": suppliers_df, "data_description": data_description},
)
print(output)
# Out:
# ╭─────────────────────────── New run ────────────────────────────╮
# │                                                                │
# │ Here is a dataframe of different ice cream suppliers.          │
# │ Could you give me a comparative table (as a dataframe) of the  │
# │ total                                                          │
# │ daily price for getting daily ice cream delivery from each of  │
# │ them,                                                          │
# │ given that we need exactly 30 liters of ice cream per day?     │
# │ Take                                                           │
# │ into account transportation cost and tariffs.                  │
# │                                                                │
# │ You have been provided with these additional arguments, that   │
# │ you can access using the keys as variables in your python      │
# │ code:                                                          │
# │ {'suppliers_data':                     name        location    │
# │ distance_km  canadian  \                                       │
# │ 0  Montreal Ice Cream Co    Montreal, QC          120          │
# │ True                                                           │
# │ 1  Brain Freeze Brothers  Burlington, VT           85          │
# │ False                                                          │
# │ 2     Toronto Gelato Ltd     Toronto, ON          400          │
# │ True                                                           │
# │ 3         Buffalo Scoops     Buffalo, NY          220          │
# │ False                                                          │
# │ 4       Vermont Creamery    Portland, ME          280          │
# │ False                                                          │
# │                                                                │
# │    price_per_liter  tasting_fee                                │
# │ 0             1.95         0.00                                │
# │ 1             1.91        12.50                                │
# │ 2             1.82        30.14                                │
# │ 3             2.43        42.00                                │
# │ 4             2.33         0.20  , 'data_description':         │
# │ 'Suppliers have an additional tasting fee: that is a fixed fee │
# │ applied to each order to taste the ice cream.'}.               │
# │                                                                │
# ╰─ LiteLLMModel - openai/gpt-4o-mini ────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_transport_cost' with arguments:       │
# │ {'distance_km': 120, 'order_volume': 30}                       │
# ╰────────────────────────────────────────────────────────────────╯
# Observations: 144.0
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_tariff' with arguments: {'base_cost': │
# │ 58.5, 'is_canadian': True}                                     │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_transport_cost' with arguments:       │
# │ {'distance_km': 85, 'order_volume': 30}                        │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_tariff' with arguments: {'base_cost': │
# │ 57.3, 'is_canadian': False}                                    │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_transport_cost' with arguments:       │
# │ {'distance_km': 400, 'order_volume': 30}                       │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_tariff' with arguments: {'base_cost': │
# │ 54.6, 'is_canadian': True}                                     │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_transport_cost' with arguments:       │
# │ {'distance_km': 220, 'order_volume': 30}                       │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_tariff' with arguments: {'base_cost': │
# │ 72.9, 'is_canadian': False}                                    │
# ╰────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_transport_cost' with arguments:       │
# │ {'distance_km': 280, 'order_volume': 30}                       │
# ╰────────────────────────────────────────────────────────────────╯
# Observations: 3.675663404700058
# Observations: 102.0
# Observations: 0
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'calculate_tariff' with arguments: {'base_cost': │
# │ 69.9, 'is_canadian': False}                                    │
# ╰────────────────────────────────────────────────────────────────╯
# Observations: 480.0
# Observations: 3.4306191777200543
# Observations: 264.0
# Observations: 0
# Observations: 336.0
# Observations: 0
# [Step 1: Duration 6.07 seconds| Input tokens: 1,457 | Output
# tokens: 246]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer':        │
# │ 'Supplier Name      Total Daily Price\nMontreal Ice Cream Co   │
# │ $147.68\nBrain Freeze Brothers      $57.30\nToronto Gelato Ltd │
# │ $484.57\nBuffalo Scoops            $336.00\nVermont Creamery   │
# │ $264.00\n'}                                                    │
# ╰────────────────────────────────────────────────────────────────╯
# Final answer: Supplier Name      Total Daily Price
# Montreal Ice Cream Co    $147.68
# Brain Freeze Brothers      $57.30
# Toronto Gelato Ltd       $484.57
# Buffalo Scoops            $336.00
# Vermont Creamery          $264.00
# [Step 2: Duration 4.46 seconds| Input tokens: 3,831 | Output
# tokens: 332]
# Supplier Name      Total Daily Price
# Montreal Ice Cream Co    $147.68
# Brain Freeze Brothers      $57.30
# Toronto Gelato Ltd       $484.57
# Buffalo Scoops            $336.00
# Vermont Creamery          $264.00
