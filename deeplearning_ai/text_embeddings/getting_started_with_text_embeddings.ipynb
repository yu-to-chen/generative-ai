# %% [markdown]
# # Getting Started With Text Embeddings

# %%
import sys
# !{sys.executable} -m pip install -U google-generativeai
# Out:
# Collecting google-generativeai
#   Obtaining dependency information for google-generativeai from https://files.pythonhosted.org/packages/f4/0a/d14c0482986fb488e4833399a29e972d63635d1f27b198e32fb28101f585/google_generativeai-0.2.1-py3-none-any.whl.metadata
#   Downloading google_generativeai-0.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-ai-generativelanguage==0.3.3 (from google-generativeai)
#   Obtaining dependency information for google-ai-generativelanguage==0.3.3 from https://files.pythonhosted.org/packages/8f/66/b5a83cdb4c8cb1d0f64243ae61bfa4e970b5740c2999dfe1bb96725599ab/google_ai_generativelanguage-0.3.3-py3-none-any.whl.metadata
#   Downloading google_ai_generativelanguage-0.3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: google-auth in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-generativeai) (2.23.2)
# Requirement already satisfied: google-api-core in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-generativeai) (2.12.0)
# Requirement already satisfied: protobuf in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-generativeai) (4.24.0)
# Requirement already satisfied: tqdm in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-generativeai) (4.66.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-ai-generativelanguage==0.3.3->google-generativeai) (1.22.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-api-core->google-generativeai) (1.60.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-auth->google-generativeai) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-auth->google-generativeai) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-auth->google-generativeai) (4.9)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-api-core->google-generativeai) (1.59.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from google-api-core->google-generativeai) (1.59.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth->google-generativeai) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ytchen/Documents/experimental/env11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Downloading google_generativeai-0.2.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 754.8 kB/s eta 0:00:00a 0:00:01
# Downloading google_ai_generativelanguage-0.3.3-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.9/267.9 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: google-ai-generativelanguage, google-generativeai
# Successfully installed google-ai-generativelanguage-0.3.3 google-generativeai-0.2.1

# %%
import google.generativeai as palm
import os
import pprint
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

palm.configure(api_key=os.environ['API_KEY'])

# %%
for model in palm.list_models():
  if 'embedText' in model.supported_generation_methods:
    print(model.name)
# Out:
# models/embedding-gecko-001

# %% [markdown]
# #### Use the embeddings model

# %%
x = 'life'
close_to_x = 'What is the meaning of life?'

model = "models/embedding-gecko-001"

# Create an embedding
embedding_x = palm.generate_embeddings(model=model, text=x)
embedding_close_to_x = palm.generate_embeddings(model=model, text=close_to_x)

vector = embedding_x['embedding']
print(f"Length = {len(vector)}")
print(vector[:10])
# Out:
# Length = 768
# [-0.0062485174, 0.015260352, -0.030612998, 0.053223047, 0.014430896, -0.05429975, 0.045275558, 0.021513924, -0.06517641, 0.019092383]

# %%
vector = embedding_close_to_x['embedding']
print(f"Length = {len(vector)}")
print(vector[:10])
# Out:
# Length = 768
# [0.020220786, 0.022316508, -0.009204807, 0.004977066, 0.016092807, -0.018982107, 0.043249473, 0.026188457, -0.04345435, 0.023770839]

# %%
embedding_close_to_x
# Out:
# {'embedding': [0.020220786,
#   0.022316508,
#   -0.009204807,
#   0.004977066,
#   0.016092807,
#   -0.018982107,
#   0.043249473,
#   0.026188457,
#   -0.04345435,
#   0.023770839,
#   0.0070713465,
#   0.013504822,
#   0.027093675,
#   -0.0010874213,
#   -0.05329074,
#   -0.034527313,
#   -0.02143942,
#   -0.019982468,
#   0.036332387,
#   -6.272615e-05,
#   -0.09729496,
#   -0.04436393,
#   -0.0074598226,
#   -0.0034127934,
#   -0.020365834,
#   0.033585176,
#   -0.07001547,
#   -0.0014657908,
#   0.06559514,
#   -0.010701706,
#   0.011561594,
#   0.05060078,
#   -0.026713371,
#   0.00022009578,
#   -0.018033806,
#   0.0030499338,
#   0.06852211,
#   0.02675625,
#   0.0017161423,
#   -0.06532928,
#   0.05191272,
#   -0.028039712,
#   -0.05173035,
#   0.0045357356,
#   0.047123767,
#   -0.020915901,
#   0.0060861898,
#   -0.019406406,
#   -0.055722423,
#   0.044913318,
#   -0.04489277,
#   -0.04581012,
#   0.012130714,
#   -0.029686064,
#   0.03091112,
#   0.0049106367,
#   -0.031240897,
#   -0.009820177,
#   -0.048538063,
#   0.01299491,
#   -0.023018897,
#   -0.0126150055,
#   -0.043414153,
#   -0.03612232,
#   -0.034647707,
#   0.030080214,
#   0.010898302,
#   0.033523876,
#   -0.041318014,
#   0.005840735,
#   0.043762047,
#   0.029413817,
#   0.008634841,
#   -0.047171284,
#   -0.05494802,
#   -0.058345553,
#   -0.019324284,
#   -0.029528791,
#   -0.0031768165,
#   0.008585264,
#   0.031561192,
#   0.06992486,
#   0.0072965357,
#   0.049293336,
#   -0.03641138,
#   0.06595504,
#   0.005222166,
#   0.0018149223,
#   -0.04746252,
#   0.040189933,
#   0.035546534,
#   -0.02303265,
#   -0.053167608,
#   0.0065062516,
#   0.045660146,
#   -0.059374847,
#   0.01980591,
#   0.011054823,
#   -0.028283551,
#   -0.019365324,
#   0.045656327,
#   0.06334985,
#   -0.02330438,
#   -0.012121282,
#   -0.012234887,
#   0.013794961,
#   0.041238114,
#   -0.04700442,
#   -0.0021130645,
#   0.036318462,
#   -0.005890727,
#   0.019174503,
#   0.04317169,
#   0.007226924,
#   0.027543958,
#   -0.00017819184,
#   -0.060411315,
#   -0.042263024,
#   -0.08079351,
#   0.04775429,
#   -0.014466261,
#   0.02957785,
#   -0.05739883,
#   0.028968493,
#   0.052284963,
#   -0.016923781,
#   -0.02512829,
#   -0.009595182,
#   0.0040887054,
#   0.016203973,
#   -0.027043344,
#   -0.0022217669,
#   0.019310482,
#   -0.0021989031,
#   -0.05440193,
#   -0.016769793]}

# %%
similar_measure = np.dot(embedding_x['embedding'], embedding_close_to_x['embedding'])
print(similar_measure)
# Out:
# 0.642187941111088
# '\nemb_1 = embedding_model.get_embeddings(\n    ["What is the meaning of life?"]) # 42!\n\nemb_2 = embedding_model.get_embeddings(\n    ["How does one spend their time well on Earth?"])\n\nemb_3 = embedding_model.get_embeddings(\n    ["Would you like a salad?"])\n\nvec_1 = [emb_1[0].values]\nvec_2 = [emb_2[0].values]\nvec_3 = [emb_3[0].values]\n'

# %% [markdown]
# #### Similarity
#
# - Calculate the similarity between two sentences as a number between 0 and 1.
# - Try out your own sentences and check if the similarity calculations match your intuition.

# %%
"""
emb_1 = embedding_model.get_embeddings(
    ["What is the meaning of life?"]) # 42!

emb_2 = embedding_model.get_embeddings(
    ["How does one spend their time well on Earth?"])

emb_3 = embedding_model.get_embeddings(
    ["Would you like a salad?"])

vec_1 = [emb_1[0].values]
vec_2 = [emb_2[0].values]
vec_3 = [emb_3[0].values]
"""

emb_1 = palm.generate_embeddings(model=model, text=["What is the meaning of life?"])
emb_2 = palm.generate_embeddings(model=model, text=["How does one spend their time well on Earth?"])
emb_3 = palm.generate_embeddings(model=model, text=["Would you like a salad?"])

vec_1 = emb_1['embedding']
vec_2 = emb_2['embedding']
vec_3 = emb_3['embedding']

# %% [markdown]
# - Note: the reason we wrap the embeddings (a Python list) in another list is because the `cosine_similarity` function expects either a 2D numpy array or a list of lists.
# ```Python
# vec_1 = [emb_1[0].values]
# ```

# %%
print(cosine_similarity(vec_1, vec_2)) 
print(cosine_similarity(vec_2, vec_3))
print(cosine_similarity(vec_1, vec_3))
# Out:
# [[0.65584864]]
# [[0.51988917]]
# [[0.54102993]]

# %% [markdown]
# #### From word to sentence embeddings
# - One possible way to calculate sentence embeddings from word embeddings is to take the average of the word embeddings.
# - This ignores word order and context, so two sentences with different meanings, but the same set of words will end up with the same sentence embedding.

# %%
in_1 = "The kids play in the park."
in_2 = "The play was for kids in the park."

# %% [markdown]
# - Remove stop words like ["the", "in", "for", "an", "is"] and punctuation.

# %%
in_pp_1 = ["kids", "play", "park"]
in_pp_2 = ["play", "kids", "park"]

# %% [markdown]
# - Generate one embedding for each word.  So this is a list of three lists.

# %%
embeddings_1 = [palm.generate_embeddings(model=model, text=s)['embedding'] for s in in_pp_1]
print(len(embeddings_1))

emb_array_1 = np.stack(embeddings_1)
print(emb_array_1.shape)
# Out:
# 3
# (3, 768)

# %% [markdown]
# - Use numpy to convert this list of lists into a 2D array of 3 rows and 768 columns.

# %%
embeddings_2 = [palm.generate_embeddings(model=model, text=s)['embedding'] for s in in_pp_2]
emb_array_2 = np.stack(embeddings_2)
print(emb_array_1.shape)
# Out:
# (3, 768)

# %% [markdown]
# - Take the average embedding across the 3 word embeddings
# - You'll get a single embedding of length 768.

# %%
emb_1_mean = emb_array_1.mean(axis = 0) 
print(emb_1_mean.shape)
# Out:
# (768,)

# %%
emb_2_mean = emb_array_2.mean(axis = 0)

# %% [markdown]
# - Check to see that taking an average of word embeddings results in two sentence embeddings that are identical.

# %%
print(emb_1_mean[:4])
print(emb_2_mean[:4])
# Out:
# [-0.00388558 -0.00526848  0.0058703   0.03315523]
# [-0.00388558 -0.00526848  0.0058703   0.03315523]

# %% [markdown]
# #### Get sentence embeddings from the model.
# - These sentence embeddings account for word order and context.
# - Verify that the sentence embeddings are not the same.

# %%
print(in_1)
print(in_2)
# Out:
# The kids play in the park.
# The play was for kids in the park.

# %%
embedding_1 = palm.generate_embeddings(model=model, text=in_1)
embedding_2 = palm.generate_embeddings(model=model, text=in_2)

# %%
vector_1 = embedding_1['embedding']
print(vector_1[:4])
vector_2 = embedding_2['embedding']
print(vector_2[:4])
# Out:
# [0.0040104063, -0.02063808, -0.0028912085, -0.007481416]
# [-0.0154303685, -0.012839607, 0.012309532, -0.00071919535]
