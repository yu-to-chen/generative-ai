# %% [markdown]
# # L3: Measuring Cache Effectiveness

# %% [markdown]
# In this lab, you’ll learn how to evaluate your cache using metrics like hit rate, precision, recall, and latency to understand its real impact.

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setup Environment

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import time

from tqdm.auto import tqdm

from cache.evals import CacheEvaluator
from cache.faq_data_container import FAQDataContainer
from cache.wrapper import SemanticCacheWrapper
from cache.config import config, load_openai_key

print("📦 Libraries imported successfully")
# Out:
# /Users/ytchen/Documents/experimental/Cache/.venv/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1646c51a-4584-4ddb-88c5-17d19ab78060'>
#   <div id="abe5ed32-20f1-496a-b413-9fa6b3ecb656" data-root-id="1646c51a-4584-4ddb-88c5-17d19ab78060" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8a7caed0-55e8-4b2e-8e06-041428bab24d":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"240da248-7945-4625-b9c1-c64a65501156","attributes":{"notifications":{"type":"object","name":"Notifications","id":"1efa5b1d-da3f-4274-a0d7-a5368970220b"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1646c51a-4584-4ddb-88c5-17d19ab78060"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9e1f3d08-7b72-4e21-b2f1-d6e18610f79c","attributes":{"plot_id":"1646c51a-4584-4ddb-88c5-17d19ab78060","comm_id":"9dc38ba54e504681a80eb4f72bf09064","client_comm_id":"d99b5342b6ed415392408bd062cfac72"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"8a7caed0-55e8-4b2e-8e06-041428bab24d","roots":{"1646c51a-4584-4ddb-88c5-17d19ab78060":"abe5ed32-20f1-496a-b413-9fa6b3ecb656"},"root_ids":["1646c51a-4584-4ddb-88c5-17d19ab78060"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# 📦 Libraries imported successfully

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
# </div>

# %% [markdown]
# ## Load Data and Recreate Cache

# %%
data_container = FAQDataContainer()
faq_df, test_df = data_container.faq_df, data_container.test_df

test_queries = test_df["question"].tolist()
# Out:
# Loaded 8 FAQ entries
# Loaded 80 test queries

# %%
# Initialize semantic cache wrapper from config
cache_wrapper = SemanticCacheWrapper.from_config(config)
# Out:
# ✅ Redis is running and accessible!
# 20:10:59 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 20:10:59 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: redis/langcache-embed-v1

# %% [markdown]
# ## Evaluating cache quality

# %%
# Cache hydration via wrapper helper
cache_wrapper.hydrate_from_df(faq_df)

cache_wrapper.check(faq_df["question"].iloc[0])
# Out:
# (Query: 'How do I get a refund?', Matches: ['How do I get a refund?'])

# %%
test_queries[:4]
# Out:
# ["What's the process for getting my money back?",
#  'How can I request a refund for my purchase?',
#  'What steps do I follow to return an item for money back?',
#  "What's your refund policy for digital products?"]

# %%
cache_results = cache_wrapper.check_many(test_queries)
cache_results[:4]
# Out:
# [(Query: 'What's the process for getting my money back?', Matches: ['How do I get a refund?']),
#  (Query: 'How can I request a refund for my purchase?', Matches: ['How do I get a refund?']),
#  (Query: 'What steps do I follow to return an item for money back?', Matches: ['How do I get a refund?']),
#  (Query: 'What's your refund policy for digital products?', Matches: [])]

# %%
evaluator = CacheEvaluator(
    true_labels=data_container.label_cache_hits(cache_results),
    cache_results=cache_results,
)
evaluator.report_metrics()
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] DataFrame(DataFrame, width=200)
#         [1] DataFrame(Styler)

# %%
[[tn, fp], [fn, tp]] = evaluator.get_metrics()["confusion_mask"]

# %%
tn[:9]
# Out:
# array([False, False, False,  True,  True, False,  True,  True,  True])

# %%
evaluator.matches_df()[fp]
# Out:
#                                             query  \
# 5        Can I get a refund if I changed my mind?
# 24  Can I change my order after it's been placed?
# 53         How do I upgrade my subscription plan?
# 55       Can I pause my subscription temporarily?
# 75       Can I schedule a specific delivery time?
#
#                                 match  distance  true_label
# 5              How do I get a refund?  0.294379       False
# 24  Can I change my delivery address?  0.286985       False
# 53   How do I cancel my subscription?  0.250154       False
# 55   How do I cancel my subscription?  0.277127       False
# 75  Can I change my delivery address?  0.286493       False

# %% [markdown]
# ## Evaluating cache latency

# %%
def simulate_llm_call(prompt):
    time.sleep(np.random.uniform(0.2, 0.5))
    return f"LLM response to {prompt}"

# %%
from cache.evals import PerfEval

perf_eval = PerfEval()

with perf_eval:
    for query in tqdm(test_queries):
        cache_wrapper.check(query)
        perf_eval.tick("cache_hit")
        perf_eval.start()
        simulate_llm_call(query)
        perf_eval.tick("llm_call")

metrics = perf_eval.get_metrics(labels=["cache_hit", "llm_call"])
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]

# %%
metrics["by_label"]
# Out:
# {'cache_hit': {'count': 80,
#   'average_latency': 5.594941973686218,
#   'p50': 5.394458770751953,
#   'p90': 6.302762031555176,
#   'p95': 6.451237201690671,
#   'p99': 8.500947952270483,
#   'average_throughput': 178732.86348690256},
#  'llm_call': {'count': 80,
#   'average_latency': 345.52208483219147,
#   'p50': 336.21084690093994,
#   'p90': 462.15796470642096,
#   'p95': 479.1483402252197,
#   'p99': 489.853823184967,
#   'average_throughput': 2894.1710064225463}}

# %%
perf_eval.plot(
    title="Performance Comparison", show_cost_analysis=False
)

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"><b>Note:</b> In the above experiment we measure the latency of the cache response and a mocked latency of an LLM call. The mocked LLM call is a dummy function that sleeps for a random amount of time. The randomness in the results mainly comes from the randomness we introduced to mock the LLM. The results show us what we can typically see in practice.</p>

# %%
llm_latency = metrics["by_label"]["llm_call"]["average_latency"]
cache_latency = metrics["by_label"]["cache_hit"]["average_latency"]

cache_hit_rate = 0.3
cached_llm_latency = llm_latency * (1 - cache_hit_rate) + cache_latency * cache_hit_rate
cached_llm_drop_in_latency = (llm_latency - cached_llm_latency) / llm_latency
cached_llm_speedup = llm_latency / cached_llm_latency
print(f"Overall latency drop of an LLM app: {int(cached_llm_drop_in_latency * 100)}%")
print(f"Overall speedup of an LLM app {cached_llm_speedup:.2f}x")
# Out:
# Overall latency drop of an LLM app: 29%
# Overall speedup of an LLM app 1.42x

# %% [markdown]
# ## LLM-as-a-Judge for cache quality evaluation

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output visualizations generated may differ from those shown in the video.</p>

# %%
cache_wrapper.hydrate_from_df(faq_df)

# we set the distance to obtain even bad matches and evaluate if they are true negatives
full_retrieval_nearest_neighbors = cache_wrapper.check_many(
    test_queries, distance_threshold=1
)
full_retrieval_matches = [h.matches[0].prompt for h in full_retrieval_nearest_neighbors]
full_retrieval_matches[:4]
# Out:
# ['How do I get a refund?',
#  'How do I get a refund?',
#  'How do I get a refund?',
#  'How do I get a refund?']

# %%
load_openai_key()
# Out:
# > OpenAI API key is already loaded in the environment

# %%
from cache.llm_evaluator import LLMEvaluator

evaluator = LLMEvaluator.construct_with_gpt()

# %%
llm_similarity_results = evaluator.predict(
    dataset=zip(test_queries, full_retrieval_matches),
    batch_size=5,
)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 20:12:31 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:31 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:31 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:31 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:32 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:32 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:32 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:32 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:33 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:33 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:34 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:34 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:34 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:35 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:35 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:36 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:36 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:36 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:36 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:38 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:39 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:39 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:39 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:39 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:39 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:40 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:40 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:40 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:40 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:41 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:42 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:42 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:42 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:42 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:43 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:44 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:44 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:44 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:44 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:44 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:45 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:45 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:45 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:46 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:46 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:47 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:47 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:47 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:47 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:48 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:48 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:49 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:49 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:49 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:49 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:50 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:51 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:51 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:51 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:51 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:52 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:52 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:52 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:52 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:53 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:55 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:55 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:55 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:55 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:56 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:57 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:57 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:57 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:58 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 20:12:58 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
llm_similarity_results.df.head()
# Out:
#                                               reason  is_similar
# 0  Both sentences ask about the procedure to rece...        True
# 1  Both sentences ask about the process of obtain...        True
# 2  The first sentence asks about the procedure to...        True
# 3  Sentence1 specifically asks about the refund p...       False
# 4  The first sentence asks specifically about the...       False

# %%
# When evaluation is based on full retrieval we should use this constructor
evaluator = CacheEvaluator.from_full_retrieval(
    true_labels=llm_similarity_results.df["is_similar"].values,
    cache_results=cache_wrapper.check_many(test_queries),
)
evaluator.report_metrics()
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] DataFrame(DataFrame, width=200)
#         [1] DataFrame(Styler)

# %%
cache_wrapper.cache.clear()
