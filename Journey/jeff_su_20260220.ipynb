# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI

def get_completion(prompt, model="gpt-4o-mini"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content


# Initialize the client
client = OpenAI(api_key=openai.api_key)

def get_completion_from_messages(messages, model="gpt-4o-mini", temperature=0):
    # The new syntax: client.chat.completions.create
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    
    # Accessing the content is now done via dot notation, not a dictionary
    return response.choices[0].message.content

# %% [markdown]
# # Context + Task

# %%
messages =  [
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'I am a 70kg male, give me a 3-month training program.'}  ]

response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm not qualified to provide personalized training programs, but I can offer some general guidance. A well-rounded 3-month training program typically includes a mix of cardiovascular exercise, strength training, flexibility work, and rest days for recovery. Here's a sample outline you could consider:
#
# 1. Cardio: Aim for 3-5 days per week of activities like running, cycling, swimming, or aerobics for 30-60 minutes each session.
# 2. Strength training: Include 2-3 days per week of weightlifting or bodyweight exercises targeting major muscle groups. Include exercises like squats, lunges, push-ups, and rows.
# 3. Flexibility: Stretch daily or include yoga or Pilates sessions 1-2 times per week to improve flexibility and reduce the risk of injury.
# 4. Rest and recovery: Make sure to include rest days in your schedule to allow your body to recover and adapt to the training stimulus.
#
# Remember to listen to your body, adjust the intensity of your workouts as needed, stay hydrated, and fuel your body with proper nutrition to support your training goals. It's also a good idea to consult with a fitness professional or personal trainer for a program tailored to your specific needs and goals.

# %% [markdown]
# ## Context
# - User background: 我是一個70公斤的男性
# - Sucess looks like this: 希望在接下來的3個月內增加5公斤的肌肉質量
# - Environment: 我每週只有時間去健身房兩次，每次1小時。

# %% [markdown]
# ## Task
# - 請給我一個3個月的訓練計劃

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'I am a 70kg male looking to put on 5 kg of muscle mass \
over the next 3 months. \
I only have time to go to the gym twice a week, and for 1 hour each session. \
Give me a 3-month traning program to follow.'}  ]

response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# It's great that you're looking to increase your muscle mass! With only two gym sessions per week, it's important to make the most out of your time in the gym. Here's a basic 3-month training program you can follow:
#
# **Weeks 1-4:**
# - **Day 1:** Full-body workout focusing on compound movements such as squats, deadlifts, bench press, and rows. Aim for 3-4 sets of 8-12 reps for each exercise.
# - **Day 2:** Rest day or light cardio for recovery.
#
# **Weeks 5-8:**
# - **Day 1:** Full-body workout similar to Weeks 1-4 but with increased weight or intensity. Add in some isolation exercises like bicep curls, tricep extensions, or calf raises.
# - **Day 2:** Rest day or light cardio for recovery.
#
# **Weeks 9-12:**
# - **Day 1:** Full-body workout focusing on increasing weight and intensity. Incorporate supersets or drop sets to push your muscles harder. Don't forget to include core exercises like planks or Russian twists.
# - **Day 2:** Rest day or light cardio for recovery.
#
# **Nutrition is also key when it comes to gaining muscle mass. Here are some tips:**
# - Make sure you're consuming enough protein to support muscle growth. Aim for at least 1.2-2.2 grams of protein per kilogram of body weight per day.
# - Eat a balanced diet with plenty of fruits, vegetables, whole grains, and healthy fats.
# - Stay hydrated and consider adding protein shakes or smoothies to your diet if necessary.
#
# Remember to listen to your body and adjust the program as needed based on your progress and how you feel. Consistency is key, so make sure to stick to your training schedule and give your body the rest it needs to recover and grow. Good luck on your muscle-building journey!

# %% [markdown]
# # Exemplar
# - Task: 使用這個結構重寫這個子彈點: 我通過Y手段達成了X，從而導致了Z。
# - Exemplar: 例如：我通過教育護士新的協議，將醫院死亡率降低了10%，這意味著每年節省了200條人命。

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Re-write this bullet point using this structure: \
"I accomplished X by the measure Y that resulted in Z" \
For example: "I lowered hospital mortality rate by 10% by educating nurses \
in new protocols which translates to 200 lives saved per year" \
Here iss the bullet point I have now: \
- Brand strategy developed and implements/ Market research, market analysis \
- Analysis the data by in market and out market, \
developed the marketing strategy by data insight \
- Raised public and KOL awareness of the brand and the related information \
- Owned brand assigned portfolio, budget controlled, and pricing plan.'}]

response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I raised public and Key Opinion Leader (KOL) awareness of the brand and related information by developing a brand strategy based on market research and analysis. This resulted in effective budget control, pricing plans, and ownership of the brand-assigned portfolio.

# %% [markdown]
# # Put it all together
# - Persona: 您是Apple的資深產品行銷經理
# - Context: 剛剛與Tesla合作揭露了最新的Apple產品，即Apple汽車，並收到了12,000筆預訂，這比目標高出200%
# - Task: 寫
# - Format: 電子郵件
# - Exemplar: 該電子郵件應該包括一個tl;dr（太長，沒讀）部分，項目背景（為什麼這個產品誕生），業務結果部分（量化的業務指標），並以感謝產品和工程團隊的部分結尾
# - Tone: 請使用清晰簡潔的語言，以自信但友好的語氣撰寫

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'You are a senior product marketing manager at Apple \
and you have just unveiled the latest Apple product in collaboration with Tesla, \
the Apple car, and received 12,000 pre-orders, which is 200% higher than target. \
Write an email to your boss, Tim Cookie, sharing this positive news. \
The email should include a tl;dr (too long, did not read) section, \
 project background (why this product came into existence), \
 business results section (quantifiable business metrics), \
 and end with a section thanking the product and engineering teams. \
Use clear and concise language and write in a confident yet friendly tone.'}]

response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Subject: Successful Launch of the Apple Car: Exceeded Pre-order Targets by 200%
#
# Hi Tim,
#
# I hope this email finds you well! I am thrilled to share the exciting news about the successful launch of the Apple Car in collaboration with Tesla. Our team has received an overwhelming 12,000 pre-orders, which is 200% higher than our initial target. This remarkable response speaks volumes about the potential of this groundbreaking product.
#
# **TL;DR:** The Apple Car launch has surpassed pre-order targets by an impressive 200%, showcasing strong market demand and consumer interest in our innovative collaboration with Tesla.
#
# **Project Background:**
# The Apple Car was conceptualized to revolutionize the automotive industry by merging cutting-edge technology with sustainable transportation solutions. Our goal was to create a seamless and intelligent driving experience that reflects the ethos of both Apple and Tesla, catering to tech-savvy consumers looking for a premium electric vehicle.
#
# **Business Results:**
# - Total pre-orders: 12,000
# - Exceeded pre-order target by 200%
# - Positive market feedback and media coverage
# - Increased brand visibility and competitiveness in the electric vehicle market
#
# **Thank You:**
# I want to express my deepest gratitude to the dedicated product and engineering teams who worked tirelessly to bring the Apple Car to life. Their creativity, innovation, and relentless pursuit of excellence have been instrumental in achieving this remarkable milestone.
#
# Thank you for your unwavering support throughout this project. I look forward to further discussions on how we can leverage this success to drive continued growth and innovation at Apple.
#
# Best regards,
#
# [Your Name]
# Senior Product Marketing Manager

# %% [markdown]
# # Put it all together, again
# - Persona: 您是Amazon的高級市場營銷經理
# - Context: 剛剛推出了與Tiktok的最新市場營銷活動，並使您的ROMI（市場營銷投資回報）翻了一番，比目標高出100%
# - Task: 寫
# - Format: 電子郵件
# - Exemplar: 該電子郵件應該包括一個tl;dr（太長，沒讀）部分，項目背景（為什麼這個產品誕生），業務結果部分（量化的業務指標），並以感謝市場營銷和工程團隊的部分結束
# - Tone: 請使用清晰簡潔的語言，以自信但風趣的語氣撰寫

# %%
messages =  [  
{'role':'system', 'content':'你是友善的聊天機器人。'},    
{'role':'user', 'content':'You are a senior marketing manager at Amazon and \
you have just unveiled the latest marketing campaign with Tiktok, \
and doubled your ROMI, return on marketing investing, \
which is 100% higher than target. \
Write an email to your boss, Jeff Bezz, sharing this positive news. \
The email should include a tl;dr (too long, did not read) section, \
marketing background (why this campaign came into existence), \
business results section (quantifiable business metrics), \
and end with a section thanking the marketing and engineering teams. \
Use clear and concise language and write in a confident yet witty tone.' }]

response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Subject: Exciting News: TikTok Marketing Campaign Doubles ROMI, Exceeds Target!
#
# Hi Jeff,
#
# I hope this email finds you well. I am thrilled to share some exciting news with you about our most recent marketing campaign with TikTok. Here’s a brief overview for you:
#
# **TL;DR:** Our latest TikTok marketing campaign has doubled our ROMI, exceeding our target by 100%.
#
# **Marketing Background:** The campaign was designed to tap into the growing trend of user-generated content on TikTok and leverage the platform's engagement to boost brand visibility and drive conversions. We focused on creating authentic, engaging content that resonated with our target audience, resulting in a significant increase in brand awareness and customer engagement.
#
# **Business Results:** I am overjoyed to report that our ROMI for this campaign has doubled, surpassing our target by 100%. This achievement not only demonstrates the effectiveness of our marketing strategy but also showcases the potential for future collaborations with TikTok. Furthermore, we have seen a significant uplift in new customer acquisition and retention rates, indicating a positive impact on our bottom line.
#
# I want to take this opportunity to express my gratitude to the incredible marketing and engineering teams who worked tirelessly to make this campaign a success. Their dedication, creativity, and hard work have truly paid off, and I couldn't be prouder of their efforts.
#
# Thank you for your continued support and guidance as we strive to innovate and excel in the digital marketing landscape.
#
# Best regards,
# [Your Name]
# Senior Marketing Manager, Amazon
