# %% [markdown]
# ## Test LLM by AI Suite

# %%
from dotenv import load_dotenv, find_dotenv  
import numpy as np
import os
from pprint import pprint as pp

# Load variables from .env file
load_dotenv()
# Out:
# True

# %%
import aisuite as ai
client = ai.Client()

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
provider = "openai"
model_id = "gpt-4o-mini"

# %%
messages = [
    {"role": "system", "content": "Talk using Pirate English."},
    {"role": "user", "content": "Tell a joke in 1 line."}
]

response = client.chat.completions.create(model="openai:gpt-3.5-turbo", 
                                          messages=messages, 
                                          temperature=0.0)
print(response.choices[0].message.content)

# %%
provider = "openai"
model_id = "gpt-4o-mini"
messages = [
    {"role": "system", "content": "Talk using Pirate English."},
    {"role": "user", "content": "Tell a joke in 1 line."}
]
response = client.chat.completions.create(
    model=f"{provider}:{model_id}",
    messages=messages,
    temperature=0.0
)
print(response.choices[0].message.content)
# Out:
# Why did the pirate go to school? To improve his "arrrticulation!"

# %% [markdown]
# ## Data preparation for Few-shot learning

# %%
import pandas as pd

filepath = '/Users/ytchen/Documents/projects/John/AI_team/analysis/GPT_example_20250210.csv'

try:
  df = pd.read_csv(filepath)
  print(df)
  # Access data:
  # print(df['column_name'])
except FileNotFoundError:
  print("File not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
#    product_id_int  is_publish_int          product_name_str  \
# 0          111472               1      【預購】美型正姿防滑瑜珈球椅 - 常規版
# 1          118047               1          Zenlet 3 Pro Max
# 2          114070               1  【初芳宇】ROCKY 翹翹隨行杯 - 500mL
#
#                                 product_features_str  \
# 0  citiesocial 全臺獨家引進，歐洲萬人好評支持\n宛如法式輕奢裝潢的瑜珈球椅\n絕美...
# 1  輕觸即展卡，俐落優雅\n一目了然的卡距，易讀好取\n十五度卡片仰角，輕鬆好拿\n輕鬆感應，便利延續
# 2  Mag Disk 磁吸止水蓋，只需輕輕一按即可輕鬆開關\n防漏設計｜強力磁鐵緊密壓縮，安心防...
#
#                               product_features_split  \
# 0  ["citiesocial 全臺獨家引進，歐洲萬人好評支持", "宛如法式輕奢裝潢的瑜珈球椅...
# 1  ["輕觸即展卡，俐落優雅", "一目了然的卡距，易讀好取", "十五度卡片仰角，輕鬆好拿",...
# 2  ["Mag Disk 磁吸止水蓋，只需輕輕一按即可輕鬆開關", "防漏設計｜強力磁鐵緊密壓縮...
#
#                             product_features_cleaned  \
# 0  ["citiesocial 全臺獨家引進歐洲萬人好評支持", "宛如法式輕奢裝潢的瑜珈球椅"...
# 1  ["輕觸即展卡俐落優雅", "一目了然的卡距易讀好取", "十五度卡片仰角輕鬆好拿", "輕...
# 2  ["Mag Disk 磁吸止水蓋只需輕輕一按即可輕鬆開關", "防漏設計強力磁鐵緊密壓縮安心...
#
#                           product_features_segmented  \
# 0  ["citiesocial", "全", "臺", "獨家", "引進", "歐洲", "萬...
# 1  ["輕", "觸", "即", "展卡", "俐落", "優雅", "一目了然", "的",...
# 2  ["Mag", " Disk", "磁吸", "止水蓋", "只", "需", "輕輕", ...
#
#                                     product_info_str  \
# 0  https://citiesocial.s3.ap-northeast-1.amazonaw...
# 1  \n\n\n\n\n\n\n\n\n\n讓 Zenlet 3 系列為你展現隨身收納的魔法！無...
# 2  https://citiesocial.s3.ap-northeast-1.amazonaw...
#
#                                   product_info_split  \
# 0  ["https://citiesocial.s3.ap-northeast-1.amazon...
# 1  ["", "", "", "", "", "", "", "", "", "", "讓 Ze...
# 2  ["https://citiesocial.s3.ap-northeast-1.amazon...
#
#                                     product_info_ocr  \
# 0  [["Co>^"], [], ["bloin"], [], ["三種鍛鍊效果", "久坐不再...
# 1  [["讓 Zenlet 3 系列為你展現隨身收納的魔法！無論你對錢包使用習慣為何，Zenle...
# 2  [["專利 Mag Disk磁吸止水蓋", "可拆卸且沒有隱藏的細縫'便於清潔", "強大的...
#
#                                 product_info_cleaned  \
# 0  [["三種鍛鍊效果", "久坐不再容易腰痛坐著就在鍛鍊核心", "增強下肢肌肉", "促進血...
# 1  [["讓   系列為你展現隨身收納的魔法無論你對錢包使用習慣為何  系列 的  種規格必有一...
# 2  [["專利  磁吸止水蓋", "可拆卸且沒有隱藏的細縫便於清潔", "強大的磁鐵與矽膠塞配合...
#
#                               product_info_segmented persona  \
# 0  ["三", "種", "鍛鍊", "效果", "久坐", "不再", "容易", "腰", ...  Maggie
# 1  ["讓", "系列", "為", "你", "展現", "隨身", "收納", "的", "...   David
# 2  ["專利", "磁吸", "止水蓋", "可", "拆卸", "且", "沒有", "隱藏"...   David
#
#                                             function  \
# 0  ["增強下肢肌肉", "促進血液循環", "養成挺直坐姿", "修正坐姿", "鍛鍊核心",...
# 1  ["輕觸即展卡", "零錢收納", "鈔票專屬夾層", "磁吸模組變化", "卡片一秒抽換"...
# 2  ["磁吸止水蓋", "輕輕一按即可輕鬆開關", "防漏設計", "強力磁鐵緊密壓縮", "安...
#
#                     material  \
# 0      ["無毒認證布套", "義大利製造內胎"]
# 1  ["鋁合金比肩航太科技", "鋼化抗刮玻璃面板"]
# 2           ["陶瓷塗層", "噴塑塗層"]
#
#                                               design  \
# 0            ["法式輕奢", "絕美手工球椅", "葡萄牙手工縫製", "布料美感設計"]
# 1  ["見不到按鈕或螺絲", "減去不必要的綴飾", "呈現機能之美", "超精密一體成形", ...
# 2                                       ["開放式無死角設計"]
#
#                                           experience   user       scenario  \
# 0  ["久坐不再容易腰痛", "坐著就在鍛鍊核心", "舒適", "容易使用", "背痛減少",...  ["無"]  ["辦公室", "客廳"]
# 1  ["俐落優雅", "聰明生活態度", "避免惱人硬幣聲", "易讀好取", "輕鬆好拿", ...  ["無"]          ["無"]
# 2  ["時尚經典色款", " 人體工學手把", "平滑圓潤", "手把舒適握持", "輕鬆清潔"...  ["無"]          ["無"]
#
#                               limit
# 0  ["citiesocial 全臺獨家引進", "法國防滑球椅"]
# 1                             ["無"]
# 2                             ["無"]

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['product_id_int', 'is_publish_int', 'product_name_str', 'product_features_str', 'product_features_split', 'product_features_cleaned', 'product_features_segmented', 'product_info_str', 'product_info_split', 'product_info_ocr', 'product_info_cleaned', 'product_info_segmented', 'persona', 'function', 'material', 'design', 'experience', 'user', 'scenario', 'limit']

# %% [markdown]
# - Generate output column

# %%
import pandas as pd
import json

def create_json_string(row):
    """Creates a JSON string from a DataFrame row with a specific format."""
    try:
        data = {
            "product_name_str": row["product_name_str"],
            "function": row["function"] if pd.notna(row["function"]) else [],
            "material": row["material"] if pd.notna(row["material"]) else [],
            "design": row["design"] if pd.notna(row["design"]) else [],
            "experience": row["experience"] if pd.notna(row["experience"]) else [],
            "user": row["user"] if pd.notna(row["user"]) else [],
            "scenario": row["scenario"] if pd.notna(row["scenario"]) else [],
            "limit": row["limit"] if pd.notna(row["limit"]) else []
        }
        return json.dumps(data, ensure_ascii=False)  # Handles non-ASCII characters

    except Exception as e:
        print(f"Error creating JSON string: {e}")
        return None  # Or handle the error as needed


# Method 1: Using .apply() (recommended for this task)
df['output'] = df.apply(create_json_string, axis=1)

print(df[['product_name_str', 'function', 'material', 'design', 'experience', 'user', 'scenario', 'limit', 'output']]) # Show the relevant columns

# Example of working with the 'output' column:
for json_str in df['output']:
    if json_str: # Check if the string is not None (in case of errors)
        data = json.loads(json_str) # Parse back to a python dictionary
        print(data['product_name_str']) # Access data within the dictionary
    else:
      print("Error in JSON string.")
# Out:
#            product_name_str  \
# 0      【預購】美型正姿防滑瑜珈球椅 - 常規版
# 1          Zenlet 3 Pro Max
# 2  【初芳宇】ROCKY 翹翹隨行杯 - 500mL
#
#                                             function  \
# 0  ["增強下肢肌肉", "促進血液循環", "養成挺直坐姿", "修正坐姿", "鍛鍊核心",...
# 1  ["輕觸即展卡", "零錢收納", "鈔票專屬夾層", "磁吸模組變化", "卡片一秒抽換"...
# 2  ["磁吸止水蓋", "輕輕一按即可輕鬆開關", "防漏設計", "強力磁鐵緊密壓縮", "安...
#
#                     material  \
# 0      ["無毒認證布套", "義大利製造內胎"]
# 1  ["鋁合金比肩航太科技", "鋼化抗刮玻璃面板"]
# 2           ["陶瓷塗層", "噴塑塗層"]
#
#                                               design  \
# 0            ["法式輕奢", "絕美手工球椅", "葡萄牙手工縫製", "布料美感設計"]
# 1  ["見不到按鈕或螺絲", "減去不必要的綴飾", "呈現機能之美", "超精密一體成形", ...
# 2                                       ["開放式無死角設計"]
#
#                                           experience   user       scenario  \
# 0  ["久坐不再容易腰痛", "坐著就在鍛鍊核心", "舒適", "容易使用", "背痛減少",...  ["無"]  ["辦公室", "客廳"]
# 1  ["俐落優雅", "聰明生活態度", "避免惱人硬幣聲", "易讀好取", "輕鬆好拿", ...  ["無"]          ["無"]
# 2  ["時尚經典色款", " 人體工學手把", "平滑圓潤", "手把舒適握持", "輕鬆清潔"...  ["無"]          ["無"]
#
#                               limit  \
# 0  ["citiesocial 全臺獨家引進", "法國防滑球椅"]
# 1                             ["無"]
# 2                             ["無"]
#
#                                               output
# 0  {"product_name_str": "【預購】美型正姿防滑瑜珈球椅 - 常規版", "...
# 1  {"product_name_str": "Zenlet 3 Pro Max", "func...
# 2  {"product_name_str": "【初芳宇】ROCKY 翹翹隨行杯 - 500mL...
# 【預購】美型正姿防滑瑜珈球椅 - 常規版
# Zenlet 3 Pro Max
# 【初芳宇】ROCKY 翹翹隨行杯 - 500mL

# %% [markdown]
# - Generate source column

# %%
import pandas as pd
import json

def create_source_column(df):
    """Creates 'combine' and 'source' columns in the DataFrame.

    Args:
        df: The input Pandas DataFrame.

    Returns:
        The updated DataFrame, or None if an error occurs.
    """
    try:
        # 1. Create 'combine' column
        df['combine'] = df['product_features_cleaned'].fillna('') + ' ' + df['product_info_cleaned'].fillna('')

        # 2. Create 'source' column
        def create_json_string(row):
            data = {
                "product_name_str": row["product_name_str"],
                "combine": row["combine"]
            }
            return json.dumps(data, ensure_ascii=False)

        df['source'] = df.apply(create_json_string, axis=1)
        return df

    except Exception as e:
        print(f"An error occurred: {e}")
        return None



# Example usage (assuming you have your DataFrame 'df' already):
updated_df = create_source_column(df)

if updated_df is not None:
    print(updated_df[['product_name_str', 'product_features_cleaned', 'product_info_cleaned', 'combine', 'source']])

    # Example of working with the 'source' column:
    for json_str in updated_df['source']:
        if json_str:
            data = json.loads(json_str)
            print(data['product_name_str'], data['combine'])
        else:
            print("Error in JSON string.")
else:
    print("Failed to update DataFrame.")
# Out:
#            product_name_str  \
# 0      【預購】美型正姿防滑瑜珈球椅 - 常規版
# 1          Zenlet 3 Pro Max
# 2  【初芳宇】ROCKY 翹翹隨行杯 - 500mL
#
#                             product_features_cleaned  \
# 0  ["citiesocial 全臺獨家引進歐洲萬人好評支持", "宛如法式輕奢裝潢的瑜珈球椅"...
# 1  ["輕觸即展卡俐落優雅", "一目了然的卡距易讀好取", "十五度卡片仰角輕鬆好拿", "輕...
# 2  ["Mag Disk 磁吸止水蓋只需輕輕一按即可輕鬆開關", "防漏設計強力磁鐵緊密壓縮安心...
#
#                                 product_info_cleaned  \
# 0  [["三種鍛鍊效果", "久坐不再容易腰痛坐著就在鍛鍊核心", "增強下肢肌肉", "促進血...
# 1  [["讓   系列為你展現隨身收納的魔法無論你對錢包使用習慣為何  系列 的  種規格必有一...
# 2  [["專利  磁吸止水蓋", "可拆卸且沒有隱藏的細縫便於清潔", "強大的磁鐵與矽膠塞配合...
#
#                                              combine  \
# 0  ["citiesocial 全臺獨家引進歐洲萬人好評支持", "宛如法式輕奢裝潢的瑜珈球椅"...
# 1  ["輕觸即展卡俐落優雅", "一目了然的卡距易讀好取", "十五度卡片仰角輕鬆好拿", "輕...
# 2  ["Mag Disk 磁吸止水蓋只需輕輕一按即可輕鬆開關", "防漏設計強力磁鐵緊密壓縮安心...
#
#                                               source
# 0  {"product_name_str": "【預購】美型正姿防滑瑜珈球椅 - 常規版", "...
# 1  {"product_name_str": "Zenlet 3 Pro Max", "comb...
# 2  {"product_name_str": "【初芳宇】ROCKY 翹翹隨行杯 - 500mL...
# 【預購】美型正姿防滑瑜珈球椅 - 常規版 ["citiesocial 全臺獨家引進歐洲萬人好評支持", "宛如法式輕奢裝潢的瑜珈球椅", "絕美手工球椅 xa0增強下肢肌肉xa0xa0 xa0自然調整坐姿", "100 歐洲製造葡萄牙手工縫製", "與整骨醫師共同研發人體工學健康椅", "2kg 超輕量還配備手拉腰帶挪動移位毫不累贅", "紡織物無毒認證布套還可拆下丟機洗", "義大利製造內胎結實彈性不漏氣", "內容物美型正姿瑜珈球椅常規版 x 1球椅專用腰帶 x 1打氣筒 x 1"] [["三種鍛鍊效果", "久坐不再容易腰痛坐著就在鍛鍊核心", "增強下肢肌肉", "促進血液循環", "養成挺直坐姿"], ["Giso"], ["Elosn"], ["DISTANCE", "AVEC  BUREAU", "entre vous etle bureau"], ["款風格球椅任選", "大地色", "象牙白", "深邊黑", "炭厭色", "粉彩玫瑰", "松木棕", "巧克力棕", "海軍藍", "淡藍色", "萊姆黃", "清新綠", "石榴紅", "陶木紅", "象厭色", "淡紫色"], ["國外使用者 好評推薦", "Choix sur  site web  liwraison", "jawais teste", "Suite iune hernie discalej", "decide", "essayer  ballon", "prealable  Bon Marche  Paris", "Facture retue", "carje travail assis loho parjourll  permet  faire", "Confort  top", "bouger mon bassin", "importe quel moment    faire", "utiliser progressive ment  partielle ment dans uen", "penser", "gainer mon ventre regulierement  qui aide", "journee car cela fait trawailler pas", "mal  muscle", "renforcement abdominal", "limitertes douleurs", "jambes  bras", "Respecter", "une periode", "dadaptation Sincorpore aussi bien dans mon", "bureau que dans", "mon salon", "自從罹患椎間盤突出後", "我開始試著", "先前在巴黎的展場試坐過", "後來決定", "改坐這款球椅", "從官網下訂", "我每天必須花 個小時坐著辦公", "坐起來相當舒適且很容易使用", "坐球椅時", "開始在白天坐球椅可以鍛鍊到很多", "隨時都可以移動骨盆 拉伸還能不", "肌肉背部 頸部 腿部和手臂", "時提醒我注意收腹", "很適台放在辦公室和客廳", "換成這款球椅後", "讓我能增強鍛鍊腹部肌肉", "並減少腰", "間疼痛", "pour que  tissu soit bien tendu Icomme", "surla noticeljelavais beaucou", "gonfle etil etait trop dur", "pour etre confortable", "beaucoup mieux Concernant les maux  dos", "jai  disque", "pince etje trawaille toute  journee assise", "avais  bon", "siege classique  bureau auparawantIquejlai garde", "siege ballon est tout simplement genial Mon seulement", "alternatiwelJutilise desormais  ballon  quotidien etle", "mon chat nela pas abime", "resultat sur mon mal  dos est incroyable  souffre", "position assise dynamique nous contraint", "beaucoup moins", "Jai reutilise  chaise classique durant", "faire  bien", "dos notamment", "mais fait trawailler", "une matinee etla douleur sest aussitot reveillee", "Donc", "nombreux muscles egalement abdominaux  debut", "ballon pour soulager les maux  dos", "mais  shabitue vite", "faudra refaire  bilan", "Merci pour wotre trawail non seulement  souffre moins", "dans  mois    pourles bienfaits sante", "mais  plus", "est tres beau", "一開始不小心充太多氣球椅變得", "這款球椅實在是太棒", "太硬不好坐後來稍微放氣後就好", "我的貓沒有抓壞牠", "牠的布套實在", "多了", "是太紮實耐用", "我整天必須坐著工作椎間盤壓力", "最重要的是 動態的坐姿使我自動", "太大因此受背痛所苦", "挺直背部", "以前我有一張不錯的辦公椅現在", "也可以同時鍛鍊到肌肉", "尤其是腹", "我換成了這個球椅我的背痛減少", "肌", "了非常多", "開始坐感很特別", "但很快就會坐", "某次嘗試坐回舊式辦公椅背痛馬", "習慣", "上復發", "所以我非常推薦乘坐", "球椅來緩解背痛 不僅舒緩疼痛", "還很好看", "Lop", "Apres"], ["法國防滑球椅", "傳統瑜伽球", "修正坐姿", "鍛鍊核心", "防滑保護", "可調式座椅高度", "移動繫帶", "防變形充氣結構", "布料美感設計"]]
# Zenlet 3 Pro Max ["輕觸即展卡俐落優雅", "一目了然的卡距易讀好取", "十五度卡片仰角輕鬆好拿", "輕鬆感應便利延續"] [["讓   系列為你展現隨身收納的魔法無論你對錢包使用習慣為何  系列 的  種規格必有一款能符合你的需求"], ["不僅減少高達  傳統錢包的體積且無需對容量妥協充分展現你獨特的聰明生活態度"], ["系列 那任何人都能一手掌握的大小使它不僅就手好拿且完全不挑口袋無論西裝牛仔褲外套甚至是襯衫都能輕鬆滑入無負擔"], ["從此展卡只需你一指輕壓剩下由它搞定不儘助你從容應對一切場合更是凸顯你率性風格的絕佳表徵"], ["有別於市面上的卡片夾  系列 給你真正一目了然的清楚卡距一眼辨識你要的卡片"], ["展開後的卡片將自動仰起度貼心的提供了充裕的空間以便輕鬆取卡"], ["拋開老舊的拉鍊扣子與魔鬼沾吧  系列 帶你體驗單手開闔於掌間的獨特魅力"], ["受夠了口袋零錢包發出的惱人噪音嗎有了   系列 的靜音收納設計每當你闔上錢包即享靜音模式盡情擺動也不怕尷尬"], ["鈔票夾層採斜開開口單手即可快速將紙鈔放入固定不管在收納或開啟錢包都能更加安全便利"], ["兩面皆可各別收納一張可直接感應的卡片讓你無論支付還是通勤現在只需一個翻轉面面俱到"], ["其它位於錢包中的卡片依然享有防盜保障"], ["想更換感應卡嗎超簡單現在只要單手一推一放即刻搞定"], ["雙面磁吸式模組化設計讓你的錢包永遠不無聊無論是多樣色彩各種材質還是你最心愛的圖樣隨心變換都只在彈指之間盡情發揮你的想像與創意吧"], ["挑選指南", "Zenlet", "Zenlet", "Zenlet", "Zenlet", "Plus", "Pro", "Pro Max", "零錢收納", "零錢收納", "零錢收納", "零錢收納", "感應模組", "感應模組", "感應模組", "感應模組"], ["更多風格", "亮面銀", "亮面金", "亮面 深紫", "亮面", "太空灰", "霧面 銀", "霧面 金", "霧面", "深紫", "霧面", "六空灰"], ["Zenlef", "Pro Max"], ["為何我們為您重新設計錢包", "更小但是更好"], ["口袋或你手隨身帶著走"], ["觸按即展卡俐落優雅"], ["一目了然的卡距易讀好取"], ["十五度卡片仰角輕鬆好拿"], ["輕推即開闔一氣呵成", "票證支付"], ["靜音收納避免惱人硬幣聲"], ["鈔票專屬夾層"], ["正", "正反都可感應便利延續"], ["卡片一秒抽換毫不費力"], ["磁吸模組變化無限可能", "Ton"], ["見不到按鈕或螺絲", "滿足視覺潔癬"], ["簡約和諧的圓角", "令人百看不厭"], ["減去不必要的綴飾", "呈現機能之美"], ["超精密一體成形", "鋁合金比肩航太科技"], ["鋼化抗刮玻璃面板", "質感耐用兼具"], ["當前款式", "Zenlet", "Zenlet", "Zenlet", "Zenlet", "Plus", "Pro", "Pro Max", "最大容卡數", "直接感應", "安全屏蔽", "感應模組", "靜音收納層"]]
# 【初芳宇】ROCKY 翹翹隨行杯 - 500mL ["Mag Disk 磁吸止水蓋只需輕輕一按即可輕鬆開關", "防漏設計強力磁鐵緊密壓縮安心防漏", "陶瓷塗層疏水陶瓷塗層減少殘留氣味", "輕鬆清潔可拆卸磁吸止水蓋不沾疏水陶瓷塗層和開放式無死角設計輕鬆清潔", "噴塑塗層形成耐刮耐衝擊的堅韌外殼", "雙層真空保溫可保溫6小時保冷12小時最佳的溫度下享用飲品", "人體工學手把平滑圓潤手把舒適握持"] [["專利  磁吸止水蓋", "可拆卸且沒有隱藏的細縫便於清潔", "強大的磁鐵與矽膠塞配合形成防漏密封", "直覺簡易的麴板開關手感超好", "防呆定向磁鐵確保每次安裝都正確", "所有這些像魔法般隱藏在極薄的", "磁吸止水蓋中"], ["一按即開", "一按即關"], ["防漏設計"], ["陶瓷塗層"], ["輕鬆清潔", "今"], ["真空保溫"], ["噴塑塗層"], ["人體工學手把"], ["兩種容量"], ["毫升盎司", "毫升盎司"], ["時尚經典色款"]]

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['product_id_int', 'is_publish_int', 'product_name_str', 'product_features_str', 'product_features_split', 'product_features_cleaned', 'product_features_segmented', 'product_info_str', 'product_info_split', 'product_info_ocr', 'product_info_cleaned', 'product_info_segmented', 'persona', 'function', 'material', 'design', 'experience', 'user', 'scenario', 'limit', 'output', 'combine', 'source']

# %%
import pandas as pd

def write_to_text_file(df, filepath):
    """Writes the 'source' and 'output' columns of a DataFrame to a text file
       in the specified format.

    Args:
        df: The input Pandas DataFrame.
        filepath: The path to the output text file.

    Returns:
        True if the file was written successfully, False otherwise.  Prints error messages.
    """
    try:
        with open(filepath, 'w', encoding='utf-8') as f:  # Open in write mode ('w')
            for index, row in df.iterrows():
                source = row['source']
                output = row['output']

                # Format and write the data:
                f.write(f"input || {source}\n")  # Use f-string for formatting
                f.write(f"output || {output}\n")
                f.write("-" * 20 + "\n") # Separator between entries (optional)

        return True  # Indicate success

    except Exception as e:
        print(f"An error occurred while writing to file: {e}")
        return False


# Example usage:
filepath = '/Users/ytchen/Documents/projects/John/AI_team/analysis/output.txt'
#filepath = 'output.txt'  # Replace with your desired filepath
success = write_to_text_file(df, filepath) # Pass your dataframe `df`

if success:
    print(f"Data successfully written to {filepath}")
else:
    print("Failed to write data to file.")
# Out:
# Data successfully written to /Users/ytchen/Documents/projects/John/AI_team/analysis/output.txt

# %% [markdown]
# ## Few-shot learning

# %% [markdown]
# - Load examples into a string

# %%
def load_text_file(filepath):
    """Loads the content of a text file into a single string.

    Args:
        filepath: The path to the text file.

    Returns:
        The content of the file as a string, or None if an error occurs.
        Prints error message.
    """
    try:
        with open(filepath, 'r', encoding='utf-8') as f:  # Handle encoding
            file_content = f.read()
            return file_content

    except FileNotFoundError:
        print(f"Error: File not found at {filepath}")
        return None
    except Exception as e: # Catch other potential errors (like encoding issues)
        print(f"An error occurred: {e}")
        return None

# Example usage:
#filepath = 'my_text_file.txt'  # Replace with the actual path
filepath = '/Users/ytchen/Documents/projects/John/AI_team/analysis/output.txt'
text_content = load_text_file(filepath)

if text_content is not None:
    print(text_content)
    # Now you can work with the string 'text_content'
    # Example: print the first 100 characters
    print(text_content[:100])
else:
    print("Failed to load text file.")
# Out:
# input || {"product_name_str": "【預購】美型正姿防滑瑜珈球椅 - 常規版", "combine": "[\"citiesocial 全臺獨家引進歐洲萬人好評支持\", \"宛如法式輕奢裝潢的瑜珈球椅\", \"絕美手工球椅 xa0增強下肢肌肉xa0xa0 xa0自然調整坐姿\", \"100 歐洲製造葡萄牙手工縫製\", \"與整骨醫師共同研發人體工學健康椅\", \"2kg 超輕量還配備手拉腰帶挪動移位毫不累贅\", \"紡織物無毒認證布套還可拆下丟機洗\", \"義大利製造內胎結實彈性不漏氣\", \"內容物美型正姿瑜珈球椅常規版 x 1球椅專用腰帶 x 1打氣筒 x 1\"] [[\"三種鍛鍊效果\", \"久坐不再容易腰痛坐著就在鍛鍊核心\", \"增強下肢肌肉\", \"促進血液循環\", \"養成挺直坐姿\"], [\"Giso\"], [\"Elosn\"], [\"DISTANCE\", \"AVEC  BUREAU\", \"entre vous etle bureau\"], [\"款風格球椅任選\", \"大地色\", \"象牙白\", \"深邊黑\", \"炭厭色\", \"粉彩玫瑰\", \"松木棕\", \"巧克力棕\", \"海軍藍\", \"淡藍色\", \"萊姆黃\", \"清新綠\", \"石榴紅\", \"陶木紅\", \"象厭色\", \"淡紫色\"], [\"國外使用者 好評推薦\", \"Choix sur  site web  liwraison\", \"jawais teste\", \"Suite iune hernie discalej\", \"decide\", \"essayer  ballon\", \"prealable  Bon Marche  Paris\", \"Facture retue\", \"carje travail assis loho parjourll  permet  faire\", \"Confort  top\", \"bouger mon bassin\", \"importe quel moment    faire\", \"utiliser progressive ment  partielle ment dans uen\", \"penser\", \"gainer mon ventre regulierement  qui aide\", \"journee car cela fait trawailler pas\", \"mal  muscle\", \"renforcement abdominal\", \"limitertes douleurs\", \"jambes  bras\", \"Respecter\", \"une periode\", \"dadaptation Sincorpore aussi bien dans mon\", \"bureau que dans\", \"mon salon\", \"自從罹患椎間盤突出後\", \"我開始試著\", \"先前在巴黎的展場試坐過\", \"後來決定\", \"改坐這款球椅\", \"從官網下訂\", \"我每天必須花 個小時坐著辦公\", \"坐起來相當舒適且很容易使用\", \"坐球椅時\", \"開始在白天坐球椅可以鍛鍊到很多\", \"隨時都可以移動骨盆 拉伸還能不\", \"肌肉背部 頸部 腿部和手臂\", \"時提醒我注意收腹\", \"很適台放在辦公室和客廳\", \"換成這款球椅後\", \"讓我能增強鍛鍊腹部肌肉\", \"並減少腰\", \"間疼痛\", \"pour que  tissu soit bien tendu Icomme\", \"surla noticeljelavais beaucou\", \"gonfle etil etait trop dur\", \"pour etre confortable\", \"beaucoup mieux Concernant les maux  dos\", \"jai  disque\", \"pince etje trawaille toute  journee assise\", \"avais  bon\", \"siege classique  bureau auparawantIquejlai garde\", \"siege ballon est tout simplement genial Mon seulement\", \"alternatiwelJutilise desormais  ballon  quotidien etle\", \"mon chat nela pas abime\", \"resultat sur mon mal  dos est incroyable  souffre\", \"position assise dynamique nous contraint\", \"beaucoup moins\", \"Jai reutilise  chaise classique durant\", \"faire  bien\", \"dos notamment\", \"mais fait trawailler\", \"une matinee etla douleur sest aussitot reveillee\", \"Donc\", \"nombreux muscles egalement abdominaux  debut\", \"ballon pour soulager les maux  dos\", \"mais  shabitue vite\", \"faudra refaire  bilan\", \"Merci pour wotre trawail non seulement  souffre moins\", \"dans  mois    pourles bienfaits sante\", \"mais  plus\", \"est tres beau\", \"一開始不小心充太多氣球椅變得\", \"這款球椅實在是太棒\", \"太硬不好坐後來稍微放氣後就好\", \"我的貓沒有抓壞牠\", \"牠的布套實在\", \"多了\", \"是太紮實耐用\", \"我整天必須坐著工作椎間盤壓力\", \"最重要的是 動態的坐姿使我自動\", \"太大因此受背痛所苦\", \"挺直背部\", \"以前我有一張不錯的辦公椅現在\", \"也可以同時鍛鍊到肌肉\", \"尤其是腹\", \"我換成了這個球椅我的背痛減少\", \"肌\", \"了非常多\", \"開始坐感很特別\", \"但很快就會坐\", \"某次嘗試坐回舊式辦公椅背痛馬\", \"習慣\", \"上復發\", \"所以我非常推薦乘坐\", \"球椅來緩解背痛 不僅舒緩疼痛\", \"還很好看\", \"Lop\", \"Apres\"], [\"法國防滑球椅\", \"傳統瑜伽球\", \"修正坐姿\", \"鍛鍊核心\", \"防滑保護\", \"可調式座椅高度\", \"移動繫帶\", \"防變形充氣結構\", \"布料美感設計\"]]"}
# output || {"product_name_str": "【預購】美型正姿防滑瑜珈球椅 - 常規版", "function": "[\"增強下肢肌肉\", \"促進血液循環\", \"養成挺直坐姿\", \"修正坐姿\", \"鍛鍊核心\", \"防滑保護\", \"可調式座椅高度\", \"移動繫帶\", \"防變形充氣結構\"]", "material": "[\"無毒認證布套\", \"義大利製造內胎\"]", "design": "[\"法式輕奢\", \"絕美手工球椅\", \"葡萄牙手工縫製\", \"布料美感設計\"]", "experience": "[\"久坐不再容易腰痛\", \"坐著就在鍛鍊核心\", \"舒適\", \"容易使用\", \"背痛減少\", \"減少腰間疼痛\", \"紮實耐用\", \"坐感很特別\", \"緩解背痛\", \"舒緩疼痛\"]", "user": "[\"無\"]", "scenario": "[\"辦公室\", \"客廳\"]", "limit": "[\"citiesocial 全臺獨家引進\", \"法國防滑球椅\"]"}
# --------------------
# input || {"product_name_str": "Zenlet 3 Pro Max", "combine": "[\"輕觸即展卡俐落優雅\", \"一目了然的卡距易讀好取\", \"十五度卡片仰角輕鬆好拿\", \"輕鬆感應便利延續\"] [[\"讓   系列為你展現隨身收納的魔法無論你對錢包使用習慣為何  系列 的  種規格必有一款能符合你的需求\"], [\"不僅減少高達  傳統錢包的體積且無需對容量妥協充分展現你獨特的聰明生活態度\"], [\"系列 那任何人都能一手掌握的大小使它不僅就手好拿且完全不挑口袋無論西裝牛仔褲外套甚至是襯衫都能輕鬆滑入無負擔\"], [\"從此展卡只需你一指輕壓剩下由它搞定不儘助你從容應對一切場合更是凸顯你率性風格的絕佳表徵\"], [\"有別於市面上的卡片夾  系列 給你真正一目了然的清楚卡距一眼辨識你要的卡片\"], [\"展開後的卡片將自動仰起度貼心的提供了充裕的空間以便輕鬆取卡\"], [\"拋開老舊的拉鍊扣子與魔鬼沾吧  系列 帶你體驗單手開闔於掌間的獨特魅力\"], [\"受夠了口袋零錢包發出的惱人噪音嗎有了   系列 的靜音收納設計每當你闔上錢包即享靜音模式盡情擺動也不怕尷尬\"], [\"鈔票夾層採斜開開口單手即可快速將紙鈔放入固定不管在收納或開啟錢包都能更加安全便利\"], [\"兩面皆可各別收納一張可直接感應的卡片讓你無論支付還是通勤現在只需一個翻轉面面俱到\"], [\"其它位於錢包中的卡片依然享有防盜保障\"], [\"想更換感應卡嗎超簡單現在只要單手一推一放即刻搞定\"], [\"雙面磁吸式模組化設計讓你的錢包永遠不無聊無論是多樣色彩各種材質還是你最心愛的圖樣隨心變換都只在彈指之間盡情發揮你的想像與創意吧\"], [\"挑選指南\", \"Zenlet\", \"Zenlet\", \"Zenlet\", \"Zenlet\", \"Plus\", \"Pro\", \"Pro Max\", \"零錢收納\", \"零錢收納\", \"零錢收納\", \"零錢收納\", \"感應模組\", \"感應模組\", \"感應模組\", \"感應模組\"], [\"更多風格\", \"亮面銀\", \"亮面金\", \"亮面 深紫\", \"亮面\", \"太空灰\", \"霧面 銀\", \"霧面 金\", \"霧面\", \"深紫\", \"霧面\", \"六空灰\"], [\"Zenlef\", \"Pro Max\"], [\"為何我們為您重新設計錢包\", \"更小但是更好\"], [\"口袋或你手隨身帶著走\"], [\"觸按即展卡俐落優雅\"], [\"一目了然的卡距易讀好取\"], [\"十五度卡片仰角輕鬆好拿\"], [\"輕推即開闔一氣呵成\", \"票證支付\"], [\"靜音收納避免惱人硬幣聲\"], [\"鈔票專屬夾層\"], [\"正\", \"正反都可感應便利延續\"], [\"卡片一秒抽換毫不費力\"], [\"磁吸模組變化無限可能\", \"Ton\"], [\"見不到按鈕或螺絲\", \"滿足視覺潔癬\"], [\"簡約和諧的圓角\", \"令人百看不厭\"], [\"減去不必要的綴飾\", \"呈現機能之美\"], [\"超精密一體成形\", \"鋁合金比肩航太科技\"], [\"鋼化抗刮玻璃面板\", \"質感耐用兼具\"], [\"當前款式\", \"Zenlet\", \"Zenlet\", \"Zenlet\", \"Zenlet\", \"Plus\", \"Pro\", \"Pro Max\", \"最大容卡數\", \"直接感應\", \"安全屏蔽\", \"感應模組\", \"靜音收納層\"]]"}
# output || {"product_name_str": "Zenlet 3 Pro Max", "function": "[\"輕觸即展卡\", \"零錢收納\", \"鈔票專屬夾層\", \"磁吸模組變化\", \"卡片一秒抽換\", \"正反都可感應\", \"靜音收納, \"隨身收納\", \"防盜\", \"直接感應\", \"安全屏蔽\"]", "material": "[\"鋁合金比肩航太科技\", \"鋼化抗刮玻璃面板\"]", "design": "[\"見不到按鈕或螺絲\", \"減去不必要的綴飾\", \"呈現機能之美\", \"超精密一體成形\", \"率性風格\"]", "experience": "[\"俐落優雅\", \"聰明生活態度\", \"避免惱人硬幣聲\", \"易讀好取\", \"輕鬆好拿\", \"輕鬆感應便利延續\", \"毫不費力\", \"輕鬆滑入無負擔\", \"輕鬆取卡\", \"盡情擺動也不怕尷尬\", \"安全便利\", \"簡約和諧\", \"質感耐用兼具\"]", "user": "[\"無\"]", "scenario": "[\"無\"]", "limit": "[\"無\"]"}
# --------------------
# input || {"product_name_str": "【初芳宇】ROCKY 翹翹隨行杯 - 500mL", "combine": "[\"Mag Disk 磁吸止水蓋只需輕輕一按即可輕鬆開關\", \"防漏設計強力磁鐵緊密壓縮安心防漏\", \"陶瓷塗層疏水陶瓷塗層減少殘留氣味\", \"輕鬆清潔可拆卸磁吸止水蓋不沾疏水陶瓷塗層和開放式無死角設計輕鬆清潔\", \"噴塑塗層形成耐刮耐衝擊的堅韌外殼\", \"雙層真空保溫可保溫6小時保冷12小時最佳的溫度下享用飲品\", \"人體工學手把平滑圓潤手把舒適握持\"] [[\"專利  磁吸止水蓋\", \"可拆卸且沒有隱藏的細縫便於清潔\", \"強大的磁鐵與矽膠塞配合形成防漏密封\", \"直覺簡易的麴板開關手感超好\", \"防呆定向磁鐵確保每次安裝都正確\", \"所有這些像魔法般隱藏在極薄的\", \"磁吸止水蓋中\"], [\"一按即開\", \"一按即關\"], [\"防漏設計\"], [\"陶瓷塗層\"], [\"輕鬆清潔\", \"今\"], [\"真空保溫\"], [\"噴塑塗層\"], [\"人體工學手把\"], [\"兩種容量\"], [\"毫升盎司\", \"毫升盎司\"], [\"時尚經典色款\"]]"}
# output || {"product_name_str": "【初芳宇】ROCKY 翹翹隨行杯 - 500mL", "function": "[\"磁吸止水蓋\", \"輕輕一按即可輕鬆開關\", \"防漏設計\", \"強力磁鐵緊密壓縮\", \"安心防漏\", \"雙層真空保溫\", \"可保溫6小時\", \"保冷12小時\", \"減少殘留氣味\", \"耐刮\", \"耐衝擊\", \"防漏密封\"]", "material": "[\"陶瓷塗層\", \"噴塑塗層\"]", "design": "[\"開放式無死角設計\"]", "experience": "[\"時尚經典色款\", \" 人體工學手把\", \"平滑圓潤\", \"手把舒適握持\", \"輕鬆清潔\", \"手感超好\"]", "user": "[\"無\"]", "scenario": "[\"無\"]", "limit": "[\"無\"]"}
# --------------------
#
# input || {"product_name_str": "【預購】美型正姿防滑瑜珈球椅 - 常規版", "combine": "[\"citiesocial 全臺獨家引進歐洲萬人好評支持\", \

# %% [markdown]
# - Load source file

# %%
import pandas as pd

filepath = '/Users/ytchen/Documents/projects/John/AI_team/analysis/product_sample_removed_20250218.csv'

try:
  df = pd.read_csv(filepath)
  print(df)
  # Access data:
  # print(df['column_name'])
except FileNotFoundError:
  print("File not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
#     new_category         parent_product_name_str  \
# 0         119546             10 in 1 百變手機支架 - 黑色
# 1         118432            拍照快點翻譯機 WM-T29W+專用皮套
# 2         121241          【特惠組】磁吸無線萬用充+磁吸100W捲捲線
# 3         123022    Superthin極度輕薄・磁吸行動電源10000mAh
# 4         124778           【預購】雲朵系六合一 磁吸無線快充行動電源
# ..           ...                             ...
# 95        118977                  舉杯低卡蒟蒻凍2盒組12根入
# 96        120158              西班牙油漆桶馬鈴薯片(原味)500g
# 97        122928  32MM 國際電壓水潤負離子溫控捲髮器(MR.Curler)
# 98        123686                    芬蘭天然冷熱護理按摩石組
# 99        122820            溫感空氣髮根蓬蓬熱風梳(MR.7374)
#
#                              product_features_cleaned  \
# 0   ["徹底顛覆對手機配件的想像", "citiesocial 全臺獨家只有這裡有", "只有卡...
# 1   ["語音文字雙向翻譯自動播放翻譯後的外語學會外語精準發音", "拍照就能翻譯文字菜單路標簡單...
# 2   ["可無線為手機Air PodsApple Watch等電子產品充電", "可同時使用無線與...
# 3   ["隨身攜帶無負擔體積重量減半", "極輕薄外型完美貼合手機", "穩固磁吸充電不會輕易脫落...
# 4   ["小小一顆好攜帶電力滿滿不間斷", "多功磁吸無線充手機耳機Apple Watch都適用"...
# ..                                                ...
# 95  ["CheersJelly低卡輕食首選", "馥郁果香Ｑ彈微脆感", "獨家不沾手杯身設計"...
# 96  ["馬鈴薯片界的愛馬仕", "西班牙原裝進口", "真材實料無化學添加物", "純素食者適用...
# 97  ["自動雙向捲髮輕鬆解決初學者困擾", "2000萬潤髮負離子", "3檔溫控自由調節", ...
# 98  ["芬蘭當地純天然石材製成擁有卓越的蓄熱和導熱性", "可依不同情境使用達到冷熱雙重按摩效果...
# 99  ["梳子吹風機2in1告別油扁軟塌髮", "雙齒梳熱風氣孔打造豐盈柔順感", "3段溫控因應...
#
#                                  product_info_cleaned
# 0   [["STANCE"], ["儿", "仆", "化"], ["Watch"], ["卜器"...
# 1   [["拍照快點翮譯機", "訃刈", "二儿二芍", "Hola", "Wonpe", "你...
# 2   [["黑", "莫蘭迪粉紅", "莫蘭迪綠", "莫蘭迪白", "莫蘭迪紫", "莫蘭迪灰"...
# 3   [["贈", "觸控調光印", "護眼檯燈"], ["亂買隊長", "逼伊恩恩歪", "出門...
# 4   [["雲朵係", "六合一磁吸快充", "行動電源", "減重減積 輕量便攜", "磁吸無線...
# ..                                                ...
# 95  [["CHEERSJELLY", "百香", "句弱", "藏 役", "兮味更佳", "葡...
# 96  [["日"], ["ala virta", "poflla alawini", "Fil",...
# 97  [["水潤負離子", "溫控捲髮器", "Curler", "香", "獨家", "發售",...
# 98  [["HukfA DLSiGi", "HUEEA pESiGN", "HufEA DESIG...
# 99  [["NUNICHI", "卞", "溫感", "空氣熱風梳", "告別扁塌問題打造豐盈柔順...
#
# [100 rows x 4 columns]

# %% [markdown]
# - Format source file

# %%
# Rename one column
df = df.rename(columns={'parent_product_name_str': 'product_name_str'})

# %%
# Example usage (assuming you have your DataFrame 'df' already):
updated_df = create_source_column(df)

if updated_df is not None:
    print(updated_df[['product_name_str', 'product_features_cleaned', 'product_info_cleaned', 'combine', 'source']])

    # Example of working with the 'source' column:
    for json_str in updated_df['source']:
        if json_str:
            data = json.loads(json_str)
            #print(data['product_name_str'], data['combine'])
        else:
            print("Error in JSON string.")
else:
    print("Failed to update DataFrame.")
# Out:
#                   product_name_str  \
# 0              10 in 1 百變手機支架 - 黑色
# 1             拍照快點翻譯機 WM-T29W+專用皮套
# 2           【特惠組】磁吸無線萬用充+磁吸100W捲捲線
# 3     Superthin極度輕薄・磁吸行動電源10000mAh
# 4            【預購】雲朵系六合一 磁吸無線快充行動電源
# ..                             ...
# 95                  舉杯低卡蒟蒻凍2盒組12根入
# 96              西班牙油漆桶馬鈴薯片(原味)500g
# 97  32MM 國際電壓水潤負離子溫控捲髮器(MR.Curler)
# 98                    芬蘭天然冷熱護理按摩石組
# 99            溫感空氣髮根蓬蓬熱風梳(MR.7374)
#
#                              product_features_cleaned  \
# 0   ["徹底顛覆對手機配件的想像", "citiesocial 全臺獨家只有這裡有", "只有卡...
# 1   ["語音文字雙向翻譯自動播放翻譯後的外語學會外語精準發音", "拍照就能翻譯文字菜單路標簡單...
# 2   ["可無線為手機Air PodsApple Watch等電子產品充電", "可同時使用無線與...
# 3   ["隨身攜帶無負擔體積重量減半", "極輕薄外型完美貼合手機", "穩固磁吸充電不會輕易脫落...
# 4   ["小小一顆好攜帶電力滿滿不間斷", "多功磁吸無線充手機耳機Apple Watch都適用"...
# ..                                                ...
# 95  ["CheersJelly低卡輕食首選", "馥郁果香Ｑ彈微脆感", "獨家不沾手杯身設計"...
# 96  ["馬鈴薯片界的愛馬仕", "西班牙原裝進口", "真材實料無化學添加物", "純素食者適用...
# 97  ["自動雙向捲髮輕鬆解決初學者困擾", "2000萬潤髮負離子", "3檔溫控自由調節", ...
# 98  ["芬蘭當地純天然石材製成擁有卓越的蓄熱和導熱性", "可依不同情境使用達到冷熱雙重按摩效果...
# 99  ["梳子吹風機2in1告別油扁軟塌髮", "雙齒梳熱風氣孔打造豐盈柔順感", "3段溫控因應...
#
#                                  product_info_cleaned  \
# 0   [["STANCE"], ["儿", "仆", "化"], ["Watch"], ["卜器"...
# 1   [["拍照快點翮譯機", "訃刈", "二儿二芍", "Hola", "Wonpe", "你...
# 2   [["黑", "莫蘭迪粉紅", "莫蘭迪綠", "莫蘭迪白", "莫蘭迪紫", "莫蘭迪灰"...
# 3   [["贈", "觸控調光印", "護眼檯燈"], ["亂買隊長", "逼伊恩恩歪", "出門...
# 4   [["雲朵係", "六合一磁吸快充", "行動電源", "減重減積 輕量便攜", "磁吸無線...
# ..                                                ...
# 95  [["CHEERSJELLY", "百香", "句弱", "藏 役", "兮味更佳", "葡...
# 96  [["日"], ["ala virta", "poflla alawini", "Fil",...
# 97  [["水潤負離子", "溫控捲髮器", "Curler", "香", "獨家", "發售",...
# 98  [["HukfA DLSiGi", "HUEEA pESiGN", "HufEA DESIG...
# 99  [["NUNICHI", "卞", "溫感", "空氣熱風梳", "告別扁塌問題打造豐盈柔順...
#
#                                               combine  \
# 0   ["徹底顛覆對手機配件的想像", "citiesocial 全臺獨家只有這裡有", "只有卡...
# 1   ["語音文字雙向翻譯自動播放翻譯後的外語學會外語精準發音", "拍照就能翻譯文字菜單路標簡單...
# 2   ["可無線為手機Air PodsApple Watch等電子產品充電", "可同時使用無線與...
# 3   ["隨身攜帶無負擔體積重量減半", "極輕薄外型完美貼合手機", "穩固磁吸充電不會輕易脫落...
# 4   ["小小一顆好攜帶電力滿滿不間斷", "多功磁吸無線充手機耳機Apple Watch都適用"...
# ..                                                ...
# 95  ["CheersJelly低卡輕食首選", "馥郁果香Ｑ彈微脆感", "獨家不沾手杯身設計"...
# 96  ["馬鈴薯片界的愛馬仕", "西班牙原裝進口", "真材實料無化學添加物", "純素食者適用...
# 97  ["自動雙向捲髮輕鬆解決初學者困擾", "2000萬潤髮負離子", "3檔溫控自由調節", ...
# 98  ["芬蘭當地純天然石材製成擁有卓越的蓄熱和導熱性", "可依不同情境使用達到冷熱雙重按摩效果...
# 99  ["梳子吹風機2in1告別油扁軟塌髮", "雙齒梳熱風氣孔打造豐盈柔順感", "3段溫控因應...
#
#                                                source
# 0   {"product_name_str": "10 in 1 百變手機支架 - 黑色", "c...
# 1   {"product_name_str": "拍照快點翻譯機 WM-T29W+專用皮套", "...
# 2   {"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線",...
# 3   {"product_name_str": "Superthin極度輕薄・磁吸行動電源1000...
# 4   {"product_name_str": "【預購】雲朵系六合一 磁吸無線快充行動電源", ...
# ..                                                ...
# 95  {"product_name_str": "舉杯低卡蒟蒻凍2盒組12根入", "combin...
# 96  {"product_name_str": "西班牙油漆桶馬鈴薯片(原味)500g", "co...
# 97  {"product_name_str": "32MM 國際電壓水潤負離子溫控捲髮器(MR.C...
# 98  {"product_name_str": "芬蘭天然冷熱護理按摩石組", "combine"...
# 99  {"product_name_str": "溫感空氣髮根蓬蓬熱風梳(MR.7374)", "...
#
# [100 rows x 5 columns]

# %% [markdown]
# - Prepare user message in prompt

# %%
source_content = 'input||' + updated_df.loc[0, 'source'] + '\n'
print(source_content)
# Out:
# input||{"product_name_str": "10 in 1 百變手機支架 - 黑色", "combine": "[\"徹底顛覆對手機配件的想像\", \"citiesocial 全臺獨家只有這裡有\", \"只有卡片大小卻有超多變化\", \"結合超多支架立架車用磁吸手持\", \"連桿子都能輕易吊掛固定\", \"一貼即吸極度好用無負擔\", \"附有黏貼式磁環任何廠牌手機都適用  因摺疊機特性建議於展開且垂直放置的情況下使用 \", \"宅家追劇旅行拍攝工作展示日常滑手機\", \"內容物10 in 1 百變手機支架 x 1專用磁環 x 1重複貼金屬片 x 1\", \"注意事項實際商品會於表面貼上一層輕薄的保護膜形成半透明的霧面感對使用上無影響建議盡量避免撕除以免影響磁吸設計的效果\"] [[\"STANCE\"], [\"儿\", \"仆\", \"化\"], [\"Watch\"], [\"卜器\", \"Vent MountIt\"], [\"MountIt\"], [\"口\"], [\"叫\", \"IAF\"], [\"Dimensions\", \"Magnetic\", \"Base\"]]"}

# %%
provider = "openai"
model_id = "gpt-4o-mini"

delimiter = "--------------------"

system_message = f"""
您是一位電子商務領域的產品標籤專家。請你負責萃取產品標籤。 
產品標籤分為以下幾類： 
1. 功能 (function)：指產品提供的實際用途與便利性，能提升使用體驗或解決特定問題。例如：一鍵收納、空間改造、防風 
2. 材質 (material)：強調產品使用的原料特性。例如：環保材質、溫潤質感、親膚 
3. 設計理念 (design)：側重於設計的概念、風格、創意來源，著重產品的美學、創意、工藝等層面，展現設計師的想法與 技術。例如：獨特設計、工藝、簡約美學 
4. 使用感受 (experience)：側重於使用時的體驗、情感與價值感，著重消費者在使用產品時的舒適度、實用性與生活品質提升。例如：低調、奢華、精緻生活 
5. 使用對象 (user)：標示適用族群，確保產品符合特定人群的需求。例如：全家適用、親子友好、不分男女 
6. 使用場合 (scenario)：產品適合的使用情境，包含產品使用的時機、地點、事件。例如：情人節、戶外、通勤 
7. 產品或品牌限定 (limit)：凸顯產品或品牌的獨特性與稀缺性。例如：限量、大師聯名、收藏級 

禁止定義常見產品標籤後查找，並將尺寸、換行符號、型號、\、/、n、"、[、]、低於但不等於兩個字的字串移除。 
產品標籤必須完全按照原字樣出現在產品敘述中，禁止改寫標籤內容。 
產品標籤限 10 字以內。 
產品敘述不一定會包含每一類的產品標籤，若沒有出現該類標籤，請填無。 

請參考範例{text_content}
這裡有三個範例，以 {delimiter} 分隔。
每個範例都有input和output。
您將根據範例所示，從input產生output。
"""

user_message = f"""\
{source_content}
請用中文回答。
"""

messages =  [  
{'role':'system', 'content': system_message},    
#{'role':'user', 'content': f"{delimiter}{user_message}{delimiter}"},  
{'role':'user', 'content': user_message},  
] 

response = client.chat.completions.create(
    model=f"{provider}:{model_id}",
    messages=messages,
    temperature=0.0
)
print(response.choices[0].message.content)
# Out:
# output || {"product_name_str": "10 in 1 百變手機支架 - 黑色", "function": "[\"超多變化\", \"結合超多支架\", \"車用磁吸手持\", \"輕易吊掛固定\", \"極度好用無負擔\", \"任何廠牌手機都適用\"]", "material": "[\"無\"]", "design": "[\"卡片大小\"]", "experience": "[\"徹底顛覆對手機配件的想像\", \"宅家追劇\", \"旅行拍攝\", \"工作展示\", \"日常滑手機\"]", "user": "[\"無\"]", "scenario": "[\"無\"]", "limit": "[\"citiesocial 全臺獨家\"]"}

# %% [markdown]
# - Loop thru

# %%
ret = []
for i in range(3):
    print(i)
    source_content = 'input||' + updated_df.loc[i, 'source'] + '\n'
    user_message = f"""{source_content} 請用中文回答。"""
    messages =  [ {'role':'system', 'content': system_message}, 
                 {'role':'user', 'content': user_message}, 
                ] 
    response = client.chat.completions.create(
        model=f"{provider}:{model_id}",
        messages=messages,
        temperature=0.0
    )
    result = response.choices[0].message.content
    ret.append(result)
    pp(source_content)
    pp(delimiter)
    pp(result)
# Out:
# 0
# ('input||{"product_name_str": "10 in 1 百變手機支架 - 黑色", "combine": '
#  '"[\\"徹底顛覆對手機配件的想像\\", \\"citiesocial 全臺獨家只有這裡有\\", \\"只有卡片大小卻有超多變化\\", '
#  '\\"結合超多支架立架車用磁吸手持\\", \\"連桿子都能輕易吊掛固定\\", \\"一貼即吸極度好用無負擔\\", '
#  '\\"附有黏貼式磁環任何廠牌手機都適用  因摺疊機特性建議於展開且垂直放置的情況下使用 \\", \\"宅家追劇旅行拍攝工作展示日常滑手機\\", '
#  '\\"內容物10 in 1 百變手機支架 x 1專用磁環 x 1重複貼金屬片 x 1\\", '
#  '\\"注意事項實際商品會於表面貼上一層輕薄的保護膜形成半透明的霧面感對使用上無影響建議盡量避免撕除以免影響磁吸設計的效果\\"] '
#  '[[\\"STANCE\\"], [\\"儿\\", \\"仆\\", \\"化\\"], [\\"Watch\\"], [\\"卜器\\", '
#  '\\"Vent MountIt\\"], [\\"MountIt\\"], [\\"口\\"], [\\"叫\\", \\"IAF\\"], '
#  '[\\"Dimensions\\", \\"Magnetic\\", \\"Base\\"]]"}\n')
# '--------------------'
# ('output || {"product_name_str": "10 in 1 百變手機支架 - 黑色", "function": '
#  '"[\\"超多變化\\", \\"結合超多支架\\", \\"車用磁吸手持\\", \\"輕易吊掛固定\\", \\"極度好用無負擔\\"]", '
#  '"material": "[\\"無\\"]", "design": "[\\"卡片大小\\"]", "experience": '
#  '"[\\"徹底顛覆對手機配件的想像\\", \\"宅家追劇\\", \\"旅行拍攝\\", \\"工作展示\\", \\"日常滑手機\\"]", '
#  '"user": "[\\"無\\"]", "scenario": "[\\"無\\"]", "limit": "[\\"citiesocial '
#  '全臺獨家\\"]"}')
# 1
# ('input||{"product_name_str": "拍照快點翻譯機 WM-T29W+專用皮套", "combine": '
#  '"[\\"語音文字雙向翻譯自動播放翻譯後的外語學會外語精準發音\\", \\"拍照就能翻譯文字菜單路標簡單看得懂支援超過７０種連網互譯\\", '
#  '\\"超過100種國家語言60 種地區口音讓你在語言的世界暢行無阻\\", \\"第三方APP適用無需複製貼上APP間自由切換\\", '
#  '\\"語音輸入精準辯讀正確率完勝手機內建連繞口令都能完美轉譯\\", \\"精準的語音輸入系統高效率輸入每分鐘約200字\\", '
#  '\\"開啟對話模式完整記錄每一句對話\\", \\"原文譯文同步顯示原文翻譯一起呈現不怕翻錯好尷尬\\", \\"超高續航力可以連續翻譯 '
#  '10hr\\", \\"超輕盈重量15G帶著完全沒有負擔\\", \\"邊充邊用支援可邊充邊用溝通不斷線\\", '
#  '\\"標點符號依說話語義自動加入標點符號\\"] [[\\"拍照快點翮譯機\\", \\"訃刈\\", \\"二儿二芍\\", \\"Hola\\", '
#  '\\"Wonpe\\", \\"你好\\"], [\\"按一下翮譯全世界\\", \\"多國互譯\\", \\"拍照翮譯\\", \\"雙語同顯\\", '
#  '\\"語音打字\\", \\"種語言\\", \\"自動播報\\", \\"自動產出\\", \\"台灣語意\\", \\"標點符號\\", '
#  '\\"翮譯資料庫\\"], [\\"我想要一杯熱的\\", \\"焦糖瑪奇朵\\", \\"語音輸入 直接翮譯\\", \\"只需要對手機說話\\", '
#  '\\"輕鬆翮譯外語\\", \\"讓你一秒理解\\", \\"打開全球眼界\\"], [\\"眾多網友\\", \\"好評推薦\\", '
#  '\\"剛剛收試\\", \\"比起以前的翮譯機方便好用太多\\", \\"了翮譯很快主要是第三方軟體也支援\\", \\"開車不用\\", '
#  '\\"手忙腳亂與近期到臺灣的旅客溝通無障礙一次\\", \\"買了兩個慶幸買到有用的\\", \\"也可以邊學習語言\\", '
#  '\\"不會詞不達意亂翮譯一通\\", \\"谷不敢用鬧笑話了真\\", \\"的不錯用\\", \\"真的不錯用\\"], [\\"精準的\\", '
#  '\\"語音輸入係統\\", \\"蘭\\", \\"內建語音輸入\\", \\"快點翮譯機\\", \\"連繞口令都能聽得懂\\", '
#  '\\"正確率完勝手機內建系統\\", \\"James\\", \\"James\\", \\"You\\", \\"和尚端湯\\", '
#  '\\"和尚端湯上塔塔\\", \\"國語\\", \\"滑湯灑踏踏踏\\", \\"滑湯灑湯燙塔\\", \\"我 哈 好 對 貞\\", \\"我 哈 '
#  '好 對 直\\", \\"另\\", \\"女 七\\", \\"夕\\"], [\\"三\\", \\"標點符號\\", \\"也能正確呈現\\", '
#  '\\"James\\", \\"飛機預計下午\\", \\"抵達 我們\\", \\"總共個人請安\\", \\"排合適的車輛來接\\", '
#  '\\"我們謝謝\\", \\"我 哈 好 對 真的 因為\\", \\"巳虫\\"], [\\"能語音輸入 為何要手打\\", \\"有時候真的\\", '
#  '\\"騰不出手打字\\", \\"語音輸入\\", \\"直接轉成翮譯文字\\"], [\\"巳\\", \\"中\\", \\"高效率輸\\", '
#  '\\"每分鐘輸入\\", \\"孛\\", \\"手打輸入\\", \\"語音輸入\\", \\"每分鐘約字\\", \\"每分鐘約 字\\", '
#  '\\"齣入文字\\", \\"咭鹵\\", \\"琦吊\\"], [\\"不需要複製貼上\\", \\"任何第三方軟體都適用\\", \\"交友\\", '
#  '\\"記事本\\", \\"搜尋引擎\\", \\"LNE\\"], [\\"未使用快點翮譯機\\", \\"使用快點翮譯機\\", \\"蚩\\", '
#  '\\"上\\", \\"捆\\", \\"逗\\", \\"奸\\", \\"省下的時間\\", \\"比你想得更多\\", \\"更彈性\\", '
#  '\\"更自由\\", \\"七\\", \\"王蜚面\\", \\"好的一\\", \\"OKP\\", \\"垚\\", \\"喃喃\\"], '
#  '[\\"語音\\", \\"文字都能\\", \\"雙向二翮譯\\", \\"自動播報翮譯後的外語\\", \\"學會外語精準發音\\"], '
#  '[\\"一鍵拍照\\", \\"圖片內容立即呈現\\", \\"LUNCH\\", \\"Eggpint\\", \\"Asp\\", '
#  '\\"拍照翮評\\", \\"二\\", \\"STORE\\", \\"STARTLWS\\", \\"Chroro\\", '
#  '\\"Amtipitt\\", \\"Coinba\\", \\"Bultilo\\", \\"Dunsot\\", \\"ENTREES\\", '
#  '\\"Poi\\", \\"Grilled\\", \\"Chition\\", \\"Tiod\\", \\"日\\", \\"Honited\\", '
#  '\\"Toilaiiin\\", \\"Authomiic\\", \\"Hipolnn\\", \\"Piiis\\", \\"Alcino\\", '
#  '\\"Hitol\\", \\"Stesk\\", \\"utt\\", \\"HEATHY\\", \\"SIDES\\", '
#  '\\"Broiltd\\", \\"Tomitoos\\", \\"Potito\\", \\"臞中文\\", \\"Frlos\\", '
#  '\\"英詔夫日\\"], [\\"看不懂的文字\\", \\"也能翮譯\\", \\"把外文複製到中\\", \\"能自動翮譯及自動發音協助理解\\", '
#  '\\"用在地的語言\\", \\"搜尋在地的美食美景\\", \\"Fooil\\", \\"Cutti\\", \\"口\\", \\"Gut  '
#  'pands\\", \\"Tilt\\", \\"干\\", \\"Tiigmn\\", \\"Tiniion\\", \\"廿\\", '
#  '\\"Tiilmiian\\", \\"peie\\"], [\\"自信工作\\", \\"或\\", \\"際交友\\", '
#  '\\"與外國同事溝通侃侃而談\\", \\"只要會說話就能溝通\\", \\"只會講中文\\", \\"老少都友善\\", \\"也能出國玩\\", '
#  '\\"點一下就翮譯適合全年齡\\"], [\\"同種語言不同地區方言\\", \\"也能清楚辨識\\", \\"日韓英法泰越\\", '
#  '\\"收錄種語言\\"], [\\"連續\\", \\"翮譯\\", \\"超高續航力\\", \\"每日累計使用小時續航可達天以上\\", '
#  '\\"長途旅行也不怕\\", \\"Uonoef\\"], [\\"對話模式\\", \\"一人一句順暢翮譯\\", \\"紀錄完整對話\\", '
#  '\\"不必擔心忘記說過什麼\\"], [\\"翮譯產品比較\\", \\"旺璦\\", \\"他牌\\", \\"他牌\\", \\"產品\\", '
#  '\\"快點翮譯機\\", \\"翮譯\\", \\"翮譯筆\\", \\"語音\\", \\"輸入\\", \\"輸入\\", \\"速度\\", '
#  '\\"正常語速\\", \\"刻意放慢\\", \\"刻意放慢\\", \\"翮譯\\", \\"鍵在不同\\", \\"需於翮譯翮譯\\", '
#  '\\"需額外\\", \\"速度\\", \\"間即時翮譯\\", \\"完成後再複製貼\\", \\"輸出至手機\\", \\"上至想要的\\", '
#  '\\"在不同\\", \\"語音輸入直接轉文字\\", \\"APP\\", \\"原\\", \\"原\\", \\"間使用\\", '
#  '\\"戛旻\\", \\"自動\\", \\"播報譯文\\", \\"語意\\", \\"台灣本土語意\\", \\"國外語意\\", '
#  '\\"國外語意\\", \\"貼在手機背後\\", \\"方便性\\", \\"應用程式下載\\", \\"需額外攜帶產品\\", '
#  '\\"還可作為支架使用\\", \\"網路\\", \\"連接手機\\", \\"連接手機\\", \\"需外連\\", \\"使用\\"], '
#  '[\\"旺德\\", \\"樁\\", \\"在地經營年\\", \\"翮譯產品累計銷售\\", \\"超過萬台\\", \\"安心保證\\", '
#  '\\"原廠年保固\\", \\"在地蒐集台灣語言資料\\", \\"真正落實在地化的語音翮譯\\", \\"旺\\"], [\\"收錄種語言\\", '
#  '\\"種語言\\", \\"種語言\\", \\"標示相機符號此語言\\", \\"在線\\", \\"自由互譯\\", \\"在線\\", '
#  '\\"拍照即譯\\", \\"支援拍照即譯\\", \\"驪瑟\\", \\"英語加章大\\", \\"德語瑞士\\", \\"繁體中文\\", '
#  '\\"菲律賓語\\", \\"俄語\\", \\"老扭語\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語新西蘭\\", '
#  '\\"德語奧地利\\", \\"簡臘中文\\", \\"印尼語\\", \\"西班牙語\\", \\"尼泊爾語\\", \\"阿聯酋\\", '
#  '\\"厄瓜多爾\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語菲律賓\\", \\"怠大利語\\", \\"日語\\", '
#  '\\"法語\\", \\"丹麥語\\", \\"斯洛伐克語\\", \\"沙特\\", \\"波多黎各\\", \\"瑞士\\", '
#  '\\"阿拉伯語\\", \\"西班牙語\\", \\"英語肯尼亞\\", \\"法語加拿大\\", \\"韓語\\", \\"志語\\", '
#  '\\"芬蘭語\\", \\"斯洛文尼亞語\\", \\"黎巴嫩\\", \\"秘曾\\", \\"阿拉伯語\\", \\"西班牙語\\", '
#  '\\"英語南非\\", \\"法語瑞士\\", \\"英語\\", \\"裲甸語\\", \\"冰島語\\", \\"鳥克南語\\", '
#  '\\"阿爾及利亞\\", \\"玻利維亞\\", \\"美國\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語\\", '
#  '\\"法語比利時\\", \\"巍\\", \\"馬來語\\", \\"捷克語\\", \\"塞爾維亞語\\", \\"摩洛哥\\", '
#  '\\"巴孛馬\\", \\"尼日利亞\\", \\"國\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語加納\\", '
#  '\\"荷蘭語\\", \\"赶南語\\", \\"高棉語\\", \\"波苗語\\", \\"波斯語\\", \\"也門\\", \\"哥倫比亞\\", '
#  '\\"比利時\\", \\"束埔寨\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語\\", \\"葡萄牙語\\", '
#  '\\"泰語\\", \\"蒙古語蒙古\\", \\"荷南語\\", \\"拉脫維亞語\\", \\"巴林\\", \\"智利\\", '
#  '\\"坦柔尼亞\\", \\"巴西\\", \\"阿拉伯語\\", \\"驪加\\", \\"英語\\", \\"孟加拉語\\", \\"粵語\\", '
#  '\\"土耳其語\\", \\"莪大利語\\", \\"亞美尼亞語\\", \\"巴勒斯坦\\", \\"巴基斯坦\\", \\"阿拉伯語\\", '
#  '\\"西班牙語\\", \\"英語印度\\", \\"南非荷蘭語\\", \\"粵語\\", \\"阿拉伯語\\", \\"挪威語\\", '
#  '\\"阿姆哈拉語\\", \\"突尼斯\\", \\"侈朋尼共和\\", \\"南非\\", \\"棨\\", \\"埃及\\", '
#  '\\"阿拉伯語\\", \\"西班牙語\\", \\"英語愛爾南\\", \\"祖曾語\\", \\"爪哇語\\", \\"阿拉伯語\\", '
#  '\\"葡萄牙語\\", \\"格魯吉王語\\", \\"伊拉克\\", \\"鳥拉圭\\", \\"南非\\", \\"印度尼酉亞\\", '
#  '\\"利比亞\\", \\"阿拉伯語\\", \\"酉班牙語\\", \\"英語\\", \\"印地君印\\", \\"巽他語\\", '
#  '\\"島茲別克語\\", \\"瑞典語\\", \\"波斯尼王吾\\", \\"約旦\\", \\"尼加拉瓜\\", \\"溴大利亞\\", '
#  '\\"甲度尼西亞\\", \\"偽茁別克斯坦\\", \\"佳泥臻絮扣\\", \\"西班牙語\\", \\"英語新加坡\\", \\"馬拉地語\\", '
#  '\\"鳥雨都語\\", \\"泰米而語\\", \\"希臘語\\", \\"斯瓦希里語\\", \\"丑西哥\\", \\"印度\\", '
#  '\\"馬來西亞\\", \\"坦栗尼王\\", \\"阿扛伯語\\", \\"西班牙語\\", \\"英語香港\\", \\"馬拉雅拉姆語\\", '
#  '\\"羆馬尼亞語\\", \\"阿而巴尼亞\\", \\"立陶宛語\\", \\"阿昱\\", \\"薩爾瓦多\\", \\"印度\\", '
#  '\\"門而巴\\", \\"阿拉伯語\\", \\"蠶\\", \\"鳥甬都語\\", \\"語\\", \\"保加利亞語\\", \\"旁言\\", '
#  '\\"希伯來語\\", \\"卡塔雨\\", \\"印度\\", \\"果魯穆語印宦\\", \\"西班牙語\\", \\"西班牙語\\", '
#  '\\"泰米雨語\\", \\"三加拉語\\", \\"杠素尼亞\\", \\"馬其頓諳\\", \\"匈牙利語\\", \\"美國\\", '
#  '\\"巴拉圭\\", \\"新加坡\\", \\"印度\\", \\"北馬其頓\\", \\"西班牙語\\", \\"西班牙語\\", '
#  '\\"泰米爾語\\", \\"古拉特語\\", \\"克羅地玉語\\", \\"爰沙尼王語\\", \\"哈薩克諳\\", \\"危地馬拉\\", '
#  '\\"洪都拉斯\\", \\"斯里芮卡\\", \\"印度\\", \\"愛沙尼亞\\", \\"冶薩克斯坦\\", \\"阿塞拜彊語\\", '
#  '\\"斯瓦希里語\\", \\"泵米爾語\\", \\"泰膚固語\\", \\"巴斯克話\\", \\"籬髒\\", \\"加利酉亞語\\", '
#  '\\"肯尼亞\\", \\"印度\\", \\"印庹\\", \\"酉班牙\\"], [\\"產品規格\\", \\"額定輸入電壓電流\\", '
#  '\\"商品尺寸\\", \\"Xmm\\", \\"商品重量\\", \\"充電時間\\", \\"小時\\", \\"Uonder\\"], '
#  '[\\"超值加購配件\\", \\"收納皮套\\", \\"本商品不包含快點翮譯機\\", \\"Uonde\\"]]"}\n')
# '--------------------'
# ('{"product_name_str": "拍照快點翻譯機 WM-T29W+專用皮套", "function": "[\\"語音文字雙向翻譯\\", '
#  '\\"拍照翻譯文字\\", \\"支援超過70種語言\\", \\"精準的語音輸入系統\\", \\"開啟對話模式\\", \\"超高續航力\\", '
#  '\\"邊充邊用\\", \\"標點符號自動加入\\"]", "material": "[\\"無\\"]", "design": '
#  '"[\\"無\\"]", "experience": "[\\"輕鬆清潔\\", \\"完全沒有負擔\\", \\"讓你一秒理解\\", '
#  '\\"不必擔心忘記說過什麼\\"]", "user": "[\\"無\\"]", "scenario": "[\\"無\\"]", "limit": '
#  '"[\\"無\\"]"}')
# 2
# ('input||{"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線", "combine": '
#  '"[\\"可無線為手機Air PodsApple Watch等電子產品充電\\", \\"可同時使用無線與有線為電子產品充電\\", '
#  '\\"使用無線為電子產品充電的同時可以使用有線為本產品充電\\", \\"攝氏60度過熱安全斷電裝置\\", '
#  '\\"兩個有線插孔Lightening及TypeC皆可充電及放電\\"] [[\\"黑\\", \\"莫蘭迪粉紅\\", \\"莫蘭迪綠\\", '
#  '\\"莫蘭迪白\\", \\"莫蘭迪紫\\", \\"莫蘭迪灰\\"], [\\"隨身攜帶負擔\\", \\"和小零錢包一樣卞小\\", '
#  '\\"輕量設計\\", \\"放進小包空間沒問題拿在\\", \\"手零負擔\\", \\"磁吸無線萬用充 小零錢包\\", '
#  '\\"告別厚重的行動電源\\", \\"厚度減少至少\\", \\"重量減少\\", \\"放包包\\", \\"口袋直接出門\\", '
#  '\\"磁吸無線萬用充  他牌磁吸萬用充\\", \\"Iphone\\", \\"pro max\\", \\"磁吸萬用充\\", '
#  '\\"磁吸萬用充重量\\", \\"Iphone pro max\\", \\"高效雙輸\\", \\"適用於\\", \\"和\\", '
#  '\\"APPI  WATCH\\", \\"機多功能 輕巧好攜帶\\"], [\\"貼合牢固\\", \\"磁吸充電\\", \\"啦\\", '
#  '\\"聲完美貼合手機不影響操\\", \\"作\\", \\"搖晃也不輕易脫落\\", \\"超薄\\", \\"輕巧服貼\\", '
#  '\\"弧形導角設計\\", \\"完美的導角設計\\", \\"增加舒適感\\", \\"握感舒適服貼\\", \\"莫蘭迪色磨砂設計\\", '
#  '\\"表面細緻磨砂處理\\", \\"經典黑\\", \\"白色\\", \\"莫蘭迪白\\", \\"莫蘭迪粉紅\\", \\"莫蘭迪綠\\", '
#  '\\"莫蘭迪紫\\", \\"莫蘭迪灰\\", \\"優雅莫蘭迪色係\\", \\"orandi Colors\\", '
#  '\\"不同螢幕皆有顯色差異\\", \\"網頁顏色呈現僅供參考以實際商品為準\\"], [\\"用品\\", \\"台搞定\\", \\"支持其他 '
#  '裝置\\", \\"輸入輸出接口\\", \\"數據線\\", \\"磁吸充電\\", \\"小巧便攜\\", \\"Twoe\\", '
#  '\\"Type\\", \\"Lightning\\", \\"國際安全認證\\", \\"支持其他裝置\\", \\"國際安全認證\\", '
#  '\\"經濟部標準檢驗局\\", \\"CCAHLPT\\", \\"國家通訊傳播委員會認證\\", \\"美國認證\\", \\"歐盟合格認證\\", '
#  '\\"電子電機設備危害物質限制指令\\", \\"德凱認證股份有限公司\\", \\"電信管制射頻器材\\", \\"式認證證明\\", \\"型式宇第 '
#  '鹽\\", \\"DEKRA\\", \\"接椎用窯驄合格籤就符台性聾明櫬蕊者矗\\", \\"盲誠國際杏奘有限公司\\", \\"么\\", '
#  '\\"無線充行勁電源\\", \\"DTGEp DES\\", \\"弒軟竺蔽器封停\\", \\"七發射功率電場強度\\", \\"文杯街\\", '
#  '\\"審驗合格標籤\\", \\"黑盃其型驍盎臉合掐標籤芷\\", \\"杜二資通安全撿測\\", \\"背面\\", \\"磁吸面\\", '
#  '\\"側面\\", \\"產品規格\\", \\"品名\\", \\"磁吸無線萬用充\\", \\"型號\\", \\"內容物\\", '
#  '\\"磁吸無線充\\", \\"說明書\\", \\"充電線\\", \\"巳寸\\", \\"lmm\\", \\"材質\\", \\"殼料\\", '
#  '\\"電子元件\\", \\"金屬元件電池線材\\", \\"電池容量\\", \\"somAh DCh\\", \\"額定容量\\", '
#  '\\"mAh\\", \\"mAh\\", \\"mAh\\", \\"輸\\", \\"DCA\\", \\"輸入\\", \\"DCA\\", '
#  '\\"輸出\\", \\"無線輸出\\", \\"WWW Apple  atch\\", \\"同時輸出\\", \\"輸出 無線輸出\\"], '
#  '[\\"超值贈品\\", \\"最整齊的線\\", \\"緊密磁吸層\\", \\"為一般標準  的充電線\\", \\"無論居家辦公\\", '
#  '\\"旅館\\", \\"車內使用皆便利\\", \\"充電 傳輸資訊更方便\\", \\"送\\", \\"高速充電\\", \\"支援  '
#  '規格快速充電\\", \\"最高速可達\\", \\"亦適用於其他適用之 設備\\", \\"口日\\", \\"高規格收納\\", '
#  '\\"隨心所欲的收納\\", \\"BEFORE\\", \\"AFTER\\"], [\\"通過次的嚴苛彎折測試\\", '
#  '\\"高性能強化結構線芯\\", \\"經測試可承受多次的 彎折測試\\", \\"頂級材質經久耐用\\", '
#  '\\"以獨家高性能線芯和彈道尼龍編織線包覆住高品質線\\", \\"外殼和  加固耐插拔施力點\\", \\"提供極佳的卓越耐用性\\"]]"}\n')
# '--------------------'
# ('output || {"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線", "function": '
#  '"[\\"無線充電\\", \\"同時使用無線與有線充電\\", \\"過熱安全斷電裝置\\", \\"雙有線插孔充電\\"]", '
#  '"material": "[\\"無\\"]", "design": "[\\"超薄設計\\", \\"弧形導角設計\\", '
#  '\\"莫蘭迪色磨砂設計\\"]", "experience": "[\\"輕量設計\\", \\"隨身攜帶無負擔\\", \\"握感舒適\\", '
#  '\\"充電傳輸方便\\", \\"經久耐用\\"]", "user": "[\\"無\\"]", "scenario": "[\\"居家辦公\\", '
#  '\\"旅館\\", \\"車內使用\\"]", "limit": "[\\"無\\"]"}')

# %% [markdown]
# - Try gpt-4o

# %%
provider = "openai"
model_id = "gpt-4o"

delimiter = "####################"

ret = []
for i in range(3):
    pp(i)
    source_content = 'input||' + updated_df.loc[i, 'source'] + '\n'
    user_message = f"""{source_content} 請用中文回答。"""
    messages =  [ {'role':'system', 'content': system_message}, 
                 {'role':'user', 'content': user_message}, 
                ] 
    response = client.chat.completions.create(
        model=f"{provider}:{model_id}",
        messages=messages,
        temperature=0.0
    )
    result = response.choices[0].message.content
    ret.append(result)
    pp(source_content)
    pp(delimiter)
    pp(result)
# Out:
# 0
# ('input||{"product_name_str": "10 in 1 百變手機支架 - 黑色", "combine": '
#  '"[\\"徹底顛覆對手機配件的想像\\", \\"citiesocial 全臺獨家只有這裡有\\", \\"只有卡片大小卻有超多變化\\", '
#  '\\"結合超多支架立架車用磁吸手持\\", \\"連桿子都能輕易吊掛固定\\", \\"一貼即吸極度好用無負擔\\", '
#  '\\"附有黏貼式磁環任何廠牌手機都適用  因摺疊機特性建議於展開且垂直放置的情況下使用 \\", \\"宅家追劇旅行拍攝工作展示日常滑手機\\", '
#  '\\"內容物10 in 1 百變手機支架 x 1專用磁環 x 1重複貼金屬片 x 1\\", '
#  '\\"注意事項實際商品會於表面貼上一層輕薄的保護膜形成半透明的霧面感對使用上無影響建議盡量避免撕除以免影響磁吸設計的效果\\"] '
#  '[[\\"STANCE\\"], [\\"儿\\", \\"仆\\", \\"化\\"], [\\"Watch\\"], [\\"卜器\\", '
#  '\\"Vent MountIt\\"], [\\"MountIt\\"], [\\"口\\"], [\\"叫\\", \\"IAF\\"], '
#  '[\\"Dimensions\\", \\"Magnetic\\", \\"Base\\"]]"}\n')
# '####################'
# ('{"product_name_str": "10 in 1 百變手機支架 - 黑色", "function": "[\\"超多支架立架\\", '
#  '\\"車用磁吸\\", \\"手持\\", \\"吊掛固定\\", \\"一貼即吸\\"]", "material": "[\\"無\\"]", '
#  '"design": "[\\"卡片大小\\"]", "experience": "[\\"極度好用無負擔\\"]", "user": '
#  '"[\\"任何廠牌手機都適用\\"]", "scenario": "[\\"宅家追劇\\", \\"旅行拍攝\\", \\"工作展示\\", '
#  '\\"日常滑手機\\"]", "limit": "[\\"citiesocial 全臺獨家\\"]"}')
# 1
# ('input||{"product_name_str": "拍照快點翻譯機 WM-T29W+專用皮套", "combine": '
#  '"[\\"語音文字雙向翻譯自動播放翻譯後的外語學會外語精準發音\\", \\"拍照就能翻譯文字菜單路標簡單看得懂支援超過７０種連網互譯\\", '
#  '\\"超過100種國家語言60 種地區口音讓你在語言的世界暢行無阻\\", \\"第三方APP適用無需複製貼上APP間自由切換\\", '
#  '\\"語音輸入精準辯讀正確率完勝手機內建連繞口令都能完美轉譯\\", \\"精準的語音輸入系統高效率輸入每分鐘約200字\\", '
#  '\\"開啟對話模式完整記錄每一句對話\\", \\"原文譯文同步顯示原文翻譯一起呈現不怕翻錯好尷尬\\", \\"超高續航力可以連續翻譯 '
#  '10hr\\", \\"超輕盈重量15G帶著完全沒有負擔\\", \\"邊充邊用支援可邊充邊用溝通不斷線\\", '
#  '\\"標點符號依說話語義自動加入標點符號\\"] [[\\"拍照快點翮譯機\\", \\"訃刈\\", \\"二儿二芍\\", \\"Hola\\", '
#  '\\"Wonpe\\", \\"你好\\"], [\\"按一下翮譯全世界\\", \\"多國互譯\\", \\"拍照翮譯\\", \\"雙語同顯\\", '
#  '\\"語音打字\\", \\"種語言\\", \\"自動播報\\", \\"自動產出\\", \\"台灣語意\\", \\"標點符號\\", '
#  '\\"翮譯資料庫\\"], [\\"我想要一杯熱的\\", \\"焦糖瑪奇朵\\", \\"語音輸入 直接翮譯\\", \\"只需要對手機說話\\", '
#  '\\"輕鬆翮譯外語\\", \\"讓你一秒理解\\", \\"打開全球眼界\\"], [\\"眾多網友\\", \\"好評推薦\\", '
#  '\\"剛剛收試\\", \\"比起以前的翮譯機方便好用太多\\", \\"了翮譯很快主要是第三方軟體也支援\\", \\"開車不用\\", '
#  '\\"手忙腳亂與近期到臺灣的旅客溝通無障礙一次\\", \\"買了兩個慶幸買到有用的\\", \\"也可以邊學習語言\\", '
#  '\\"不會詞不達意亂翮譯一通\\", \\"谷不敢用鬧笑話了真\\", \\"的不錯用\\", \\"真的不錯用\\"], [\\"精準的\\", '
#  '\\"語音輸入係統\\", \\"蘭\\", \\"內建語音輸入\\", \\"快點翮譯機\\", \\"連繞口令都能聽得懂\\", '
#  '\\"正確率完勝手機內建系統\\", \\"James\\", \\"James\\", \\"You\\", \\"和尚端湯\\", '
#  '\\"和尚端湯上塔塔\\", \\"國語\\", \\"滑湯灑踏踏踏\\", \\"滑湯灑湯燙塔\\", \\"我 哈 好 對 貞\\", \\"我 哈 '
#  '好 對 直\\", \\"另\\", \\"女 七\\", \\"夕\\"], [\\"三\\", \\"標點符號\\", \\"也能正確呈現\\", '
#  '\\"James\\", \\"飛機預計下午\\", \\"抵達 我們\\", \\"總共個人請安\\", \\"排合適的車輛來接\\", '
#  '\\"我們謝謝\\", \\"我 哈 好 對 真的 因為\\", \\"巳虫\\"], [\\"能語音輸入 為何要手打\\", \\"有時候真的\\", '
#  '\\"騰不出手打字\\", \\"語音輸入\\", \\"直接轉成翮譯文字\\"], [\\"巳\\", \\"中\\", \\"高效率輸\\", '
#  '\\"每分鐘輸入\\", \\"孛\\", \\"手打輸入\\", \\"語音輸入\\", \\"每分鐘約字\\", \\"每分鐘約 字\\", '
#  '\\"齣入文字\\", \\"咭鹵\\", \\"琦吊\\"], [\\"不需要複製貼上\\", \\"任何第三方軟體都適用\\", \\"交友\\", '
#  '\\"記事本\\", \\"搜尋引擎\\", \\"LNE\\"], [\\"未使用快點翮譯機\\", \\"使用快點翮譯機\\", \\"蚩\\", '
#  '\\"上\\", \\"捆\\", \\"逗\\", \\"奸\\", \\"省下的時間\\", \\"比你想得更多\\", \\"更彈性\\", '
#  '\\"更自由\\", \\"七\\", \\"王蜚面\\", \\"好的一\\", \\"OKP\\", \\"垚\\", \\"喃喃\\"], '
#  '[\\"語音\\", \\"文字都能\\", \\"雙向二翮譯\\", \\"自動播報翮譯後的外語\\", \\"學會外語精準發音\\"], '
#  '[\\"一鍵拍照\\", \\"圖片內容立即呈現\\", \\"LUNCH\\", \\"Eggpint\\", \\"Asp\\", '
#  '\\"拍照翮評\\", \\"二\\", \\"STORE\\", \\"STARTLWS\\", \\"Chroro\\", '
#  '\\"Amtipitt\\", \\"Coinba\\", \\"Bultilo\\", \\"Dunsot\\", \\"ENTREES\\", '
#  '\\"Poi\\", \\"Grilled\\", \\"Chition\\", \\"Tiod\\", \\"日\\", \\"Honited\\", '
#  '\\"Toilaiiin\\", \\"Authomiic\\", \\"Hipolnn\\", \\"Piiis\\", \\"Alcino\\", '
#  '\\"Hitol\\", \\"Stesk\\", \\"utt\\", \\"HEATHY\\", \\"SIDES\\", '
#  '\\"Broiltd\\", \\"Tomitoos\\", \\"Potito\\", \\"臞中文\\", \\"Frlos\\", '
#  '\\"英詔夫日\\"], [\\"看不懂的文字\\", \\"也能翮譯\\", \\"把外文複製到中\\", \\"能自動翮譯及自動發音協助理解\\", '
#  '\\"用在地的語言\\", \\"搜尋在地的美食美景\\", \\"Fooil\\", \\"Cutti\\", \\"口\\", \\"Gut  '
#  'pands\\", \\"Tilt\\", \\"干\\", \\"Tiigmn\\", \\"Tiniion\\", \\"廿\\", '
#  '\\"Tiilmiian\\", \\"peie\\"], [\\"自信工作\\", \\"或\\", \\"際交友\\", '
#  '\\"與外國同事溝通侃侃而談\\", \\"只要會說話就能溝通\\", \\"只會講中文\\", \\"老少都友善\\", \\"也能出國玩\\", '
#  '\\"點一下就翮譯適合全年齡\\"], [\\"同種語言不同地區方言\\", \\"也能清楚辨識\\", \\"日韓英法泰越\\", '
#  '\\"收錄種語言\\"], [\\"連續\\", \\"翮譯\\", \\"超高續航力\\", \\"每日累計使用小時續航可達天以上\\", '
#  '\\"長途旅行也不怕\\", \\"Uonoef\\"], [\\"對話模式\\", \\"一人一句順暢翮譯\\", \\"紀錄完整對話\\", '
#  '\\"不必擔心忘記說過什麼\\"], [\\"翮譯產品比較\\", \\"旺璦\\", \\"他牌\\", \\"他牌\\", \\"產品\\", '
#  '\\"快點翮譯機\\", \\"翮譯\\", \\"翮譯筆\\", \\"語音\\", \\"輸入\\", \\"輸入\\", \\"速度\\", '
#  '\\"正常語速\\", \\"刻意放慢\\", \\"刻意放慢\\", \\"翮譯\\", \\"鍵在不同\\", \\"需於翮譯翮譯\\", '
#  '\\"需額外\\", \\"速度\\", \\"間即時翮譯\\", \\"完成後再複製貼\\", \\"輸出至手機\\", \\"上至想要的\\", '
#  '\\"在不同\\", \\"語音輸入直接轉文字\\", \\"APP\\", \\"原\\", \\"原\\", \\"間使用\\", '
#  '\\"戛旻\\", \\"自動\\", \\"播報譯文\\", \\"語意\\", \\"台灣本土語意\\", \\"國外語意\\", '
#  '\\"國外語意\\", \\"貼在手機背後\\", \\"方便性\\", \\"應用程式下載\\", \\"需額外攜帶產品\\", '
#  '\\"還可作為支架使用\\", \\"網路\\", \\"連接手機\\", \\"連接手機\\", \\"需外連\\", \\"使用\\"], '
#  '[\\"旺德\\", \\"樁\\", \\"在地經營年\\", \\"翮譯產品累計銷售\\", \\"超過萬台\\", \\"安心保證\\", '
#  '\\"原廠年保固\\", \\"在地蒐集台灣語言資料\\", \\"真正落實在地化的語音翮譯\\", \\"旺\\"], [\\"收錄種語言\\", '
#  '\\"種語言\\", \\"種語言\\", \\"標示相機符號此語言\\", \\"在線\\", \\"自由互譯\\", \\"在線\\", '
#  '\\"拍照即譯\\", \\"支援拍照即譯\\", \\"驪瑟\\", \\"英語加章大\\", \\"德語瑞士\\", \\"繁體中文\\", '
#  '\\"菲律賓語\\", \\"俄語\\", \\"老扭語\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語新西蘭\\", '
#  '\\"德語奧地利\\", \\"簡臘中文\\", \\"印尼語\\", \\"西班牙語\\", \\"尼泊爾語\\", \\"阿聯酋\\", '
#  '\\"厄瓜多爾\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語菲律賓\\", \\"怠大利語\\", \\"日語\\", '
#  '\\"法語\\", \\"丹麥語\\", \\"斯洛伐克語\\", \\"沙特\\", \\"波多黎各\\", \\"瑞士\\", '
#  '\\"阿拉伯語\\", \\"西班牙語\\", \\"英語肯尼亞\\", \\"法語加拿大\\", \\"韓語\\", \\"志語\\", '
#  '\\"芬蘭語\\", \\"斯洛文尼亞語\\", \\"黎巴嫩\\", \\"秘曾\\", \\"阿拉伯語\\", \\"西班牙語\\", '
#  '\\"英語南非\\", \\"法語瑞士\\", \\"英語\\", \\"裲甸語\\", \\"冰島語\\", \\"鳥克南語\\", '
#  '\\"阿爾及利亞\\", \\"玻利維亞\\", \\"美國\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語\\", '
#  '\\"法語比利時\\", \\"巍\\", \\"馬來語\\", \\"捷克語\\", \\"塞爾維亞語\\", \\"摩洛哥\\", '
#  '\\"巴孛馬\\", \\"尼日利亞\\", \\"國\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語加納\\", '
#  '\\"荷蘭語\\", \\"赶南語\\", \\"高棉語\\", \\"波苗語\\", \\"波斯語\\", \\"也門\\", \\"哥倫比亞\\", '
#  '\\"比利時\\", \\"束埔寨\\", \\"阿拉伯語\\", \\"西班牙語\\", \\"英語\\", \\"葡萄牙語\\", '
#  '\\"泰語\\", \\"蒙古語蒙古\\", \\"荷南語\\", \\"拉脫維亞語\\", \\"巴林\\", \\"智利\\", '
#  '\\"坦柔尼亞\\", \\"巴西\\", \\"阿拉伯語\\", \\"驪加\\", \\"英語\\", \\"孟加拉語\\", \\"粵語\\", '
#  '\\"土耳其語\\", \\"莪大利語\\", \\"亞美尼亞語\\", \\"巴勒斯坦\\", \\"巴基斯坦\\", \\"阿拉伯語\\", '
#  '\\"西班牙語\\", \\"英語印度\\", \\"南非荷蘭語\\", \\"粵語\\", \\"阿拉伯語\\", \\"挪威語\\", '
#  '\\"阿姆哈拉語\\", \\"突尼斯\\", \\"侈朋尼共和\\", \\"南非\\", \\"棨\\", \\"埃及\\", '
#  '\\"阿拉伯語\\", \\"西班牙語\\", \\"英語愛爾南\\", \\"祖曾語\\", \\"爪哇語\\", \\"阿拉伯語\\", '
#  '\\"葡萄牙語\\", \\"格魯吉王語\\", \\"伊拉克\\", \\"鳥拉圭\\", \\"南非\\", \\"印度尼酉亞\\", '
#  '\\"利比亞\\", \\"阿拉伯語\\", \\"酉班牙語\\", \\"英語\\", \\"印地君印\\", \\"巽他語\\", '
#  '\\"島茲別克語\\", \\"瑞典語\\", \\"波斯尼王吾\\", \\"約旦\\", \\"尼加拉瓜\\", \\"溴大利亞\\", '
#  '\\"甲度尼西亞\\", \\"偽茁別克斯坦\\", \\"佳泥臻絮扣\\", \\"西班牙語\\", \\"英語新加坡\\", \\"馬拉地語\\", '
#  '\\"鳥雨都語\\", \\"泰米而語\\", \\"希臘語\\", \\"斯瓦希里語\\", \\"丑西哥\\", \\"印度\\", '
#  '\\"馬來西亞\\", \\"坦栗尼王\\", \\"阿扛伯語\\", \\"西班牙語\\", \\"英語香港\\", \\"馬拉雅拉姆語\\", '
#  '\\"羆馬尼亞語\\", \\"阿而巴尼亞\\", \\"立陶宛語\\", \\"阿昱\\", \\"薩爾瓦多\\", \\"印度\\", '
#  '\\"門而巴\\", \\"阿拉伯語\\", \\"蠶\\", \\"鳥甬都語\\", \\"語\\", \\"保加利亞語\\", \\"旁言\\", '
#  '\\"希伯來語\\", \\"卡塔雨\\", \\"印度\\", \\"果魯穆語印宦\\", \\"西班牙語\\", \\"西班牙語\\", '
#  '\\"泰米雨語\\", \\"三加拉語\\", \\"杠素尼亞\\", \\"馬其頓諳\\", \\"匈牙利語\\", \\"美國\\", '
#  '\\"巴拉圭\\", \\"新加坡\\", \\"印度\\", \\"北馬其頓\\", \\"西班牙語\\", \\"西班牙語\\", '
#  '\\"泰米爾語\\", \\"古拉特語\\", \\"克羅地玉語\\", \\"爰沙尼王語\\", \\"哈薩克諳\\", \\"危地馬拉\\", '
#  '\\"洪都拉斯\\", \\"斯里芮卡\\", \\"印度\\", \\"愛沙尼亞\\", \\"冶薩克斯坦\\", \\"阿塞拜彊語\\", '
#  '\\"斯瓦希里語\\", \\"泵米爾語\\", \\"泰膚固語\\", \\"巴斯克話\\", \\"籬髒\\", \\"加利酉亞語\\", '
#  '\\"肯尼亞\\", \\"印度\\", \\"印庹\\", \\"酉班牙\\"], [\\"產品規格\\", \\"額定輸入電壓電流\\", '
#  '\\"商品尺寸\\", \\"Xmm\\", \\"商品重量\\", \\"充電時間\\", \\"小時\\", \\"Uonder\\"], '
#  '[\\"超值加購配件\\", \\"收納皮套\\", \\"本商品不包含快點翮譯機\\", \\"Uonde\\"]]"}\n')
# '####################'
# ('{"product_name_str": "拍照快點翻譯機 WM-T29W+專用皮套", "function": "[\\"語音文字雙向翻譯\\", '
#  '\\"拍照就能翻譯\\", \\"支援超過70種語言\\", \\"自動播放翻譯後的外語\\", \\"語音輸入精準辯讀\\", '
#  '\\"高效率輸入\\", \\"開啟對話模式\\", \\"原文譯文同步顯示\\", \\"超高續航力\\", \\"邊充邊用\\", '
#  '\\"標點符號自動加入\\"]", "material": "[\\"無\\"]", "design": "[\\"無\\"]", '
#  '"experience": "[\\"超輕盈重量15G\\", \\"帶著完全沒有負擔\\"]", "user": "[\\"全年齡適用\\"]", '
#  '"scenario": "[\\"出國旅行\\", \\"與外國同事溝通\\"]", "limit": "[\\"無\\"]"}')
# 2
# ('input||{"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線", "combine": '
#  '"[\\"可無線為手機Air PodsApple Watch等電子產品充電\\", \\"可同時使用無線與有線為電子產品充電\\", '
#  '\\"使用無線為電子產品充電的同時可以使用有線為本產品充電\\", \\"攝氏60度過熱安全斷電裝置\\", '
#  '\\"兩個有線插孔Lightening及TypeC皆可充電及放電\\"] [[\\"黑\\", \\"莫蘭迪粉紅\\", \\"莫蘭迪綠\\", '
#  '\\"莫蘭迪白\\", \\"莫蘭迪紫\\", \\"莫蘭迪灰\\"], [\\"隨身攜帶負擔\\", \\"和小零錢包一樣卞小\\", '
#  '\\"輕量設計\\", \\"放進小包空間沒問題拿在\\", \\"手零負擔\\", \\"磁吸無線萬用充 小零錢包\\", '
#  '\\"告別厚重的行動電源\\", \\"厚度減少至少\\", \\"重量減少\\", \\"放包包\\", \\"口袋直接出門\\", '
#  '\\"磁吸無線萬用充  他牌磁吸萬用充\\", \\"Iphone\\", \\"pro max\\", \\"磁吸萬用充\\", '
#  '\\"磁吸萬用充重量\\", \\"Iphone pro max\\", \\"高效雙輸\\", \\"適用於\\", \\"和\\", '
#  '\\"APPI  WATCH\\", \\"機多功能 輕巧好攜帶\\"], [\\"貼合牢固\\", \\"磁吸充電\\", \\"啦\\", '
#  '\\"聲完美貼合手機不影響操\\", \\"作\\", \\"搖晃也不輕易脫落\\", \\"超薄\\", \\"輕巧服貼\\", '
#  '\\"弧形導角設計\\", \\"完美的導角設計\\", \\"增加舒適感\\", \\"握感舒適服貼\\", \\"莫蘭迪色磨砂設計\\", '
#  '\\"表面細緻磨砂處理\\", \\"經典黑\\", \\"白色\\", \\"莫蘭迪白\\", \\"莫蘭迪粉紅\\", \\"莫蘭迪綠\\", '
#  '\\"莫蘭迪紫\\", \\"莫蘭迪灰\\", \\"優雅莫蘭迪色係\\", \\"orandi Colors\\", '
#  '\\"不同螢幕皆有顯色差異\\", \\"網頁顏色呈現僅供參考以實際商品為準\\"], [\\"用品\\", \\"台搞定\\", \\"支持其他 '
#  '裝置\\", \\"輸入輸出接口\\", \\"數據線\\", \\"磁吸充電\\", \\"小巧便攜\\", \\"Twoe\\", '
#  '\\"Type\\", \\"Lightning\\", \\"國際安全認證\\", \\"支持其他裝置\\", \\"國際安全認證\\", '
#  '\\"經濟部標準檢驗局\\", \\"CCAHLPT\\", \\"國家通訊傳播委員會認證\\", \\"美國認證\\", \\"歐盟合格認證\\", '
#  '\\"電子電機設備危害物質限制指令\\", \\"德凱認證股份有限公司\\", \\"電信管制射頻器材\\", \\"式認證證明\\", \\"型式宇第 '
#  '鹽\\", \\"DEKRA\\", \\"接椎用窯驄合格籤就符台性聾明櫬蕊者矗\\", \\"盲誠國際杏奘有限公司\\", \\"么\\", '
#  '\\"無線充行勁電源\\", \\"DTGEp DES\\", \\"弒軟竺蔽器封停\\", \\"七發射功率電場強度\\", \\"文杯街\\", '
#  '\\"審驗合格標籤\\", \\"黑盃其型驍盎臉合掐標籤芷\\", \\"杜二資通安全撿測\\", \\"背面\\", \\"磁吸面\\", '
#  '\\"側面\\", \\"產品規格\\", \\"品名\\", \\"磁吸無線萬用充\\", \\"型號\\", \\"內容物\\", '
#  '\\"磁吸無線充\\", \\"說明書\\", \\"充電線\\", \\"巳寸\\", \\"lmm\\", \\"材質\\", \\"殼料\\", '
#  '\\"電子元件\\", \\"金屬元件電池線材\\", \\"電池容量\\", \\"somAh DCh\\", \\"額定容量\\", '
#  '\\"mAh\\", \\"mAh\\", \\"mAh\\", \\"輸\\", \\"DCA\\", \\"輸入\\", \\"DCA\\", '
#  '\\"輸出\\", \\"無線輸出\\", \\"WWW Apple  atch\\", \\"同時輸出\\", \\"輸出 無線輸出\\"], '
#  '[\\"超值贈品\\", \\"最整齊的線\\", \\"緊密磁吸層\\", \\"為一般標準  的充電線\\", \\"無論居家辦公\\", '
#  '\\"旅館\\", \\"車內使用皆便利\\", \\"充電 傳輸資訊更方便\\", \\"送\\", \\"高速充電\\", \\"支援  '
#  '規格快速充電\\", \\"最高速可達\\", \\"亦適用於其他適用之 設備\\", \\"口日\\", \\"高規格收納\\", '
#  '\\"隨心所欲的收納\\", \\"BEFORE\\", \\"AFTER\\"], [\\"通過次的嚴苛彎折測試\\", '
#  '\\"高性能強化結構線芯\\", \\"經測試可承受多次的 彎折測試\\", \\"頂級材質經久耐用\\", '
#  '\\"以獨家高性能線芯和彈道尼龍編織線包覆住高品質線\\", \\"外殼和  加固耐插拔施力點\\", \\"提供極佳的卓越耐用性\\"]]"}\n')
# '####################'
# ('{"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線", "function": "[\\"可無線為手機Air '
#  'PodsApple Watch等電子產品充電\\", \\"可同時使用無線與有線為電子產品充電\\", \\"過熱安全斷電裝置\\", '
#  '\\"高效雙輸\\", \\"磁吸充電\\", \\"高速充電\\", \\"支援快速充電\\", \\"緊密磁吸層\\"]", "material": '
#  '"[\\"頂級材質經久耐用\\", \\"高性能強化結構線芯\\", \\"彈道尼龍編織線\\"]", "design": '
#  '"[\\"弧形導角設計\\", \\"莫蘭迪色磨砂設計\\", \\"表面細緻磨砂處理\\"]", "experience": '
#  '"[\\"輕量設計\\", \\"輕巧便攜\\", \\"握感舒適服貼\\", \\"隨心所欲的收納\\"]", "user": '
#  '"[\\"無\\"]", "scenario": "[\\"居家辦公\\", \\"旅館\\", \\"車內使用\\"]", "limit": '
#  '"[\\"無\\"]"}')

# %% [markdown]
# ### 'gpt-4o' is a bit better than the following 'gpt-4o-mini' response
#
# ('output || {"product_name_str": "【特惠組】磁吸無線萬用充+磁吸100W捲捲線", "function": '
#  '"[\\"無線充電\\", \\"同時使用無線與有線充電\\", \\"過熱安全斷電裝置\\", \\"雙有線插孔充電\\"]", '
#  '"material": "[\\"無\\"]", "design": "[\\"超薄設計\\", \\"弧形導角設計\\", '
#  '\\"莫蘭迪色磨砂設計\\"]", "experience": "[\\"輕量設計\\", \\"隨身攜帶無負擔\\", \\"握感舒適\\", '
#  '\\"充電傳輸方便\\", \\"經久耐用\\"]", "user": "[\\"無\\"]", "scenario": "[\\"居家辦公\\", '
#  '\\"旅館\\", \\"車內使用\\"]", "limit": "[\\"無\\"]"}')
